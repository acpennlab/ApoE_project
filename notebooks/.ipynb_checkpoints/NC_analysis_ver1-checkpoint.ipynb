% %%
format short g

% %%
pkg install "https://github.com/gnu-octave/statistics-resampling/archive/refs/heads/master.zip"
% Out:
% The statistics-resampling package was installed into the directory:
% /home/jovyan/.local/share/octave/api-v58/packages/statistics-resampling-5.6.1-dev
% License and copyright information can be found at:
% https://github.com/gnu-octave/statistics-resampling/blob/master/COPYING

% %%
pkg load statistics-resampling

% %%
[~, genotype] = xlsread ('../data/abeta-cleaned_ver1_coded.xlsx', 'Abeta', 'E2:E199');
[~, condition] = xlsread ('../data/abeta-cleaned_ver1_coded.xlsx', 'Abeta', 'F2:F199');

% for cell clusters am I averaging from the same cell into one data point
% need to load animal information once it is available

outcomes = xlsread ('../data/abeta-cleaned_ver1_coded.xlsx', 'Abeta', 'G2:S199');

disp (size(genotype))
disp (size(condition))
disp (size(outcomes))
% Out:
%           198            1
%           198            1
%           198           13

% %%
% getting rid of columns now as matrix automatically removes NaN, remember that now means that the outcome numbers have shifted

% %%
if (size(outcomes, 2) > 11)
    outcomes(:,[8,13]) = [];
end

disp (size(outcomes))
% Out:
%           198           11

% %%
for i = 1: size(outcomes, 2)
    MAT_T = bootlm (outcomes(:,i), {genotype, condition}, 'model', 'full', 'display', 'on', ...
            'contrasts', 'treatment', 'nboot', 0);
    print(sprintf('../output/NC_ver1/outcome%d.png', i), '-dpng', '-r300')
end

% %%
% after looking at graphs, outlier rows are: row 2 (outcome 7)  row 164 (outcome 11) (double check)

% %%
if (size (outcomes, 1) > 196)
    genotype([2,164],:) = [];
    condition([2,164],:) = [];
    outcomes([2,164],:) = [];
    MAT_T.X([2,164],:) = [];
end

disp (size(genotype))
disp (size(condition))
disp (size(outcomes))
disp (size(MAT_T.X))
% Out:
%           196            1
%           196            1
%           196           11
%           196            6

% %%
% bayesian bootstrap summary statistics using Simple Random Sampling

% %%
STATS_SRS = bootbayes(outcomes, MAT_T.X);

% %%
% can't do cluster bootstrap sampling as of yet, assume Deff = 1

% %%
Deff = 1
% Out:
% Deff =     1

% %%
% orthogonal (helmert) contrast coding

% %%
MAT_H = bootlm (outcomes(:,11), {genotype,condition}, 'model', 'full', ...
                'display', 'off', 'contrasts', 'helmert', 'nboot', 0, 'dim', [1,2]);
MAT_H.C

MAT_H = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', ...
                'display', 'off', 'contrasts', MAT_H.C, 'nboot', 0, 'dim', [1,2]);
                
size (MAT_H.X)
% Out:
% ans =
% {
%   [1,1] =
%
%            -0.5
%             0.5
%
%   [1,2] =
%
%        -0.66667            0
%         0.33333         -0.5
%         0.33333          0.5
%
% }
%
% ans =
%
%           196            6

% %%
% fitting model using ridge regression

% %%
tic
bootridge(outcomes, MAT_H.X, '*', 1999, 0.05, [], Deff);
toc
ridge_coeff = ans;
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of predictors (p): 5
%
%  Number of outcomes (q): 11
%
%  Sample size: 196
%
%  Design effect (Deff): 1
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 9.17345
%
%  Predicted R-squared: 0.166 (16.6%)
%
%  Bootstrap optimized ridge tuning constant (lambda): 4.09258
%
%  Effective residual degrees of freedom (df_lambda): 191.
%
%  Residual variances (range): [0.0361, 5e+03]
%
%  Inferential degrees of freedom (df_t): 191.
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     correlation   CI_lower      CI_upper
%  1             2             +0.2103       +0.06988      +0.3426
%  1             3             +0.6805       +0.5957       +0.7502
% ...

% %%
% stability selection, rate has to be 97.5

% %%
disp (ridge_coeff.stability*100)
% Out:
%  Columns 1 through 6:
%
%           NaN          NaN          NaN          NaN          NaN          NaN
%        99.875       99.675       99.925       89.675       99.875       99.975
%        99.975       98.625       94.425       99.975       99.975       99.975
%        99.975       98.375       99.975       99.075       97.625       99.175
%        99.975       69.275       99.775       77.675       51.275       75.875
%        96.575       99.875       99.975       99.725       94.575       94.775
%
%  Columns 7 through 11:
%
%           NaN          NaN          NaN          NaN          NaN
%        99.975       89.875       99.975       94.625       99.875
%        99.975       99.975       63.675       89.425       99.975
%        75.725       55.075       96.525       94.475       65.025
%        90.575       87.425       93.475       52.225       99.725
%        60.525       57.575       86.575       95.625       73.425

% %%
ridge_coeff.BF10
% Out:
% ans =
%
%  Columns 1 through 6:
%
%           NaN          NaN          NaN          NaN          NaN          NaN
%        10.963       4.1155       24.642      0.52985       8.3064       1847.1
%         13377        1.894      0.69063       82.003       4228.5   8.2072e+05
%         714.7       1.7411        12520       2.6321       2.2824       3.0796
%        67.717       0.5605       4.9069      0.61294      0.52156      0.61523
%         2.151       5.2624        30.94       5.2453       1.3468       1.2175
%
%  Columns 7 through 11:
%
%           NaN          NaN          NaN          NaN          NaN
%    1.0522e+10      0.59499        16434      0.96973       9.2007
%    3.7878e+10   1.3968e+05      0.30449      0.56705       2730.9
%       0.42628       0.3647       1.9878      0.91528      0.38971
%       0.86401      0.99002      0.99124      0.52201       3.9389
%       0.62951      0.62386      0.89445       1.6052      0.68729

% %%
%{ 
reminder- 
1. intercept, represnts grand mean
2. G2 - G1 averaged over conditions
3. C5C6 - C4 averaged over genotypes
4. C6 - C5 averaged over genotypes
5. is [G2 -G1] different in C5C6 compared to C4
6. is [G2 -G1] different in C6 compared to C5
%}

% %%
%{ 
outcome numbers now corresponds to (after removing 8 and 13) : 
1. peak
2. afterhyp
3. amp 
4. thresh
5. half (full-width at half maximum)
6. rise 
7. fall 
8. rheobase (current it takes to reach thresh)
9. sag (IH sag)
10. RMP (resting membrane potential)
11. maxApnum
%}

% %%
% 19.13 % of posterior precision is due to prior precision

% %%
%{
1 peak :
2: coeff (-3.275), lnBF10 (+2.39) BF10 (10.963) SS (99.875)
3: coeff (-5.760), lnBF10 (+9.50) BF10 (13377) SS (99.975)
4: coeff (-5.979), lnBF10 (+6.57) BF10 (714.7) SS (99.975)
5: coeff (-6.827), lnBF10 (+4.22) BF10 (67.717) SS (99.975)

2 afterhyp :
2: coeff (+2.023), lnBF10 (+1.41) BF10 (4.1155) SS (99.675)
3: coeff (+1.703), lnBF10 (+0.639) BF10 (1.894) SS (98.625)
4: coeff (+1.939), lnBF10 (+0.555) BF10 (1.7411) SS (98.375)
6: coeff (+3.868), lnBF10 (+1.66) BF10 (5.2624) SS (99.875)

3 amp:
2: coeff (-4.492), lnBF10 (+3.20) BF10 (24.642) SS (99.925)
4: coeff (-8.750), lnBF10 (+9.44) BF10 (12520) SS (99.975)
5: coeff (-5.659), lnBF10 (+1.59) BF10 (4.9069) SS (99.775)
6: coeff (-8.971), lnBF10 (+3.43) BF10 (30.94) SS (99.975)

4 thresh:
3: coeff (-3.792), lnBF10 (+4.41) BF10 (82.003) SS (99.975)
4: coeff (+2.771), lnBF10 (+0.968) BF10 (2.6321) SS (99.075)
6: coeff (+4.909), lnBF10 (+1.66) BF10 (5.2453) SS (99.725)

5 half:
2: coeff (+0.1482), lnBF10 (+2.12) BF10 (8.3064) SS (99.875)
3: coeff (+0.2558), lnBF10 (+8.35) BF10 (4228.5) SS (99.975)
4: coeff (-0.1367), lnBF10 (+0.825) BF10 (2.2824) SS (97.625)

6 rise:
2: coeff (-0.7170), lnBF10 (+7.52) BF10 (1847.1) SS (99.975)
3: coeff (-0.9527), lnBF10 (+13.6) BF10 (8.2072e+05) SS (99.975)
4: coeff (-0.4352), lnBF10 (+1.12) BF10 (3.0796) SS (99.175)

7 fall: 
2: coeff (+0.2025), lnBF10 (+23.1) BF10 (1.0522e+10) SS (99.975)
3: coeff (+0.2093), lnBF10 (+24.4) BF10 (3.7878e+10) SS (99.975)

8 rheobase: 
3: coeff (-53.1), lnBF10 (+11.8) BF10 (1.3968e+05) SS (99.975)

9 sag: 
2: coeff (+3.693), lnBF10 (+9.71) BF10 (16434) SS (99.975)

11 maxApnum:
2: coeff (-2.083), lnBF10 (+2.22) BF10 (9.2007) SS (99.875)
3: coeff (+3.454), lnBF10 (+7.91) BF10 (2730.9) SS (99.975)
5: coeff (+2.849), lnBF10 (+1.37) BF10 (3.9389) SS (99.725)
%}

% %%
% : coeff (), lnBF10 () BF10 () SS ()

% %%
%{
2: difference between G2 and G1 averaged over conditions

strong evidence (lnBF10 = +2.39, BF10 = 10.96, SS = 99.88%) for a 3.28mV decrease in peak; 
good evidence (lnBF10 (+1.41) BF10 (4.1155) SS (99.675)) for a 2.02mV increase in afterhyperpolarisation; 
strong evidence (lnBF10 (+3.20) BF10 (24.642) SS (99.925)) for a 4.5 mV decrease in amplitude; 
strong evidence (lnBF10 (+2.12) BF10 (8.3064) SS (99.875)) for a 0.1482 ms increase width in action potential (half); 
strong evidence (lnBF10 (+7.52) BF10 (1847.1) SS (99.975)) for a 0.7 mv/ms quicker rise (depolarisation) ; 
strong evidence ( lnBF10 (+23.1) BF10 (1.0522e+10) SS (99.975)) for a 0.2 mv/ms slower repolarosation (fall); 
strong evidence (lnBF10 (+9.71) BF10 (16434) SS (99.975)) for an 3.7 mV increase in IH sag; 
and strong evidence (lnBF10 (+2.22) BF10 (9.2007) SS (99.875)) that there is a 2 Hz decrease in max action potentials; 
when comparing genotypes irrespecive of the conditions. 
This provides evidence  that APOE4 has action potentials that are smaller, wider and slower than APOE3. 
%}

% %%
%{
3: difference between conditions (C5C6 - C4) averaged over the genotypes

strong evidence (lnBF10 (+9.50) BF10 (13377) SS (99.975)) for a 5.76mV decrease in peak; 
strong evidence (lnBF10 (+4.41) BF10 (82.003) SS (99.975)) for a 3.8 mV decrease in threshold; 
strong evidence (lnBF10 (+8.35) BF10 (4228.5) SS (99.975)) for a wider ap by  0.3 ms (half); 
strong evidence ( lnBF10 (+13.6) BF10 (8.2072e+05) SS (99.975)) for a 0.95 mv/ms quicker rise(depolarisation); 
strong evidence ( lnBF10 (+24.4) BF10 (3.7878e+10) SS (99.975)) for a 0.21 mv/ms slower fall ( repolarisation); 
strong evidence (lnBF10 (+11.8) BF10 (1.3968e+05) SS (99.975)) for a -53.1 pA decrease in rheobase; 
strong evidence (lnBF10 (+7.91) BF10 (2730.9) SS (99.975)) for a 3.5 Hz increase in max action potentials; 
when comparing both a-beta conditions to control
anecdotal evidence (lnBF10 (+0.639) BF10 (1.894) SS (98.625)) for a 1.7 mV increase in afterhyperpolarisation 
                                                                        when comparing a-beta conditions to control. 
This provides evidence that a-beta can affect intrinsic membrane parameters and produce ap's that are shorter and longer; 
the faster rise and lower threshold + lower current required to reach threshold can explain the increased ap's
%}

% %%
%{
4: difference between conditions (C6 - C5) averaged over genotypes

strong evidence (lnBF10 (+6.57) BF10 (714.7) SS (99.975)) for a 6 mV decrease in peak; 
strong evidence (lnBF10 (+9.44) BF10 (12520) SS (99.975)) for a 8.8 mV decrease in amplitude; 
good evidence (lnBF10 (+1.12) BF10 (3.0796) SS (99.175)) for a 0.4 mv/ms quicker rise (depolarisation);
anecdotal evidence (lnBF10 (+0.555) BF10 (1.7411) SS (98.375)) for a 1.9 mV increase in afterhyperpolarisation; 
anecdotal evidence (lnBF10 (+0.968) BF10 (2.6321) SS (99.075)) for a 2.8 mV increase in threshold; 
anecdotal evidence (lnBF10 (+0.825) BF10 (2.2824) SS (97.625)) for a 0.14 ms narrowing of ap;
provides evidence that assembly competenent a-beta may produce shorter ap's
%}

% %%
%{
5: difference between the two genotypes (G2 - G1) different in C5C6 compared to C4

strong evidence (lnBF10 (+4.22) BF10 (67.717) SS (99.975)) that there is a 6.8 mV deacrease in peak;
good evidence (lnBF10 (+1.59) BF10 (4.9069) SS (99.775)) that there is a 5.7 mV decrease in amplitude; 
good evidence (lnBF10 (+1.37) BF10 (3.9389) SS (99.725)) that there is 2.8 Hz increase in max action potential numbers;
provides evidence that abeta can result in smaller spikes, and increased number of spikes
%}

% %%
%{
6: difference between the two genotypes (G2 - G1) different in C6 compared to C5

strong evidence (lnBF10 (+3.43) BF10 (30.94) SS (99.975)) for a 9 mV decrease in amplitude;
good evidence (lnBF10 (+1.66) BF10 (5.2624) SS (99.875)) that there is a 3.8 mv increase in afterhyperpolarisation;
good evidence (lnBF10 (+1.66) BF10 (5.2453) SS (99.725)) for a 4.9 mV increase in threshold; 
%}

% %%
% correlation for pairs of outcomes involving column 11 (max Apnum)

% %%
RTAB = ridge_coeff.RTAB;
disp(min(RTAB(:,3)));
disp(max(RTAB(:,3)));
contains_maxApnum = any (RTAB(:,1:2) == 11, 2);
RTAB(contains_maxApnum,:)
% Out:
% -0.60521
% 0.85826
% ans =
%
%             1           11      0.16885      0.02698      0.30404
%             2           11     -0.45502     -0.56114     -0.33417
%             3           11      0.53818      0.42853      0.63221
%             4           11     -0.54012     -0.63385     -0.43077
%             5           11    -0.065704     -0.20629     0.077537
%             6           11      0.57896      0.47569      0.66648
%             7           11     -0.36768      -0.4848     -0.23762
%             8           11     -0.54358     -0.63677     -0.43475
%             9           11     0.078386    -0.064854      0.21846
%            10           11     -0.14074     -0.27769    0.0018112

% %% [raw]
% pairwise correlations between outcomes ranged from -0.61 - +0.86
% with reference to maximum action potential firing rate, a negative correlation was found with afterhyperpolarisation (-0.46), threshold (-0.54), fall (repolarisation rate) (-0.37) and rheobase (-0.54). Therefore, higher maximum ap frequency rate is associated with lower rheobase, faster ap repolarisation, with lower threshold and more negative afterhyperpolarisation membrane potential.
% In contrast, maximum action potential firing frequency was positively correlated with amplitude (0.54) and rise (0.58). Therefore larger amplitude and faster depolarisation are associated with higher maximum ap firing frequency.

% %%
tic 
bootridge (outcomes, MAT_H.X, '*', 1999, 0.05, MAT_H.L, Deff);
toc
ridge_emm = ans;
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of predictors (p): 5
%
%  Number of outcomes (q): 11
%
%  Sample size: 196
%
%  Design effect (Deff): 1
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 9.17345
%
%  Predicted R-squared: 0.166 (16.6%)
%
%  Bootstrap optimized ridge tuning constant (lambda): 4.09258
%
%  Effective residual degrees of freedom (df_lambda): 191.
%
%  Residual variances (range): [0.0361, 5e+03]
%
%  Inferential degrees of freedom (df_t): 191.
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     correlation   CI_lower      CI_upper
%  1             2             +0.2103       +0.06988      +0.3426
%  1             3             +0.6805       +0.5957       +0.7502
% ...

% %%
ridge_emm
% Out:
% ridge_emm =
%
%   scalar structure containing the fields:
%
%     function = bootridge
%     estimate =
%
%      Columns 1 through 5:
%
%            48.315      -52.984       88.913      -40.598       1.5833
%            49.592      -50.564       88.218      -38.626       1.7297
%            47.942      -50.986       91.924      -43.982       1.8683
%            44.423      -51.096        90.02      -45.597        2.093
%            43.994      -50.981        87.66      -43.665       1.8072
%            36.413      -47.223       76.784      -40.371       1.8808
%
%      Columns 6 through 10:
%
%            5.0573      -1.1929       143.38       6.5702      -64.222
%            4.4556      -1.0232       144.97       9.2213      -62.988
%            4.3047      -1.0204       99.958       6.5515      -65.308
%            3.7379     -0.79624       79.604       11.468      -65.215
%            4.0774     -0.99585       99.792       5.4774      -65.119
% ...

% %%
comparisons = [2 1; 4 3; 6 5]
% Out:
% comparisons =
%
%             2            1
%             4            3
%             6            5

% %%
MAT_H_PAIRS = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', ...
                     'display', 'off', 'contrasts', MAT_H.C, 'nboot', 0, 'dim', [1,2], 'posthoc', comparisons);

% %%
tic
bootridge (outcomes, MAT_H_PAIRS.X, '*', 1999, 0.05, ...
          MAT_H_PAIRS.L, Deff);
toc
ridge_pairs = ans;
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of predictors (p): 5
%
%  Number of outcomes (q): 11
%
%  Sample size: 196
%
%  Design effect (Deff): 1
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 9.17345
%
%  Predicted R-squared: 0.166 (16.6%)
%
%  Bootstrap optimized ridge tuning constant (lambda): 4.09258
%
%  Effective residual degrees of freedom (df_lambda): 191.
%
%  Residual variances (range): [0.0361, 5e+03]
%
%  Inferential degrees of freedom (df_t): 191.
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     correlation   CI_lower      CI_upper
%  1             2             +0.2103       +0.06988      +0.3426
%  1             3             +0.6805       +0.5957       +0.7502
% ...

% %%
ridge_pairs
% Out:
% ridge_pairs =
%
%   scalar structure containing the fields:
%
%     function = bootridge
%     estimate =
%
%      Columns 1 through 5:
%
%            1.2766       2.4199     -0.69479       1.9714      0.14642
%           -3.5194     -0.10985      -1.9043      -1.6151      0.22467
%           -7.5816       3.7582      -10.876       3.2942     0.073603
%
%      Columns 6 through 10:
%
%          -0.60165      0.16971       1.5954       2.6511        1.234
%          -0.56676      0.22419      -20.354       4.9162     0.092625
%          -0.98248      0.21358      -17.675       3.5124       2.5211
%
%      Column 11:
%
%           -3.9826
%            -1.516
%          -0.75053
%
%     CI_lower =
%
%      Columns 1 through 5:
%
%           -2.1832     -0.08742      -4.9765      -1.2134    -0.016654
%           -7.1231      -2.7215      -6.3642      -4.9324     0.054812
%           -11.715      0.76244      -15.991     -0.51094     -0.12123
%
%      Columns 6 through 10:
%
% ...
