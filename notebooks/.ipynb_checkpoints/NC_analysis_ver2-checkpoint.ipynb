% %%
format short g

% %%
pkg install "https://github.com/gnu-octave/statistics-resampling/archive/refs/heads/master.zip"
% Out:
% The statistics-resampling package was installed into the directory:
% /home/jovyan/.local/share/octave/api-v58/packages/statistics-resampling-5.6.1-dev
% License and copyright information can be found at:
% https://github.com/gnu-octave/statistics-resampling/blob/master/COPYING

% %%
pkg load statistics-resampling

% %%
[~, genotype] = xlsread ('../data/abeta-cleaned-ver2.xlsx', 'abeta', 'E2:E165');
[~, condition] = xlsread ('../data/abeta-cleaned-ver2.xlsx', 'abeta', 'F2:F165');

% for cell clusters am I averaging from the same cell into one data point
% need to load animal information once it is available

outcomes = xlsread ('../data/abeta-cleaned-ver2.xlsx', 'abeta', 'G2:S165');

disp (size(genotype))
disp (size(condition))
disp (size(outcomes))
% Out:
%           164            1
%           164            1
%           164           13

% %%
% getting rid of columns now as matrix automatically removes NaN, remember that now means that the outcome numbers have shifted

% %%
if (size(outcomes, 2) > 11)
    outcomes(:,[8,13]) = [];
end

disp (size(outcomes))
% Out:
%           164           11

% %%
for i = 1: size(outcomes, 2)
    MAT_T = bootlm (outcomes(:,i), {genotype, condition}, 'model', 'full', 'display', 'on', ...
            'contrasts', 'treatment', 'nboot', 0);
    print(sprintf('../output/NC_ver2/outcome%d.png', i), '-dpng', '-r300')
end

% %%
% after looking at graphs, outlier rows are: row 2 (outcome 7)  row 130 (outcome 11) (double check)

% %%
if (size (outcomes, 1) > 162)
    genotype([2,130],:) = [];
    condition([2,130],:) = [];
    outcomes([2,130],:) = [];
    MAT_T.X([2,130],:) = [];
end

disp (size(genotype))
disp (size(condition))
disp (size(outcomes))
disp (size(MAT_T.X))
% Out:
%           162            1
%           162            1
%           162           11
%           162            6

% %%
% bayesian bootstrap summary statistics using Simple Random Sampling

% %%
STATS_SRS = bootbayes(outcomes, MAT_T.X);

% %%
% can't do cluster bootstrap sampling as of yet, assume Deff = 1

% %%
Deff = 1
% Out:
% Deff =     1

% %%
% orthogonal (helmert) contrast coding

% %%
MAT_H = bootlm (outcomes(:,11), {genotype,condition}, 'model', 'full', ...
                'display', 'off', 'contrasts', 'helmert', 'nboot', 0, 'dim', [1,2]);
MAT_H.C

MAT_H = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', ...
                'display', 'off', 'contrasts', MAT_H.C, 'nboot', 0, 'dim', [1,2]);
                
size (MAT_H.X)
% Out:
% ans =
% {
%   [1,1] =
%
%            -0.5
%             0.5
%
%   [1,2] =
%
%        -0.66667            0
%         0.33333         -0.5
%         0.33333          0.5
%
% }
%
% ans =
%
%           196            6

% %%
% fitting model using ridge regression

% %%
tic
bootridge(outcomes, MAT_H.X, '*', 1999, 0.05, [], Deff);
toc
ridge_coeff = ans;
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of predictors (p): 5
%
%  Number of outcomes (q): 11
%
%  Sample size: 196
%
%  Design effect (Deff): 1
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 9.17345
%
%  Predicted R-squared: 0.166 (16.6%)
%
%  Bootstrap optimized ridge tuning constant (lambda): 4.09258
%
%  Effective residual degrees of freedom (df_lambda): 191.
%
%  Residual variances (range): [0.0361, 5e+03]
%
%  Inferential degrees of freedom (df_t): 191.
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     correlation   CI_lower      CI_upper
%  1             2             +0.2103       +0.06988      +0.3426
%  1             3             +0.6805       +0.5957       +0.7502
%  1             4             +0.1715       +0.02973      +0.3065
%  1             5             -0.2839       -0.4098       -0.1473
%  1             6             +0.6313       +0.5371       +0.7099
%  1             7             -0.4957       -0.5961       -0.3801
%  1             8             +0.06130      -0.08193      +0.2021
%  1             9             -0.04742      -0.1887       +0.09574
%  1             10            +0.1554       +0.01316      +0.2914
%  1             11            +0.1688       +0.02698      +0.3040
%  2             3             -0.4340       -0.5429       -0.3107
%  2             4             +0.8119       +0.7570       +0.8555
%  2             5             -0.01354      -0.1558       +0.1292
%  2             6             -0.3791       -0.4949       -0.2501
%  2             7             +0.3495       +0.2178       +0.4687
%  2             8             +0.2661       +0.1285       +0.3937
%  2             9             -0.1479       -0.2844       -0.005488
%  2             10            +0.4483       +0.3266       +0.5553
%  2             11            -0.4550       -0.5611       -0.3342
%  3             4             -0.6052       -0.6884       -0.5064
%  3             5             -0.1526       -0.2888       -0.01028
%  3             6             +0.8583       +0.8155       +0.8917
%  3             7             -0.5510       -0.6430       -0.4433
%  3             8             -0.2857       -0.4115       -0.1493
%  3             9             -0.06293      -0.2036       +0.08030
%  3             10            -0.2172       -0.3489       -0.07709
%  3             11            +0.5382       +0.4285       +0.6322
%  4             5             -0.1033       -0.2422       +0.03985
%  4             6             -0.4681       -0.5724       -0.3488
%  4             7             +0.2023       +0.06154      +0.3351
%  4             8             +0.4507       +0.3293       +0.5574
%  4             9             +0.03309      -0.1099       +0.1748
%  4             10            +0.4608       +0.3407       +0.5662
%  4             11            -0.5401       -0.6338       -0.4308
%  5             6             -0.2352       -0.3655       -0.09593
%  5             7             +0.4223       +0.2977       +0.5328
%  5             8             -0.07735      -0.2175       +0.06590
%  5             9             +0.005607     -0.1370       +0.1480
%  5             10            -0.01208      -0.1543       +0.1307
%  5             11            -0.06570      -0.2063       +0.07754
%  6             7             -0.5599       -0.6505       -0.4536
%  6             8             -0.1935       -0.3270       -0.05245
%  6             9             +0.003693     -0.1389       +0.1461
%  6             10            -0.2484       -0.3776       -0.1098
%  6             11            +0.5790       +0.4757       +0.6665
%  7             8             +0.06329      -0.07994      +0.2040
%  7             9             -0.05546      -0.1964       +0.08775
%  7             10            -0.0007694     -0.1433       +0.1418
%  7             11            -0.3677       -0.4848       -0.2376
%  8             9             +0.05481      -0.08840      +0.1958
%  8             10            -0.1938       -0.3273       -0.05273
%  8             11            -0.5436       -0.6368       -0.4347
%  9             10            -0.1234       -0.2613       +0.01947
%  9             11            +0.07839      -0.06485      +0.2185
%  10            11            -0.1407       -0.2777       +0.001811
%
%  95% credible intervals and Bayes factors for regression coefficients.
%  Global ridge prior contribution to posterior precision: 19.13 %
%  Stability selection (SS): >97.5% for the (-) or (+) sign of the coefficient.
%  SS probabilities are reported in S.stability
%
%  Outcome 1:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +45.11        +43.87        +46.35        +NaN          U (-Inf, Inf)
%  -3.275        -5.655        -0.8942       +2.39     (-) t (0, 4.15, 191.)
%  -5.760        -8.151        -3.370        +9.50     (-) t (0, 4.15, 191.)
%  -5.979        -8.955        -3.003        +6.57     (-) t (0, 4.15, 191.)
%  -6.827        -11.10        -2.554        +4.22     (-) t (0, 4.15, 191.)
%  -4.062        -9.136        +1.011        +0.766        t (0, 4.15, 191.)
%
%  Outcome 2:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  -50.64        -51.54        -49.74        +NaN          U (-Inf, Inf)
%  +2.023        +0.2975       +3.748        +1.41     (+) t (0, 3.01, 191.)
%  +1.703        -0.02963      +3.435        +0.639    (+) t (0, 3.01, 191.)
%  +1.939        -0.2179       +4.096        +0.555    (+) t (0, 3.01, 191.)
%  -0.5958       -3.692        +2.501        -0.579        t (0, 3.01, 191.)
%  +3.868        +0.1912       +7.545        +1.66     (+) t (0, 3.01, 191.)
%
%  Outcome 3:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +87.25        +85.72        +88.79        +NaN          U (-Inf, Inf)
%  -4.492        -7.438        -1.545        +3.20     (-) t (0, 5.14, 191.)
%  -1.968        -4.927        +0.9898       -0.370        t (0, 5.14, 191.)
%  -8.750        -12.43        -5.067        +9.44     (-) t (0, 5.14, 191.)
%  -5.695        -10.98        -0.4073       +1.59     (-) t (0, 5.14, 191.)
%  -8.971        -15.25        -2.693        +3.43     (-) t (0, 5.14, 191.)
%
%  Outcome 4:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  -42.14        -43.28        -41.00        +NaN          U (-Inf, Inf)
%  +1.217        -0.9746       +3.408        -0.635        t (0, 3.82, 191.)
%  -3.792        -5.992        -1.592        +4.41     (-) t (0, 3.82, 191.)
%  +2.771        +0.03193      +5.511        +0.968    (+) t (0, 3.82, 191.)
%  -1.132        -5.065        +2.801        -0.489        t (0, 3.82, 191.)
%  +4.909        +0.2391       +9.579        +1.66     (+) t (0, 3.82, 191.)
%
%  Outcome 5:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +1.827        +1.769        +1.885        +NaN          U (-Inf, Inf)
%  +0.1482       +0.03602      +0.2604       +2.12     (+) t (0, 0.196, 191.)
%  +0.2558       +0.1431       +0.3684       +8.35     (+) t (0, 0.196, 191.)
%  -0.1367       -0.2769       +0.003618     +0.825    (-) t (0, 0.196, 191.)
%  +0.002719     -0.1987       +0.2041       -0.651        t (0, 0.196, 191.)
%  -0.1511       -0.3902       +0.08807      +0.298        t (0, 0.196, 191.)
%
%  Outcome 6:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +4.121        +3.949        +4.294        +NaN          U (-Inf, Inf)
%  -0.7170       -1.048        -0.3859       +7.52     (-) t (0, 0.578, 191.)
%  -0.9527       -1.285        -0.6203       +13.6     (-) t (0, 0.578, 191.)
%  -0.4352       -0.8491       -0.02128      +1.12     (-) t (0, 0.578, 191.)
%  -0.1730       -0.7672       +0.4213       -0.486        t (0, 0.578, 191.)
%  -0.4157       -1.121        +0.2899       +0.197        t (0, 0.578, 191.)
%
%  Outcome 7:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  -0.9685       -0.9965       -0.9405       +NaN          U (-Inf, Inf)
%  +0.2025       +0.1487       +0.2563       +23.1     (+) t (0, 0.0940, 191.)
%  +0.2093       +0.1553       +0.2634       +24.4     (+) t (0, 0.0940, 191.)
%  +0.01928      -0.04802      +0.08657      -0.853        t (0, 0.0940, 191.)
%  +0.04917      -0.04745      +0.1458       -0.146        t (0, 0.0940, 191.)
%  -0.01061      -0.1253       +0.1041       -0.463        t (0, 0.0940, 191.)
%
%  Outcome 8:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +108.3        +97.89        +118.7        +NaN          U (-Inf, Inf)
%  -12.14        -32.16        +7.874        -0.519        t (0, 34.9, 191.)
%  -53.81        -73.91        -33.71        +11.8     (-) t (0, 34.9, 191.)
%  +1.173        -23.85        +26.20        -1.01         t (0, 34.9, 191.)
%  -20.61        -56.54        +15.32        -0.0100       t (0, 34.9, 191.)
%  +2.679        -39.98        +45.34        -0.472        t (0, 34.9, 191.)
%
%  Outcome 9:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +8.046        +7.257        +8.835        +NaN          U (-Inf, Inf)
%  +3.693        +2.176        +5.210        +9.71     (+) t (0, 2.65, 191.)
%  +0.2259       -1.297        +1.749        -1.19         t (0, 2.65, 191.)
%  -1.776        -3.672        +0.1204       +0.687        t (0, 2.65, 191.)
%  +1.563        -1.159        +4.286        -0.00880      t (0, 2.65, 191.)
%  -1.404        -4.636        +1.829        -0.112        t (0, 2.65, 191.)
%
%  Outcome 10:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  -64.24        -65.09        -63.39        +NaN          U (-Inf, Inf)
%  +1.283        -0.3459       +2.911        -0.0307       t (0, 2.84, 191.)
%  -0.9550       -2.590        +0.6801       -0.567        t (0, 2.84, 191.)
%  +1.403        -0.6326       +3.439        -0.0885       t (0, 2.84, 191.)
%  +0.07280      -2.850        +2.996        -0.650        t (0, 2.84, 191.)
%  +2.428        -1.042        +5.899        +0.473        t (0, 2.84, 191.)
%
%  Outcome 11:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +12.34        +11.54        +13.15        +NaN          U (-Inf, Inf)
%  -2.083        -3.636        -0.5301       +2.22     (-) t (0, 2.71, 191.)
%  +3.454        +1.895        +5.013        +7.91     (+) t (0, 2.71, 191.)
%  +0.3690       -1.572        +2.310        -0.942        t (0, 2.71, 191.)
%  +2.849        +0.06213      +5.637        +1.37     (+) t (0, 2.71, 191.)
%  +0.7654       -2.544        +4.075        -0.375        t (0, 2.71, 191.)
%
% Elapsed time is 158.256 seconds.

% %%
% stability selection, rate has to be 97.5

% %%
disp (ridge_coeff.stability*100)
% Out:
%  Columns 1 through 6:
%
%           NaN          NaN          NaN          NaN          NaN          NaN
%        99.875       99.675       99.925       89.675       99.875       99.975
%        99.975       98.625       94.425       99.975       99.975       99.975
%        99.975       98.375       99.975       99.075       97.625       99.175
%        99.975       69.275       99.775       77.675       51.275       75.875
%        96.575       99.875       99.975       99.725       94.575       94.775
%
%  Columns 7 through 11:
%
%           NaN          NaN          NaN          NaN          NaN
%        99.975       89.875       99.975       94.625       99.875
%        99.975       99.975       63.675       89.425       99.975
%        75.725       55.075       96.525       94.475       65.025
%        90.575       87.425       93.475       52.225       99.725
%        60.525       57.575       86.575       95.625       73.425

% %%
ridge_coeff.BF10
% Out:
% ans =
%
%  Columns 1 through 6:
%
%           NaN          NaN          NaN          NaN          NaN          NaN
%        10.963       4.1155       24.642      0.52985       8.3064       1847.1
%         13377        1.894      0.69063       82.003       4228.5   8.2072e+05
%         714.7       1.7411        12520       2.6321       2.2824       3.0796
%        67.717       0.5605       4.9069      0.61294      0.52156      0.61523
%         2.151       5.2624        30.94       5.2453       1.3468       1.2175
%
%  Columns 7 through 11:
%
%           NaN          NaN          NaN          NaN          NaN
%    1.0522e+10      0.59499        16434      0.96973       9.2007
%    3.7878e+10   1.3968e+05      0.30449      0.56705       2730.9
%       0.42628       0.3647       1.9878      0.91528      0.38971
%       0.86401      0.99002      0.99124      0.52201       3.9389
%       0.62951      0.62386      0.89445       1.6052      0.68729

% %%
reminder- 
1. intercept, represnts grand mean
2. G2 - G1 averaged over conditions
3. C5C6 - C4 averaged over genotypes
4. C6 - C5 averaged over genotypes
5. is [G2 -G1] different in C5C6 compared to C4
6. is [G2 -G1] different in C6 compared to C5
% Out:
% error: parse error:
%
%   syntax error
%
% >>> reminder-
%              ^
% error: parse error:
%
%   syntax error
%
% >>> 1. intercept, represnts grand mean
%                ^
% error: parse error:
%
%   syntax error
%
% >>> 2. G2 - G1 averaged over conditions
%         ^
% error: parse error:
%
%   syntax error
%
% >>> 3. C5C6 - C4 averaged over genotypes
%           ^
% error: parse error:
%
%   syntax error
%
% >>> 4. C6 - C5 averaged over genotypes
%         ^
% error: parse error:
%
%   syntax error
%
% >>> 5. is [G2 -G1] different in C5C6 compared to C4
%         ^
% error: parse error:
%
%   syntax error
%
% >>> 6. is [G2 -G1] different in C6 compared to C5
%         ^

% %%
outcome numbers now corresponds to (after removing 8 and 13) : 
1. peak
2. afterhyp
3. amp 
4. thresh
5. half (full-width at half maximum)
6. rise 
7. fall 
8. rheobase (current it takes to reach thresh)
9. sag (IH sag)
10. RMP (resting membrane potential)
11. maxApnum
% Out:
% error: 'outcome' undefined near line 1, column 1
% error: parse error:
%
%   syntax error
%
% >>> 1. peak
%           ^
% error: parse error:
%
%   syntax error
%
% >>> 2. afterhyp
%               ^
% error: parse error:
%
%   syntax error
%
% >>> 3. amp
%          ^
% error: parse error:
%
%   syntax error
%
% >>> 4. thresh
%             ^
% error: parse error:
%
%   syntax error
%
% >>> 5. half (full-width at half maximum)
%           ^
% error: parse error:
%
%   syntax error
%
% >>> 6. rise
%           ^
% error: parse error:
%
%   syntax error
%
% >>> 7. fall
%           ^
% error: parse error:
%
%   syntax error
%
% >>> 8. rheobase (current it takes to reach thresh)
%               ^
% error: parse error:
%
%   syntax error
%
% >>> 9. sag (IH sag)
%          ^
% error: parse error:
%
%   syntax error
%
% >>> 10. RMP (resting membrane potential)
%           ^
% error: parse error:
%
%   syntax error
%
% >>> 11. maxApnum
%                ^

% %%
19.13 % of posterior precision is due to prior precision
% Out:
% ans = 19.13

% %%
: coeff (), lnBF10 () BF10 () SS ()
% Out:
% error: parse error:
%
%   syntax error
%
% >>> : coeff (), lnBF10 () BF10 () SS ()
%     ^

% %%
% correlation for pairs of outcomes involving column 11 (max Apnum)

% %%
RTAB = ridge_coeff.RTAB;
disp(min(RTAB(:,3)));
disp(max(RTAB(:,3)));
contains_maxApnum = any (RTAB(:,1:2) == 11, 2);
RTAB(contains_maxApnum,:)
% Out:
% -0.60521
% 0.85826
% ans =
%
%             1           11      0.16885      0.02698      0.30404
%             2           11     -0.45502     -0.56114     -0.33417
%             3           11      0.53818      0.42853      0.63221
%             4           11     -0.54012     -0.63385     -0.43077
%             5           11    -0.065704     -0.20629     0.077537
%             6           11      0.57896      0.47569      0.66648
%             7           11     -0.36768      -0.4848     -0.23762
%             8           11     -0.54358     -0.63677     -0.43475
%             9           11     0.078386    -0.064854      0.21846
%            10           11     -0.14074     -0.27769    0.0018112

% %%
tic 
bootridge (outcomes, MAT_H.X, '*', 1999, 0.05, MAT_H.L, Deff);
toc
ridge_emm = ans;
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of predictors (p): 5
%
%  Number of outcomes (q): 11
%
%  Sample size: 196
%
%  Design effect (Deff): 1
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 9.17345
%
%  Predicted R-squared: 0.166 (16.6%)
%
%  Bootstrap optimized ridge tuning constant (lambda): 4.09258
%
%  Effective residual degrees of freedom (df_lambda): 191.
%
%  Residual variances (range): [0.0361, 5e+03]
%
%  Inferential degrees of freedom (df_t): 191.
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     correlation   CI_lower      CI_upper
%  1             2             +0.2103       +0.06988      +0.3426
%  1             3             +0.6805       +0.5957       +0.7502
%  1             4             +0.1715       +0.02973      +0.3065
%  1             5             -0.2839       -0.4098       -0.1473
%  1             6             +0.6313       +0.5371       +0.7099
%  1             7             -0.4957       -0.5961       -0.3801
%  1             8             +0.06130      -0.08193      +0.2021
%  1             9             -0.04742      -0.1887       +0.09574
%  1             10            +0.1554       +0.01316      +0.2914
%  1             11            +0.1688       +0.02698      +0.3040
%  2             3             -0.4340       -0.5429       -0.3107
%  2             4             +0.8119       +0.7570       +0.8555
%  2             5             -0.01354      -0.1558       +0.1292
%  2             6             -0.3791       -0.4949       -0.2501
%  2             7             +0.3495       +0.2178       +0.4687
%  2             8             +0.2661       +0.1285       +0.3937
%  2             9             -0.1479       -0.2844       -0.005488
%  2             10            +0.4483       +0.3266       +0.5553
%  2             11            -0.4550       -0.5611       -0.3342
%  3             4             -0.6052       -0.6884       -0.5064
%  3             5             -0.1526       -0.2888       -0.01028
%  3             6             +0.8583       +0.8155       +0.8917
%  3             7             -0.5510       -0.6430       -0.4433
%  3             8             -0.2857       -0.4115       -0.1493
%  3             9             -0.06293      -0.2036       +0.08030
%  3             10            -0.2172       -0.3489       -0.07709
%  3             11            +0.5382       +0.4285       +0.6322
%  4             5             -0.1033       -0.2422       +0.03985
%  4             6             -0.4681       -0.5724       -0.3488
%  4             7             +0.2023       +0.06154      +0.3351
%  4             8             +0.4507       +0.3293       +0.5574
%  4             9             +0.03309      -0.1099       +0.1748
%  4             10            +0.4608       +0.3407       +0.5662
%  4             11            -0.5401       -0.6338       -0.4308
%  5             6             -0.2352       -0.3655       -0.09593
%  5             7             +0.4223       +0.2977       +0.5328
%  5             8             -0.07735      -0.2175       +0.06590
%  5             9             +0.005607     -0.1370       +0.1480
%  5             10            -0.01208      -0.1543       +0.1307
%  5             11            -0.06570      -0.2063       +0.07754
%  6             7             -0.5599       -0.6505       -0.4536
%  6             8             -0.1935       -0.3270       -0.05245
%  6             9             +0.003693     -0.1389       +0.1461
%  6             10            -0.2484       -0.3776       -0.1098
%  6             11            +0.5790       +0.4757       +0.6665
%  7             8             +0.06329      -0.07994      +0.2040
%  7             9             -0.05546      -0.1964       +0.08775
%  7             10            -0.0007694     -0.1433       +0.1418
%  7             11            -0.3677       -0.4848       -0.2376
%  8             9             +0.05481      -0.08840      +0.1958
%  8             10            -0.1938       -0.3273       -0.05273
%  8             11            -0.5436       -0.6368       -0.4347
%  9             10            -0.1234       -0.2613       +0.01947
%  9             11            +0.07839      -0.06485      +0.2185
%  10            11            -0.1407       -0.2777       +0.001811
%
%  95% credible intervals and Bayes factors for linear estimates.
%  Global ridge prior contribution to posterior precision: 19.13 %
%
%  Outcome 1:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +48.32        +46.01        +50.62        +NaN          U (-Inf, Inf)
%  +49.59        +46.83        +52.35        +NaN          U (-Inf, Inf)
%  +47.94        +45.17        +50.71        +NaN          U (-Inf, Inf)
%  +44.42        +41.83        +47.01        +NaN          U (-Inf, Inf)
%  +43.99        +40.38        +47.61        +NaN          U (-Inf, Inf)
%  +36.41        +33.90        +38.92        +NaN          U (-Inf, Inf)
%
%  Outcome 2:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -52.98        -54.65        -51.32        +NaN          U (-Inf, Inf)
%  -50.56        -52.56        -48.56        +NaN          U (-Inf, Inf)
%  -50.99        -52.99        -48.98        +NaN          U (-Inf, Inf)
%  -51.10        -52.97        -49.22        +NaN          U (-Inf, Inf)
%  -50.98        -53.60        -48.36        +NaN          U (-Inf, Inf)
%  -47.22        -49.04        -45.40        +NaN          U (-Inf, Inf)
%
%  Outcome 3:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +88.91        +86.06        +91.76        +NaN          U (-Inf, Inf)
%  +88.22        +84.80        +91.63        +NaN          U (-Inf, Inf)
%  +91.92        +88.49        +95.35        +NaN          U (-Inf, Inf)
%  +90.02        +86.81        +93.23        +NaN          U (-Inf, Inf)
%  +87.66        +83.18        +92.14        +NaN          U (-Inf, Inf)
%  +76.78        +73.68        +79.89        +NaN          U (-Inf, Inf)
%
%  Outcome 4:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -40.60        -42.72        -38.48        +NaN          U (-Inf, Inf)
%  -38.63        -41.17        -36.09        +NaN          U (-Inf, Inf)
%  -43.98        -46.53        -41.43        +NaN          U (-Inf, Inf)
%  -45.60        -47.98        -43.21        +NaN          U (-Inf, Inf)
%  -43.67        -46.99        -40.34        +NaN          U (-Inf, Inf)
%  -40.37        -42.68        -38.06        +NaN          U (-Inf, Inf)
%
%  Outcome 5:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +1.583        +1.475        +1.692        +NaN          U (-Inf, Inf)
%  +1.730        +1.600        +1.860        +NaN          U (-Inf, Inf)
%  +1.868        +1.738        +1.999        +NaN          U (-Inf, Inf)
%  +2.093        +1.971        +2.215        +NaN          U (-Inf, Inf)
%  +1.807        +1.637        +1.978        +NaN          U (-Inf, Inf)
%  +1.881        +1.762        +1.999        +NaN          U (-Inf, Inf)
%
%  Outcome 6:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +5.057        +4.737        +5.377        +NaN          U (-Inf, Inf)
%  +4.456        +4.072        +4.840        +NaN          U (-Inf, Inf)
%  +4.305        +3.919        +4.690        +NaN          U (-Inf, Inf)
%  +3.738        +3.377        +4.098        +NaN          U (-Inf, Inf)
%  +4.077        +3.574        +4.580        +NaN          U (-Inf, Inf)
%  +3.095        +2.746        +3.444        +NaN          U (-Inf, Inf)
%
%  Outcome 7:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -1.193        -1.245        -1.141        +NaN          U (-Inf, Inf)
%  -1.023        -1.086        -0.9607       +NaN          U (-Inf, Inf)
%  -1.020        -1.083        -0.9578       +NaN          U (-Inf, Inf)
%  -0.7962       -0.8548       -0.7376       +NaN          U (-Inf, Inf)
%  -0.9958       -1.078        -0.9141       +NaN          U (-Inf, Inf)
%  -0.7823       -0.8390       -0.7255       +NaN          U (-Inf, Inf)
%
%  Outcome 8:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +143.4        +124.0        +162.7        +NaN          U (-Inf, Inf)
%  +145.0        +121.8        +168.2        +NaN          U (-Inf, Inf)
%  +99.96        +76.66        +123.3        +NaN          U (-Inf, Inf)
%  +79.60        +57.81        +101.4        +NaN          U (-Inf, Inf)
%  +99.79        +69.38        +130.2        +NaN          U (-Inf, Inf)
%  +82.12        +61.01        +103.2        +NaN          U (-Inf, Inf)
%
%  Outcome 9:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +6.570        +5.103        +8.037        +NaN          U (-Inf, Inf)
%  +9.221        +7.462        +10.98        +NaN          U (-Inf, Inf)
%  +6.551        +4.786        +8.317        +NaN          U (-Inf, Inf)
%  +11.47        +9.816        +13.12        +NaN          U (-Inf, Inf)
%  +5.477        +3.173        +7.782        +NaN          U (-Inf, Inf)
%  +8.990        +7.391        +10.59        +NaN          U (-Inf, Inf)
%
%  Outcome 10:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -64.22        -65.80        -62.65        +NaN          U (-Inf, Inf)
%  -62.99        -64.88        -61.10        +NaN          U (-Inf, Inf)
%  -65.31        -67.20        -63.41        +NaN          U (-Inf, Inf)
%  -65.22        -66.99        -63.44        +NaN          U (-Inf, Inf)
%  -65.12        -67.59        -62.65        +NaN          U (-Inf, Inf)
%  -62.60        -64.31        -60.88        +NaN          U (-Inf, Inf)
%
%  Outcome 11:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +12.03        +10.53        +13.53        +NaN          U (-Inf, Inf)
%  +8.051        +6.250        +9.851        +NaN          U (-Inf, Inf)
%  +14.07        +12.26        +15.88        +NaN          U (-Inf, Inf)
%  +12.55        +10.86        +14.24        +NaN          U (-Inf, Inf)
%  +14.06        +11.70        +16.41        +NaN          U (-Inf, Inf)
%  +13.30        +11.67        +14.94        +NaN          U (-Inf, Inf)
%
% Elapsed time is 205.835 seconds.

% %%
ridge_emm
% Out:
% ridge_emm =
%
%   scalar structure containing the fields:
%
%     function = bootridge
%     estimate =
%
%      Columns 1 through 5:
%
%            48.315      -52.984       88.913      -40.598       1.5833
%            49.592      -50.564       88.218      -38.626       1.7297
%            47.942      -50.986       91.924      -43.982       1.8683
%            44.423      -51.096        90.02      -45.597        2.093
%            43.994      -50.981        87.66      -43.665       1.8072
%            36.413      -47.223       76.784      -40.371       1.8808
%
%      Columns 6 through 10:
%
%            5.0573      -1.1929       143.38       6.5702      -64.222
%            4.4556      -1.0232       144.97       9.2213      -62.988
%            4.3047      -1.0204       99.958       6.5515      -65.308
%            3.7379     -0.79624       79.604       11.468      -65.215
%            4.0774     -0.99585       99.792       5.4774      -65.119
%            3.0949     -0.78227       82.117       8.9898      -62.598
%
%      Column 11:
%
%            12.033
%            8.0507
%            14.069
%            12.553
%            14.056
%            13.305
%
%     CI_lower =
%
%      Columns 1 through 5:
%
%            46.013      -54.652       86.064      -42.717       1.4748
%            46.831      -52.564       84.802      -41.167       1.5996
%            45.171      -52.994       88.495      -46.533       1.7377
%            41.831      -52.974       86.812      -47.983       1.9708
%            40.377      -53.602       83.183      -46.995       1.6367
%            33.903      -49.041       73.678      -42.681       1.7625
%
%      Columns 6 through 10:
%
%            4.7371      -1.2449       124.02       5.1034      -65.797
%            4.0717      -1.0856       121.76       7.4623      -64.876
%            3.9193      -1.0831       76.656       4.7858      -67.203
%            3.3775     -0.85485       57.809       9.8161      -66.988
%            3.5743      -1.0776       69.376       3.1727      -67.593
%            2.7459     -0.83902       61.012       7.3907      -64.315
%
%      Column 11:
%
%            10.532
%            6.2499
%            12.262
%            10.863
%            11.696
%            11.668
%
%     CI_upper =
%
%      Columns 1 through 5:
%
%            50.617      -51.316       91.761      -38.479       1.6918
%            52.352      -48.563       91.634      -36.085       1.8599
%            50.713      -48.977       95.354      -41.431       1.9989
%            47.014      -49.217       93.227      -43.211       2.2151
%            47.611      -48.359       92.136      -40.336       1.9776
%            38.922      -45.404        79.89      -38.061       1.9991
%
%      Columns 6 through 10:
%
%            5.3774      -1.1408       162.73       8.0369      -62.648
%            4.8396     -0.96073       168.18        10.98        -61.1
%            4.6901     -0.95777       123.26       8.3172      -63.412
%            4.0984     -0.73763        101.4       13.119      -63.442
%            4.5804     -0.91406       130.21       7.7821      -62.645
%             3.444     -0.72552       103.22       10.589      -60.881
%
%      Column 11:
%
%            13.535
%            9.8514
%            15.877
%            14.244
%            16.415
%            14.942
%
%     BF10 =
%
%      Columns 1 through 5:
%
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%
%      Columns 6 through 10:
%
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%
%      Column 11:
%
%               NaN
%               NaN
%               NaN
%               NaN
%               NaN
%               NaN
%
%     lnBF10 =
%
%      Columns 1 through 5:
%
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%
%      Columns 6 through 10:
%
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%               NaN          NaN          NaN          NaN          NaN
%
%      Column 11:
%
%               NaN
%               NaN
%               NaN
%               NaN
%               NaN
%               NaN
%
%     prior =
%     {
%       [1,1] = U (-Inf, Inf)
%       [2,1] = U (-Inf, Inf)
%       [3,1] = U (-Inf, Inf)
%       [4,1] = U (-Inf, Inf)
%       [5,1] = U (-Inf, Inf)
%       [6,1] = U (-Inf, Inf)
%       [1,2] = U (-Inf, Inf)
%       [2,2] = U (-Inf, Inf)
%       [3,2] = U (-Inf, Inf)
%       [4,2] = U (-Inf, Inf)
%       [5,2] = U (-Inf, Inf)
%       [6,2] = U (-Inf, Inf)
%       [1,3] = U (-Inf, Inf)
%       [2,3] = U (-Inf, Inf)
%       [3,3] = U (-Inf, Inf)
%       [4,3] = U (-Inf, Inf)
%       [5,3] = U (-Inf, Inf)
%       [6,3] = U (-Inf, Inf)
%       [1,4] = U (-Inf, Inf)
%       [2,4] = U (-Inf, Inf)
%       [3,4] = U (-Inf, Inf)
%       [4,4] = U (-Inf, Inf)
%       [5,4] = U (-Inf, Inf)
%       [6,4] = U (-Inf, Inf)
%       [1,5] = U (-Inf, Inf)
%       [2,5] = U (-Inf, Inf)
%       [3,5] = U (-Inf, Inf)
%       [4,5] = U (-Inf, Inf)
%       [5,5] = U (-Inf, Inf)
%       [6,5] = U (-Inf, Inf)
%       [1,6] = U (-Inf, Inf)
%       [2,6] = U (-Inf, Inf)
%       [3,6] = U (-Inf, Inf)
%       [4,6] = U (-Inf, Inf)
%       [5,6] = U (-Inf, Inf)
%       [6,6] = U (-Inf, Inf)
%       [1,7] = U (-Inf, Inf)
%       [2,7] = U (-Inf, Inf)
%       [3,7] = U (-Inf, Inf)
%       [4,7] = U (-Inf, Inf)
%       [5,7] = U (-Inf, Inf)
%       [6,7] = U (-Inf, Inf)
%       [1,8] = U (-Inf, Inf)
%       [2,8] = U (-Inf, Inf)
%       [3,8] = U (-Inf, Inf)
%       [4,8] = U (-Inf, Inf)
%       [5,8] = U (-Inf, Inf)
%       [6,8] = U (-Inf, Inf)
%       [1,9] = U (-Inf, Inf)
%       [2,9] = U (-Inf, Inf)
%       [3,9] = U (-Inf, Inf)
%       [4,9] = U (-Inf, Inf)
%       [5,9] = U (-Inf, Inf)
%       [6,9] = U (-Inf, Inf)
%       [1,10] = U (-Inf, Inf)
%       [2,10] = U (-Inf, Inf)
%       [3,10] = U (-Inf, Inf)
%       [4,10] = U (-Inf, Inf)
%       [5,10] = U (-Inf, Inf)
%       [6,10] = U (-Inf, Inf)
%       [1,11] = U (-Inf, Inf)
%       [2,11] = U (-Inf, Inf)
%       [3,11] = U (-Inf, Inf)
%       [4,11] = U (-Inf, Inf)
%       [5,11] = U (-Inf, Inf)
%       [6,11] = U (-Inf, Inf)
%     }
%
%     Deff =     1
%     lambda = 4.0926
%     df_lambda = 190.96
%     df_t = 190.96
%     Sigma_Y_hat =
%
%      Columns 1 through 5:
%
%             70.65       10.768       59.496       11.155     -0.94525
%            10.768       37.107        -27.5       38.268    -0.032678
%            59.496        -27.5       108.21       -48.71     -0.62875
%            11.155       38.268       -48.71       59.865      -0.3165
%          -0.94525    -0.032678     -0.62875      -0.3165      0.15696
%            6.2031      -2.6996       10.437      -4.2335     -0.10894
%          -0.79195      0.40462      -1.0894      0.29747     0.031799
%            36.419       114.58      -210.05       246.47      -2.1659
%           -2.1349      -4.8249      -3.5062       1.3713     0.011897
%            7.5094         15.7      -12.992       20.501    -0.027508
%            7.7815      -15.197       30.695      -22.914     -0.14272
%
%      Columns 6 through 10:
%
%                 1            4      0.17152     0.029732      0.30654
%                 1            5     -0.28386     -0.40979      -0.1473
%                 1            6       0.6313      0.53711      0.70994
%                 1            7     -0.49573     -0.59613     -0.38006
%                 1            8     0.061301    -0.081931      0.20205
%                 1            9    -0.047424     -0.18866     0.095739
%                 1           10      0.15539     0.013163      0.29145
%                 1           11      0.16885      0.02698      0.30404
%                 2            3     -0.43398     -0.54292     -0.31068
%                 2            4      0.81193        0.757      0.85545
%                 2            5    -0.013541     -0.15576      0.12922
%                 2            6     -0.37911     -0.49489     -0.25011
%                 2            7      0.34948      0.21781      0.46865
%                 2            8      0.26613      0.12848      0.39371
%                 2            9     -0.14789     -0.28441   -0.0054881
%                 2           10      0.44828      0.32664      0.55532
%                 2           11     -0.45502     -0.56114     -0.33417
%                 3            4     -0.60521     -0.68836     -0.50637
%                 3            5     -0.15257      -0.2888    -0.010276
%                 3            6      0.85826       0.8155      0.89171
%                 3            7     -0.55102     -0.64304     -0.44332
%                 3            8     -0.28569     -0.41145     -0.14925
%                 3            9    -0.062934     -0.20362     0.080302
%                 3           10     -0.21722     -0.34894    -0.077093
%                 3           11      0.53818      0.42853      0.63221
%                 4            5     -0.10325      -0.2422     0.039851
%                 4            6     -0.46806      -0.5724     -0.34881
%                 4            7      0.20228     0.061541      0.33514
%                 4            8      0.45069      0.32932       0.5574
%                 4            9     0.033091     -0.10994      0.17478
%                 4           10      0.46085      0.34071      0.56618
%                 4           11     -0.54012     -0.63385     -0.43077
%                 5            6     -0.23523     -0.36549    -0.095929
%                 5            7       0.4223       0.2977      0.53275
%                 5            8    -0.077347     -0.21746     0.065895
%                 5            9    0.0056067     -0.13702        0.148
%                 5           10    -0.012077     -0.15433      0.13066
%                 5           11    -0.065704     -0.20629     0.077537
%                 6            7     -0.55991     -0.65052     -0.45359
%                 6            8     -0.19352     -0.32702    -0.052454
%                 6            9    0.0036927      -0.1389      0.14613
%                 6           10     -0.24843     -0.37758     -0.10981
%                 6           11      0.57896      0.47569      0.66648
%                 7            8     0.063294    -0.079942      0.20397
%                 7            9    -0.055458     -0.19642     0.087751
%                 7           10  -0.00076936     -0.14327      0.14176
%                 7           11     -0.36768      -0.4848     -0.23762
%                 8            9     0.054809    -0.088397      0.19579
%                 8           10     -0.19379     -0.32726    -0.052727
%                 8           11     -0.54358     -0.63677     -0.43475
%                 9           10     -0.12339     -0.26131     0.019472
%                 9           11     0.078386    -0.064854      0.21846
%                10           11     -0.14074     -0.27769    0.0018112
%
%     P_vec =
%
%                 0
%                 1
%                 1
%                 1
%                 1
%                 1

% %%
comparisons = [2 1; 4 3; 6 5]
% Out:
% comparisons =
%
%             2            1
%             4            3
%             6            5

% %%
MAT_H_PAIRS = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', ...
                     'display', 'off', 'contrasts', MAT_H.C, 'nboot', 0, 'dim', [1,2], 'posthoc', comparisons);

% %%
tic
bootridge (outcomes, MAT_H_PAIRS.X, '*', 1999, 0.05, ...
          MAT_H_PAIRS.L, Deff);
toc
ridge_pairs = ans;

% %%
ridge_pairs
