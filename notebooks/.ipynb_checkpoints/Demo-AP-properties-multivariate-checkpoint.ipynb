% %% [markdown]
% My Octave Notebook
% ============
%
% Interact with Octave and the statistics-resampling package online in Jupyter Notebook with Binder. All commands are interpreted by Octave.  Since this is a [MetaKernel](https://github.com/Calysto/metakernel), a standard set of magics are available.  Help on commands is available using the `%help` magic or using `?` with a command. For the best experience, run this notebook in [Jupyter Lab](https://mybinder.org/v2/gh/acpennlab/statistics-resampling-online/master?labpath=statistics-resampling.ipynb).
%
% The code cells and their output below illustrate some examples of loading data and then performing analysis using functions from the **statistics-resampling** package. Follow the links in the **Quick start** section of the [README page](https://gnu-octave.github.io/statistics-resampling/readme.html), or on the [Function reference page](https://gnu-octave.github.io/statistics-resampling/function_reference), to find further examples. The example data files provided, **data1.tsv** and **data2.csv**, can be edited directly in this instance of JupyterLab.
%
% The statistics-resampling package already comes installed and loaded at **statistics-resampling-online**. Visit [GNU Octave Packages](https://gnu-octave.github.io/packages/) to see what other packages are available and how to install them. To load a newly installed package called `<package-name>`, use the command `pkg load <package-name>`. To preview demonstration number `X` of a function called `<function-name>`, use the command `demo ('<function-name>', X)`. To get more information about a particular function called `<function-name>`, use the command `help <function-name>`. Note that the **parallel** package cannot be installed at **statistics-resampling-online**, and that additions to the binder environment may be required to build or run some other Octave packages.

% %%
# Number formatting for outputs
format short g

% %% [markdown]
% Some Octave packages come already installed and in this statistics-resampling-online Binder environment. If you were running Octave on your own machine, you would need to install and load the statistics-resampling package first by running the code in the following two cells:

% %%
# Run this command once to install the package
pkg install "https://github.com/gnu-octave/statistics-resampling/archive/refs/heads/master.zip"
% Out:
% The statistics-resampling package was installed into the directory:
% /home/jovyan/.local/share/octave/api-v58/packages/statistics-resampling-5.6.1-dev
% License and copyright information can be found at:
% https://github.com/gnu-octave/statistics-resampling/blob/master/COPYING

% %%
# Run this command in each new Octave session
pkg load statistics-resampling

% %% [markdown]
% Run the code in the next code cell if you wish to know:
% 1) The version of GNU Octave that you are running
% 2) What packages (and their version) are already installed (and loaded*) here
% 3) More information about the statistics-resampling package

% %%
ver('Octave');
pkg list;
pkg describe -verbose statistics-resampling
% Out:
% ----------------------------------------------------------------------
% GNU Octave Version: 8.3.0 (hg id: 6fc591af58ba)
% GNU Octave License: GNU General Public License
% Operating System: Linux 6.8.0-86-generic #87-Ubuntu SMP PREEMPT_DYNAMIC Mon Sep 22 18:03:36 UTC 2025 x86_64
% ----------------------------------------------------------------------
% Package Name           | Version   | Installation directory
% -----------------------+-----------+-----------------------
%                 coder  |     1.9.1 | .../octave/api-v58/packages/coder-1.9.1
%               control  |     4.0.0 | .../octave/api-v58/packages/control-4.0.0
%        data-smoothing  |     1.3.0 | .../api-v58/packages/data-smoothing-1.3.0
%             dataframe  |     1.2.0 | .../api-v58/packages/dataframe-1.2.0
%                fileio  |     1.2.2 | .../octave/api-v58/packages/fileio-1.2.2
%                    ga  |    0.10.4 | .../octave/api-v58/packages/ga-0.10.4
%                    io *|     2.6.4 | .../share/octave/api-v58/packages/io-2.6.4
%         miscellaneous  |     1.3.0 | .../api-v58/packages/miscellaneous-1.3.0
%                 optim  |     1.6.2 | .../octave/api-v58/packages/optim-1.6.2
%           optiminterp  |     0.3.7 | .../api-v58/packages/optiminterp-0.3.7
%                signal  |     1.4.5 | .../octave/api-v58/packages/signal-1.4.5
%               splines  |     1.3.5 | .../octave/api-v58/packages/splines-1.3.5
%            statistics *|     1.6.6 | .../api-v58/packages/statistics-1.6.6
% statistics-resampling *| 5.6.1-dev | .../statistics-resampling-5.6.1-dev
%               strings  |     1.3.1 | .../octave/api-v58/packages/strings-1.3.1
%                struct  |    1.0.18 | .../octave/api-v58/packages/struct-1.0.18
%              symbolic  |     3.2.1 | .../octave/api-v58/packages/symbolic-3.2.1
%            tablicious *|     0.4.2 | .../api-v58/packages/tablicious-0.4.2
% ---
% Package name:
% 	statistics-resampling
% Version:
% 	5.6.1-dev
% Short description:
% 	The statistics-resampling package is an Octave  package and Matlab toolbox that can be used to perform a wide  variety of statistics tasks using non-parametric resampling  methods. In particular, the functions included can be used to  estimate bias, uncertainty (standard errors and confidence  intervals), prediction error, information criteria, and  calculate p-values for null hypothesis significance tests.  Variations of the resampling methods are included that  improve the accuracy of the statistics for small samples  and samples with complex dependence structures.
% Depends on:
% 	octave >= 4.4.0
% Depended on by:
%
% Status:
% 	Loaded
% ---
% Provides:
% Cloned Matlab functions
% 	bootstrp
% 	bootci
% Main functions
% 	bootridge
% 	bootknife
% 	bootclust
% 	bootwild
% 	bootbayes
% 	randtest
% 	randtest1
% 	randtest2
% 	bootlm
% 	boot1way
% 	bootmode
% Utility Functions
% 	boot
% 	bootcdf
% 	bootint
% 	credint
% 	deffcalc
% 	sampszcalc
% Parameter functions
% 	smoothmedian
% 	smoothmad
% 	cor

% %%
# Load the predictor genotype - it has two levels: G1 and G2
[~, genotype]  = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'E2:E77');

# Load the predictor condition - it has three levels: C1, C2 and C3
[~, condition] = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'F2:F77');

# Load the animal cluster ids
animal = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'B2:B77');

# Fetch matrix of all the outcome measures
outcomes = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'G2:R77');

# Get size of the data
disp(size(genotype))
disp(size(condition))
disp(size(animal))
disp(size(outcomes))

# Note that outcomes has 12 columns: a different outcome measure for each of the 76 rows (cell recordings)
% Out:
%            76            1
%            76            1
%            76            1
%            76           12

% %%
# Fit multiple univariate linear models by ordinary least squares to each of the outcomes and save the diagnostic plots
for i = 1:size(outcomes, 2)

  # By default bootlm assumes variables listed in cell array of second input argument are categorical.
  # Set 'model' to 'full' so that it includes the interaction.
  # Set 'nboot' to 0 to bypass bootstrap resampling.
  # Set 'display' to 'on' to create diagnostic plots.
  MAT = bootlm (outcomes(:,i), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'on', ...
                'contrasts', 'treatment');

  # Save the figure of the diagnostic plots
  print (sprintf('../output/Demo/outcome%d.png', i),'-dpng','-r300')
  
end

# Diagnostic plots shown in the output below are just for the last column.
# Figures of the diagnostic plots have been saved.

% %%
# Remove outlier (row 6) from the original data
genotype(6,:) = [];
condition(6,:) = [];
animal(6,:) = []; 
outcomes(6,:) = [];

# ... and the design matrix (X) in MAT
MAT.X(6,:) = [];

# Remove the Apnum (column 11) - it is mostly redundant with column 12 (maxApnum)
outcomes(:,11) = [];

# Get size of the data now - all should have 75 rows) 
disp(size(genotype))
disp(size(condition))
disp(size(animal))
disp(size(outcomes))
disp(size(MAT.X))
% Out:
%            75            1
%            75            1
%            75            1
%            75           11

% %%
# Get bayesian bootstrap summary statistics of all outcomes (Simple Random Sampling)
STATS_SRS = bootbayes (outcomes, MAT.X);

% %%
# Get bayesian cluster bootstrap summary statistics
STATS = bootbayes (outcomes, MAT.X, animal);

% %%
# Estimate design effect per outcome
Deff_per_outcome = mean (STATS.stdev.^2 ./ STATS_SRS.stdev.^2, 1);
Deff = mean (Deff_per_outcome);

disp (Deff_per_outcome)
disp (Deff)
% Out:
%  Columns 1 through 6:
%
%        1.3294       1.5649       1.9128       1.6697        2.049       1.7065
%
%  Columns 7 through 11:
%
%        2.1219       1.2062       0.6517      0.78045       0.8936
% 1.4442

% %%
# Get design matrix for orthogonal (helmert) contrast coding and hypothesis matrix for estimated marginal means
# This time we set display off. 
MAT_EMM = bootlm (outcomes(:,12), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                'contrasts', 'helmert', 'dim', [1, 2]);
                
# Get dimenions of the design matrix (which was constructed using helmert contrasts)
size (MAT_EMM.X)
# It has 76 rows (cell recordings) and 6 columns (1 intercept and 5 predictor terms, all categorical)
% Out:
% ans =
%
%            75            6

% %% [markdown]
% https://gnu-octave.github.io/statistics-resampling/function/bootridge.html

% %%
# Lets fit using ridge regression and use the hypothesis matrix to return the group estimated marginal means.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_EMM.X, [2:6], 1999, .05, MAT_EMM.L, Deff);
toc
ridge_emm = ans;

# Note that we expect NaN for Bayes factors (BF10) and U (-Inf, Inf) for the prior on all the linear estimates
# of the marginal means since they all involve the intercept.
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 12
%
%  Design effect (Deff): 1.4
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 11.3248
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 5.17869
%
%  Effective residual degrees of freedom (df_lambda): 71.0
%
%  Residual variances (range, Deff-inflated):  [0.0174, 1.97e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 49.3
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     Correlation   CI_lower      CI_upper
%  1             2             +0.2685       -0.01986      +0.5156
%  1             3             +0.6749       +0.4812       +0.8058
%  1             4             -0.01462      -0.3002       +0.2734
%  1             5             -0.3351       -0.5674       -0.05343
%  1             6             +0.6284       +0.4166       +0.7754
%  1             7             -0.4403       -0.6456       -0.1757
%  1             8             +0.3180       +0.03430      +0.5543
%  1             9             -0.1846       -0.4477       +0.1080
%  1             10            -0.1640       -0.4306       +0.1289
%  1             11            +0.4277       +0.1605       +0.6364
%  1             12            +0.4014       +0.1294       +0.6172
%  2             3             +0.7343       +0.5668       +0.8435
%  2             4             -0.7533       -0.8553       -0.5950
%  2             5             -0.04780      -0.3301       +0.2424
%  2             6             +0.2847       -0.002317     +0.5284
%  2             7             -0.3414       -0.5722       -0.06049
%  2             8             -0.04618      -0.3287       +0.2439
%  2             9             -0.09585      -0.3725       +0.1964
%  2             10            +0.2923       +0.006002     +0.5344
%  2             11            +0.1353       -0.1577       +0.4064
%  2             12            +0.1702       -0.1227       +0.4358
%  3             4             -0.7477       -0.8518       -0.5867
%  3             5             -0.4157       -0.6277       -0.1463
%  3             6             +0.7418       +0.5780       +0.8482
%  3             7             -0.6685       -0.8016       -0.4722
%  3             8             +0.04665      -0.2435       +0.3291
%  3             9             -0.1860       -0.4489       +0.1065
%  3             10            +0.2623       -0.02653      +0.5107
%  3             11            +0.3834       +0.1085       +0.6039
%  3             12            +0.3933       +0.1200       +0.6112
%  4             5             +0.2617       -0.02718      +0.5102
%  4             6             -0.4398       -0.6452       -0.1750
%  4             7             +0.5096       +0.2609       +0.6949
%  4             8             +0.2230       -0.06824      +0.4792
%  4             9             +0.08599      -0.2059       +0.3639
%  4             10            -0.5030       -0.6903       -0.2526
%  4             11            -0.1347       -0.4059       +0.1583
%  4             12            -0.1717       -0.4371       +0.1211
%  5             6             -0.5811       -0.7440       -0.3531
%  5             7             +0.7929       +0.6550       +0.8797
%  5             8             -0.01133      -0.2972       +0.2764
%  5             9             +0.2116       -0.08010      +0.4699
%  5             10            +0.06336      -0.2276       +0.3440
%  5             11            -0.3343       -0.5668       -0.05251
%  5             12            -0.3705       -0.5942       -0.09354
%  6             7             -0.6741       -0.8053       -0.4801
%  6             8             -0.06846      -0.3485       +0.2228
%  6             9             -0.09570      -0.3723       +0.1965
%  6             10            +0.1822       -0.1104       +0.4458
%  6             11            +0.4339       +0.1680       +0.6410
%  6             12            +0.4102       +0.1398       +0.6236
%  7             8             -0.09738      -0.3738       +0.1949
%  7             9             +0.2505       -0.03912      +0.5014
%  7             10            -0.1361       -0.4071       +0.1568
%  7             11            -0.4568       -0.6575       -0.1955
%  7             12            -0.5003       -0.6884       -0.2493
%  8             9             -0.2931       -0.5350       -0.006839
%  8             10            -0.1590       -0.4264       +0.1340
%  8             11            +0.07697      -0.2146       +0.3560
%  8             12            +0.1159       -0.1769       +0.3898
%  9             10            +0.1395       -0.1534       +0.4100
%  9             11            -0.3026       -0.5424       -0.01728
%  9             12            -0.3781       -0.5999       -0.1024
%  10            11            +0.06555      -0.2255       +0.3459
%  10            12            +0.1600       -0.1329       +0.4272
%  11            12            +0.9405       +0.8952       +0.9666
%
%  95% credible intervals and Bayes factors for linear estimates:
%  (Global ridge prior contribution to posterior:precision: 39.08 %)
%
%  Outcome 1:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +44.76        +42.41        +47.12        +NaN          U (-Inf, Inf)
%  +44.41        +41.94        +46.88        +NaN          U (-Inf, Inf)
%  +43.95        +41.26        +46.65        +NaN          U (-Inf, Inf)
%  +43.07        +40.63        +45.51        +NaN          U (-Inf, Inf)
%  +45.30        +42.73        +47.87        +NaN          U (-Inf, Inf)
%  +45.07        +42.28        +47.86        +NaN          U (-Inf, Inf)
%
%  Outcome 2:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -10.77        -12.65        -8.877        +NaN          U (-Inf, Inf)
%  -11.69        -13.67        -9.710        +NaN          U (-Inf, Inf)
%  -11.96        -14.12        -9.801        +NaN          U (-Inf, Inf)
%  -13.39        -15.34        -11.43        +NaN          U (-Inf, Inf)
%  -11.73        -13.79        -9.674        +NaN          U (-Inf, Inf)
%  -13.08        -15.32        -10.85        +NaN          U (-Inf, Inf)
%
%  Outcome 3:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +82.99        +79.44        +86.54        +NaN          U (-Inf, Inf)
%  +82.75        +79.03        +86.47        +NaN          U (-Inf, Inf)
%  +79.95        +75.89        +84.01        +NaN          U (-Inf, Inf)
%  +79.70        +76.03        +83.37        +NaN          U (-Inf, Inf)
%  +81.27        +77.40        +85.14        +NaN          U (-Inf, Inf)
%  +81.07        +76.87        +85.27        +NaN          U (-Inf, Inf)
%
%  Outcome 4:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -38.22        -40.84        -35.61        +NaN          U (-Inf, Inf)
%  -38.34        -41.08        -35.59        +NaN          U (-Inf, Inf)
%  -35.99        -38.99        -33.00        +NaN          U (-Inf, Inf)
%  -36.63        -39.34        -33.92        +NaN          U (-Inf, Inf)
%  -35.98        -38.83        -33.12        +NaN          U (-Inf, Inf)
%  -36.00        -39.10        -32.90        +NaN          U (-Inf, Inf)
%
%  Outcome 5:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +1.811        +1.729        +1.892        +NaN          U (-Inf, Inf)
%  +1.795        +1.709        +1.880        +NaN          U (-Inf, Inf)
%  +1.737        +1.644        +1.831        +NaN          U (-Inf, Inf)
%  +1.711        +1.626        +1.795        +NaN          U (-Inf, Inf)
%  +1.703        +1.614        +1.792        +NaN          U (-Inf, Inf)
%  +1.691        +1.595        +1.788        +NaN          U (-Inf, Inf)
%
%  Outcome 6:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +3.981        +3.420        +4.542        +NaN          U (-Inf, Inf)
%  +4.059        +3.471        +4.647        +NaN          U (-Inf, Inf)
%  +4.090        +3.448        +4.732        +NaN          U (-Inf, Inf)
%  +4.092        +3.511        +4.672        +NaN          U (-Inf, Inf)
%  +4.377        +3.766        +4.989        +NaN          U (-Inf, Inf)
%  +4.092        +3.428        +4.756        +NaN          U (-Inf, Inf)
%
%  Outcome 7:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.9550       -1.012        -0.8976       +NaN          U (-Inf, Inf)
%  -0.9432       -1.003        -0.8830       +NaN          U (-Inf, Inf)
%  -0.9710       -1.037        -0.9054       +NaN          U (-Inf, Inf)
%  -0.9760       -1.035        -0.9167       +NaN          U (-Inf, Inf)
%  -0.9598       -1.022        -0.8972       +NaN          U (-Inf, Inf)
%  -0.9986       -1.067        -0.9308       +NaN          U (-Inf, Inf)
%
%  Outcome 8:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +91.13        +77.60        +104.7        +NaN          U (-Inf, Inf)
%  +74.65        +60.47        +88.84        +NaN          U (-Inf, Inf)
%  +70.96        +55.48        +86.44        +NaN          U (-Inf, Inf)
%  +68.45        +54.45        +82.45        +NaN          U (-Inf, Inf)
%  +69.81        +55.06        +84.56        +NaN          U (-Inf, Inf)
%  +78.18        +62.17        +94.19        +NaN          U (-Inf, Inf)
%
%  Outcome 9:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +159.2        +139.9        +178.5        +NaN          U (-Inf, Inf)
%  +177.0        +156.7        +197.2        +NaN          U (-Inf, Inf)
%  +160.3        +138.2        +182.4        +NaN          U (-Inf, Inf)
%  +168.6        +148.6        +188.5        +NaN          U (-Inf, Inf)
%  +156.1        +135.0        +177.2        +NaN          U (-Inf, Inf)
%  +168.0        +145.1        +190.8        +NaN          U (-Inf, Inf)
%
%  Outcome 10:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +22.72        +21.05        +24.39        +NaN          U (-Inf, Inf)
%  +21.85        +20.09        +23.60        +NaN          U (-Inf, Inf)
%  +18.51        +16.60        +20.42        +NaN          U (-Inf, Inf)
%  +19.03        +17.30        +20.76        +NaN          U (-Inf, Inf)
%  +17.76        +15.94        +19.59        +NaN          U (-Inf, Inf)
%  +17.88        +15.91        +19.86        +NaN          U (-Inf, Inf)
%
%  Outcome 11:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +9.671        +8.012        +11.33        +NaN          U (-Inf, Inf)
%  +8.498        +6.759        +10.24        +NaN          U (-Inf, Inf)
%  +10.91        +9.007        +12.81        +NaN          U (-Inf, Inf)
%  +11.11        +9.396        +12.83        +NaN          U (-Inf, Inf)
%  +11.45        +9.637        +13.26        +NaN          U (-Inf, Inf)
%  +11.92        +9.958        +13.89        +NaN          U (-Inf, Inf)
%
%  Outcome 12:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +10.51        +8.967        +12.06        +NaN          U (-Inf, Inf)
%  +9.018        +7.397        +10.64        +NaN          U (-Inf, Inf)
%  +11.22        +9.451        +12.99        +NaN          U (-Inf, Inf)
%  +11.37        +9.768        +12.97        +NaN          U (-Inf, Inf)
%  +11.73        +10.05        +13.42        +NaN          U (-Inf, Inf)
%  +12.04        +10.21        +13.87        +NaN          U (-Inf, Inf)
%
% Elapsed time is 399.093 seconds.

% %%
# Get the correlations for any pairs of outcomes involving column 11 of outcomes (Apnum)
rtab = ridge_emm.R_table;
contains_Apnum = any (rtab(:,1:2) == 12, 2);
rtab(contains_Apnum,:)
# Columns 1 and 2 are the column numbers of the matrix of outcomes for each pair
# Column 3 is the correlation coefficient between the pair of outcomes.
# Columns 4 and 5 are the lower and upper 95% credible intervals (flat prior)
% Out:
% ans =
%
%             1           12      0.40136      0.12942      0.61716
%             2           12      0.17018     -0.12265      0.43576
%             3           12      0.39329      0.11998      0.61119
%             4           12     -0.17174     -0.43706      0.12107
%             5           12     -0.37045     -0.59416    -0.093544
%             6           12      0.41016      0.13975      0.62363
%             7           12     -0.50034     -0.68839     -0.24927
%             8           12      0.11587     -0.17685      0.38976
%             9           12     -0.37812      -0.5999     -0.10238
%            10           12      0.16001     -0.13294      0.42725
%            11           12      0.94054      0.89522      0.96661

% %% [markdown]
% ## Notes
%
% maxApnum is negatively correlated with rheobase (9, -.38), fall ( 7, -.50), and half (5, -.37). Therefore, lower rheobase, faster AP repolarization and shorter AP full-width half-maximum are associated with higher AP frequency at the highest current injection.
%
% Apnum is positively correlated with AP amplitude (1, +.40), peak (3, +.39) and rise (6, +.41). Therefore, larger amplitude, peak and faster rise of APs are associated with higher AP frequency at the highest current injection. Not suprisingly, maxApnum and Apnum (10) are highly correlated (+.94).

% %%
# Now lets fit the data again to get the hypothesis matrix for specific group comparisons we are interested in.
comparisons = [2 1; 4 3; 6 5; 3 1; 5 1; 5 3; 4 2; 6 2; 6 4]

# Get design matrix hypothesis matrix for estimated marginal means. We could use any outcome but we'll pick 11.
# This time we set display off. 
MAT_PAIRS = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                'contrasts', 'helmert', 'dim', [1, 2], 'posthoc', comparisons);
% Out:
% comparisons =
%
%             2            1
%             4            3
%             6            5
%             3            1
%             5            1
%             5            3
%             4            2
%             6            2
%             6            4

% %%
# Lets fit using ridge regression and use the hypothesis matrix to return the comparisons of interest.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_PAIRS.X, [2:6], 1999, .05, MAT_PAIRS.L, Deff);
toc
ridge_pairs = ans;
# Note that outcome 8 is input resistance
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 12
%
%  Design effect (Deff): 1.4
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 11.3248
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 5.17869
%
%  Effective residual degrees of freedom (df_lambda): 71.0
%
%  Residual variances (range, Deff-inflated):  [0.0174, 1.97e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 49.3
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     Correlation   CI_lower      CI_upper
%  1             2             +0.2685       -0.01986      +0.5156
%  1             3             +0.6749       +0.4812       +0.8058
%  1             4             -0.01462      -0.3002       +0.2734
%  1             5             -0.3351       -0.5674       -0.05343
%  1             6             +0.6284       +0.4166       +0.7754
%  1             7             -0.4403       -0.6456       -0.1757
%  1             8             +0.3180       +0.03430      +0.5543
%  1             9             -0.1846       -0.4477       +0.1080
%  1             10            -0.1640       -0.4306       +0.1289
%  1             11            +0.4277       +0.1605       +0.6364
%  1             12            +0.4014       +0.1294       +0.6172
%  2             3             +0.7343       +0.5668       +0.8435
%  2             4             -0.7533       -0.8553       -0.5950
%  2             5             -0.04780      -0.3301       +0.2424
%  2             6             +0.2847       -0.002317     +0.5284
%  2             7             -0.3414       -0.5722       -0.06049
%  2             8             -0.04618      -0.3287       +0.2439
%  2             9             -0.09585      -0.3725       +0.1964
%  2             10            +0.2923       +0.006002     +0.5344
%  2             11            +0.1353       -0.1577       +0.4064
%  2             12            +0.1702       -0.1227       +0.4358
%  3             4             -0.7477       -0.8518       -0.5867
%  3             5             -0.4157       -0.6277       -0.1463
%  3             6             +0.7418       +0.5780       +0.8482
%  3             7             -0.6685       -0.8016       -0.4722
%  3             8             +0.04665      -0.2435       +0.3291
%  3             9             -0.1860       -0.4489       +0.1065
%  3             10            +0.2623       -0.02653      +0.5107
%  3             11            +0.3834       +0.1085       +0.6039
%  3             12            +0.3933       +0.1200       +0.6112
%  4             5             +0.2617       -0.02718      +0.5102
%  4             6             -0.4398       -0.6452       -0.1750
%  4             7             +0.5096       +0.2609       +0.6949
%  4             8             +0.2230       -0.06824      +0.4792
%  4             9             +0.08599      -0.2059       +0.3639
%  4             10            -0.5030       -0.6903       -0.2526
%  4             11            -0.1347       -0.4059       +0.1583
%  4             12            -0.1717       -0.4371       +0.1211
%  5             6             -0.5811       -0.7440       -0.3531
%  5             7             +0.7929       +0.6550       +0.8797
%  5             8             -0.01133      -0.2972       +0.2764
%  5             9             +0.2116       -0.08010      +0.4699
%  5             10            +0.06336      -0.2276       +0.3440
%  5             11            -0.3343       -0.5668       -0.05251
%  5             12            -0.3705       -0.5942       -0.09354
%  6             7             -0.6741       -0.8053       -0.4801
%  6             8             -0.06846      -0.3485       +0.2228
%  6             9             -0.09570      -0.3723       +0.1965
%  6             10            +0.1822       -0.1104       +0.4458
%  6             11            +0.4339       +0.1680       +0.6410
%  6             12            +0.4102       +0.1398       +0.6236
%  7             8             -0.09738      -0.3738       +0.1949
%  7             9             +0.2505       -0.03912      +0.5014
%  7             10            -0.1361       -0.4071       +0.1568
%  7             11            -0.4568       -0.6575       -0.1955
%  7             12            -0.5003       -0.6884       -0.2493
%  8             9             -0.2931       -0.5350       -0.006839
%  8             10            -0.1590       -0.4264       +0.1340
%  8             11            +0.07697      -0.2146       +0.3560
%  8             12            +0.1159       -0.1769       +0.3898
%  9             10            +0.1395       -0.1534       +0.4100
%  9             11            -0.3026       -0.5424       -0.01728
%  9             12            -0.3781       -0.5999       -0.1024
%  10            11            +0.06555      -0.2255       +0.3459
%  10            12            +0.1600       -0.1329       +0.4272
%  11            12            +0.9405       +0.8952       +0.9666
%
%  95% credible intervals and Bayes factors for linear estimates:
%  (Global ridge prior contribution to posterior:precision: 39.08 %)
%
%  Outcome 1:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.3486       -3.446        +2.749        -0.5923       t (0, 2.86, 49.3)
%  -0.8862       -4.094        +2.321        -0.3972       t (0, 2.78, 49.3)
%  -0.2286       -3.529        +3.072        -0.5154       t (0, 2.78, 49.3)
%  -0.8081       -4.133        +2.516        -0.4657       t (0, 2.98, 49.3)
%  +0.5340       -2.716        +3.784        -0.5543       t (0, 2.98, 49.3)
%  +1.342        -1.987        +4.671        -0.1416       t (0, 2.66, 49.3)
%  -1.346        -4.576        +1.884        -0.2610       t (0, 2.98, 49.3)
%  +0.6541       -2.786        +4.094        -0.4785       t (0, 2.98, 49.3)
%  +2.000        -1.320        +5.319        +0.2595       t (0, 2.66, 49.3)
%
%  Outcome 2:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.9251       -3.408        +1.557        -0.3341       t (0, 2.29, 49.3)
%  -1.424        -3.994        +1.146        +0.07042      t (0, 2.23, 49.3)
%  -1.350        -3.995        +1.295        +0.005605     t (0, 2.23, 49.3)
%  -1.197        -3.861        +1.467        -0.1749       t (0, 2.39, 49.3)
%  -0.9678       -3.572        +1.636        -0.3270       t (0, 2.39, 49.3)
%  +0.2289       -2.439        +2.897        -0.4589       t (0, 2.13, 49.3)
%  -1.696        -4.284        +0.8927       +0.2528       t (0, 2.39, 49.3)
%  -1.393        -4.150        +1.364        -0.03262      t (0, 2.39, 49.3)
%  +0.3029       -2.357        +2.963        -0.4504       t (0, 2.13, 49.3)
%
%  Outcome 3:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.2383       -4.903        +4.426        -0.6130       t (0, 4.31, 49.3)
%  -0.2464       -5.076        +4.583        -0.5486       t (0, 4.18, 49.3)
%  -0.2028       -5.173        +4.767        -0.5218       t (0, 4.18, 49.3)
%  -3.038        -8.044        +1.968        +0.1603       t (0, 4.48, 49.3)
%  -1.715        -6.608        +3.178        -0.3582       t (0, 4.48, 49.3)
%  +1.323        -3.690        +6.337        -0.3310       t (0, 4.01, 49.3)
%  -3.046        -7.910        +1.817        +0.1793       t (0, 4.48, 49.3)
%  -1.679        -6.860        +3.501        -0.3373       t (0, 4.48, 49.3)
%  +1.367        -3.631        +6.365        -0.3235       t (0, 4.01, 49.3)
%
%  Outcome 4:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.1104       -3.553        +3.332        -0.6163       t (0, 3.18, 49.3)
%  -0.6398       -4.204        +2.924        -0.4877       t (0, 3.09, 49.3)
%  -0.02583      -3.694        +3.642        -0.5252       t (0, 3.09, 49.3)
%  +2.230        -1.464        +5.924        +0.1524       t (0, 3.31, 49.3)
%  +2.249        -1.362        +5.860        +0.1765       t (0, 3.31, 49.3)
%  +0.01885      -3.681        +3.719        -0.4740       t (0, 2.96, 49.3)
%  +1.701        -1.889        +5.290        -0.1578       t (0, 3.31, 49.3)
%  +2.333        -1.490        +6.156        +0.2029       t (0, 3.31, 49.3)
%  +0.6328       -3.056        +4.321        -0.4165       t (0, 2.96, 49.3)
%
%  Outcome 5:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.01613      -0.1234       +0.09110      -0.5718       t (0, 0.0991, 49.3)
%  -0.02646      -0.1375       +0.08457      -0.4373       t (0, 0.0962, 49.3)
%  -0.01184      -0.1261       +0.1024       -0.5032       t (0, 0.0962, 49.3)
%  -0.07362      -0.1887       +0.04146      +0.2420       t (0, 0.103, 49.3)
%  -0.1078       -0.2203       +0.004672     +1.214        t (0, 0.103, 49.3)
%  -0.03419      -0.1494       +0.08105      -0.2934       t (0, 0.0921, 49.3)
%  -0.08395      -0.1958       +0.02786      +0.5190       t (0, 0.103, 49.3)
%  -0.1035       -0.2226       +0.01556      +0.9573       t (0, 0.103, 49.3)
%  -0.01958      -0.1345       +0.09532      -0.4173       t (0, 0.0921, 49.3)
%
%  Outcome 6:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +0.07760      -0.6597       +0.8149       -0.5956       t (0, 0.681, 49.3)
%  +0.001852     -0.7615       +0.7652       -0.5539       t (0, 0.661, 49.3)
%  -0.2854       -1.071        +0.5001       -0.2549       t (0, 0.661, 49.3)
%  +0.1085       -0.6827       +0.8997       -0.5484       t (0, 0.708, 49.3)
%  +0.3962       -0.3772       +1.170        -0.07523      t (0, 0.708, 49.3)
%  +0.2876       -0.5047       +1.080        -0.2041       t (0, 0.634, 49.3)
%  +0.03276      -0.7360       +0.8015       -0.6122       t (0, 0.708, 49.3)
%  +0.03314      -0.7856       +0.8519       -0.5495       t (0, 0.708, 49.3)
%  +0.0003850    -0.7896       +0.7903       -0.4771       t (0, 0.634, 49.3)
%
%  Outcome 7:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +0.01181      -0.06359      +0.08722      -0.5679       t (0, 0.0697, 49.3)
%  -0.005032     -0.08310      +0.07304      -0.5454       t (0, 0.0676, 49.3)
%  -0.03885      -0.1192       +0.04149      -0.04821      t (0, 0.0676, 49.3)
%  -0.01603      -0.09696      +0.06489      -0.5064       t (0, 0.0724, 49.3)
%  -0.004809     -0.08391      +0.07429      -0.6023       t (0, 0.0724, 49.3)
%  +0.01122      -0.06982      +0.09226      -0.4346       t (0, 0.0648, 49.3)
%  -0.03288      -0.1115       +0.04575      -0.2584       t (0, 0.0724, 49.3)
%  -0.05547      -0.1392       +0.02827      +0.3350       t (0, 0.0724, 49.3)
%  -0.02260      -0.1034       +0.05820      -0.3165       t (0, 0.0648, 49.3)
%
%  Outcome 8:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -16.47        -34.26        +1.310        +1.090        t (0, 16.4, 49.3)
%  -2.511        -20.92        +15.90        -0.5157       t (0, 15.9, 49.3)
%  +8.368        -10.58        +27.32        -0.1267       t (0, 15.9, 49.3)
%  -20.16        -39.25        -1.080        +1.613        t (0, 17.1, 49.3)
%  -21.32        -39.97        -2.663        +1.945        t (0, 17.1, 49.3)
%  -1.153        -20.27        +17.96        -0.4665       t (0, 15.3, 49.3)
%  -6.202        -24.74        +12.34        -0.3866       t (0, 17.1, 49.3)
%  +3.524        -16.22        +23.27        -0.4873       t (0, 17.1, 49.3)
%  +9.726        -9.328        +28.78        +0.05385      t (0, 15.3, 49.3)
%
%  Outcome 9:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +17.82        -7.568        +43.22        +0.3765       t (0, 23.5, 49.3)
%  +8.259        -18.03        +34.55        -0.3515       t (0, 22.8, 49.3)
%  +11.89        -15.16        +38.95        -0.1304       t (0, 22.8, 49.3)
%  +1.136        -26.11        +28.39        -0.5835       t (0, 24.4, 49.3)
%  -3.077        -29.71        +23.56        -0.5824       t (0, 24.4, 49.3)
%  -4.213        -31.50        +23.08        -0.4250       t (0, 21.8, 49.3)
%  -8.430        -34.91        +18.05        -0.4080       t (0, 24.4, 49.3)
%  -9.008        -37.21        +19.19        -0.3436       t (0, 24.4, 49.3)
%  -0.5775       -27.79        +26.63        -0.4761       t (0, 21.8, 49.3)
%
%  Outcome 10:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.8765       -3.074        +1.321        -0.2929       t (0, 2.03, 49.3)
%  +0.5219       -1.753        +2.797        -0.4458       t (0, 1.97, 49.3)
%  +0.1202       -2.221        +2.462        -0.5198       t (0, 1.97, 49.3)
%  -4.211        -6.569        -1.852        +5.246        t (0, 2.11, 49.3)
%  -4.958        -7.263        -2.653        +7.470        t (0, 2.11, 49.3)
%  -0.7476       -3.109        +1.614        -0.2685       t (0, 1.89, 49.3)
%  -2.812        -5.103        -0.5208       +2.309        t (0, 2.11, 49.3)
%  -3.961        -6.402        -1.521        +4.361        t (0, 2.11, 49.3)
%  -1.149        -3.504        +1.205        +0.008814     t (0, 1.89, 49.3)
%
%  Outcome 11:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -1.173        -3.354        +1.009        -0.03025      t (0, 2.02, 49.3)
%  +0.2064       -2.052        +2.465        -0.5368       t (0, 1.96, 49.3)
%  +0.4754       -1.849        +2.800        -0.4393       t (0, 1.96, 49.3)
%  +1.235        -1.106        +3.576        -0.02026      t (0, 2.10, 49.3)
%  +1.775        -0.5131       +4.064        +0.6000       t (0, 2.10, 49.3)
%  +0.5401       -1.804        +2.885        -0.3650       t (0, 1.87, 49.3)
%  +2.614        +0.3396       +4.889        +1.967        t (0, 2.10, 49.3)
%  +3.423        +1.001        +5.846        +3.256        t (0, 2.10, 49.3)
%  +0.8091       -1.528        +3.147        -0.2315       t (0, 1.87, 49.3)
%
%  Outcome 12:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -1.495        -3.527        +0.5372       +0.4721       t (0, 1.88, 49.3)
%  +0.1476       -1.956        +2.252        -0.5438       t (0, 1.82, 49.3)
%  +0.3098       -1.855        +2.475        -0.4831       t (0, 1.82, 49.3)
%  +0.7074       -1.473        +2.888        -0.3713       t (0, 1.95, 49.3)
%  +1.221        -0.9108       +3.352        +0.05669      t (0, 1.95, 49.3)
%  +0.5134       -1.671        +2.697        -0.3605       t (0, 1.75, 49.3)
%  +2.350        +0.2311       +4.469        +1.798        t (0, 1.95, 49.3)
%  +3.025        +0.7688       +5.282        +2.901        t (0, 1.95, 49.3)
%  +0.6756       -1.502        +2.853        -0.2796       t (0, 1.75, 49.3)
%
% Elapsed time is 202.8 seconds.
