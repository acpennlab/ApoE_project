% %% [markdown]
% My Octave Notebook
% ============
%
% Interact with Octave and the statistics-resampling package online in Jupyter Notebook with Binder. All commands are interpreted by Octave.  Since this is a [MetaKernel](https://github.com/Calysto/metakernel), a standard set of magics are available.  Help on commands is available using the `%help` magic or using `?` with a command. For the best experience, run this notebook in [Jupyter Lab](https://mybinder.org/v2/gh/acpennlab/statistics-resampling-online/master?labpath=statistics-resampling.ipynb).
%
% The code cells and their output below illustrate some examples of loading data and then performing analysis using functions from the **statistics-resampling** package. Follow the links in the **Quick start** section of the [README page](https://gnu-octave.github.io/statistics-resampling/readme.html), or on the [Function reference page](https://gnu-octave.github.io/statistics-resampling/function_reference), to find further examples. The example data files provided, **data1.tsv** and **data2.csv**, can be edited directly in this instance of JupyterLab.
%
% The statistics-resampling package already comes installed and loaded at **statistics-resampling-online**. Visit [GNU Octave Packages](https://gnu-octave.github.io/packages/) to see what other packages are available and how to install them. To load a newly installed package called `<package-name>`, use the command `pkg load <package-name>`. To preview demonstration number `X` of a function called `<function-name>`, use the command `demo ('<function-name>', X)`. To get more information about a particular function called `<function-name>`, use the command `help <function-name>`. Note that the **parallel** package cannot be installed at **statistics-resampling-online**, and that additions to the binder environment may be required to build or run some other Octave packages.

% %%
# Number formatting for outputs
format short g

% %% [markdown]
% Some Octave packages come already installed and in this statistics-resampling-online Binder environment. If you were running Octave on your own machine, you would need to install and load the statistics-resampling package first by running the code in the following two cells:

% %%
# Run this command once to install the package
pkg install "https://github.com/gnu-octave/statistics-resampling/archive/refs/heads/master.zip"
% Out:
% The statistics-resampling package was installed into the directory:
% /home/jovyan/.local/share/octave/api-v58/packages/statistics-resampling-5.6.1-dev
% License and copyright information can be found at:
% https://github.com/gnu-octave/statistics-resampling/blob/master/COPYING
% warning: library /home/jovyan/.local/share/octave/api-v58/packages/statistics-resampling-5.6.1-dev/boot.mex not reloaded due to existing references
% warning: called from
%     doc_cache_create>create_cache at line 116 column 20
%     gen_doc_cache_in_dir>@<anonymous> at line 150 column 20
%     doc_cache_create>gen_doc_cache_in_dir at line 151 column 9
%     doc_cache_create at line 62 column 12
%     install>generate_lookfor_cache at line 840 column 5
%     install at line 241 column 7
%     pkg at line 619 column 9
%
% warning: library /home/jovyan/.local/share/octave/api-v58/packages/statistics-resampling-5.6.1-dev/smoothmedian.mex not reloaded due to existing references
% warning: called from
%     doc_cache_create>create_cache at line 116 column 20
%     gen_doc_cache_in_dir>@<anonymous> at line 150 column 20
%     doc_cache_create>gen_doc_cache_in_dir at line 151 column 9
%     doc_cache_create at line 62 column 12
%     install>generate_lookfor_cache at line 840 column 5
%     install at line 241 column 7
%     pkg at line 619 column 9

% %%
# Run this command in each new Octave session
pkg load statistics-resampling

% %% [markdown]
% Run the code in the next code cell if you wish to know:
% 1) The version of GNU Octave that you are running
% 2) What packages (and their version) are already installed (and loaded*) here
% 3) More information about the statistics-resampling package

% %%
ver('Octave');
pkg list;
pkg describe -verbose statistics-resampling
% Out:
% ----------------------------------------------------------------------
% GNU Octave Version: 8.3.0 (hg id: 6fc591af58ba)
% GNU Octave License: GNU General Public License
% Operating System: Linux 6.8.0-86-generic #87-Ubuntu SMP PREEMPT_DYNAMIC Mon Sep 22 18:03:36 UTC 2025 x86_64
% ----------------------------------------------------------------------
% Package Name           | Version   | Installation directory
% -----------------------+-----------+-----------------------
%                 coder  |     1.9.1 | .../octave/api-v58/packages/coder-1.9.1
%               control  |     4.0.0 | .../octave/api-v58/packages/control-4.0.0
%        data-smoothing  |     1.3.0 | .../api-v58/packages/data-smoothing-1.3.0
%             dataframe  |     1.2.0 | .../api-v58/packages/dataframe-1.2.0
%                fileio  |     1.2.2 | .../octave/api-v58/packages/fileio-1.2.2
%                    ga  |    0.10.4 | .../octave/api-v58/packages/ga-0.10.4
%                    io *|     2.6.4 | .../share/octave/api-v58/packages/io-2.6.4
%         miscellaneous  |     1.3.0 | .../api-v58/packages/miscellaneous-1.3.0
%                 optim  |     1.6.2 | .../octave/api-v58/packages/optim-1.6.2
%           optiminterp  |     0.3.7 | .../api-v58/packages/optiminterp-0.3.7
%                signal  |     1.4.5 | .../octave/api-v58/packages/signal-1.4.5
%               splines  |     1.3.5 | .../octave/api-v58/packages/splines-1.3.5
%            statistics *|     1.6.6 | .../api-v58/packages/statistics-1.6.6
% statistics-resampling *| 5.6.1-dev | .../statistics-resampling-5.6.1-dev
%               strings  |     1.3.1 | .../octave/api-v58/packages/strings-1.3.1
%                struct  |    1.0.18 | .../octave/api-v58/packages/struct-1.0.18
%              symbolic  |     3.2.1 | .../octave/api-v58/packages/symbolic-3.2.1
%            tablicious *|     0.4.2 | .../api-v58/packages/tablicious-0.4.2
% ---
% Package name:
% 	statistics-resampling
% Version:
% 	5.6.1-dev
% Short description:
% 	The statistics-resampling package is an Octave  package and Matlab toolbox that can be used to perform a wide  variety of statistics tasks using non-parametric resampling  methods. In particular, the functions included can be used to  estimate bias, uncertainty (standard errors and confidence  intervals), prediction error, information criteria, and  calculate p-values for null hypothesis significance tests.  Variations of the resampling methods are included that  improve the accuracy of the statistics for small samples  and samples with complex dependence structures.
% Depends on:
% 	octave >= 4.4.0
% Depended on by:
%
% Status:
% 	Loaded
% ---
% Provides:
% Cloned Matlab functions
% 	bootstrp
% 	bootci
% Main functions
% 	bootridge
% 	bootknife
% 	bootclust
% 	bootwild
% 	bootbayes
% 	randtest
% 	randtest1
% 	randtest2
% 	bootlm
% 	boot1way
% 	bootmode
% Utility Functions
% 	boot
% 	bootcdf
% 	bootint
% 	credint
% 	deffcalc
% 	sampszcalc
% Parameter functions
% 	smoothmedian
% 	smoothmad
% 	cor

% %%
# Load the predictor genotype - it has two levels: G1 and G2
[~, genotype]  = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'E2:E77');

# Load the predictor condition - it has three levels: C1, C2 and C3
[~, condition] = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'F2:F77');

# Load the animal cluster ids
animal = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'B2:B77');

# Fetch matrix of all the outcome measures
outcomes = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'G2:R77');

# Get size of the data
disp(size(genotype))
disp(size(condition))
disp(size(animal))
disp(size(outcomes))

# Note that outcomes has 12 columns: a different outcome measure for each of the 76 rows (cell recordings)
% Out:
%            76            1
%            76            1
%            76            1
%            76           12

% %%
# Fit multiple univariate linear models by ordinary least squares to each of the outcomes and save the diagnostic plots
for i = 1:size(outcomes, 2)

  # By default bootlm assumes variables listed in cell array of second input argument are categorical.
  # Set 'model' to 'full' so that it includes the interaction.
  # Set 'nboot' to 0 to bypass bootstrap resampling.
  # Set 'display' to 'on' to create diagnostic plots.
  # Set 'contrasts' to 'treatment' (dummy) coding
  MAT_T = bootlm (outcomes(:,i), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'on', ...
                  'contrasts', 'treatment');

  # Save the figure of the diagnostic plots
  print (sprintf('../output/Demo/outcome%d.png', i),'-dpng','-r300')
  
end

# Diagnostic plots shown in the output below are just for the last column.
# Figures of the diagnostic plots have been saved.

% %%
if (size (outcomes, 1) > 75)

  # Remove outlier (row 6) from the original data
  genotype(6,:) = [];
  condition(6,:) = [];
  animal(6,:) = []; 
  outcomes(6,:) = [];

  # ... and the design matrix (X) in MAT_T
  MAT_T.X(6,:) = [];

  # Remove the Apnum (column 11) - it is mostly redundant with column 12 (maxApnum)
  outcomes(:,11) = [];

end

# Get size of the data now - all should have 75 rows) 
disp(size(genotype))
disp(size(condition))
disp(size(animal))
disp(size(outcomes))
disp(size(MAT_T.X))
% Out:
%            75            1
%            75            1
%            75            1
%            75           11
%            75            6

% %%
# Get bayesian bootstrap summary statistics of all outcomes (Simple Random Sampling)
STATS_SRS = bootbayes (outcomes, MAT_T.X);

% %%
# Get bayesian cluster bootstrap summary statistics
STATS = bootbayes (outcomes, MAT_T.X, animal);

% %%
# Estimate design effect per outcome
Deff_per_outcome = mean (STATS.stdev.^2 ./ STATS_SRS.stdev.^2, 1);
Deff = mean (Deff_per_outcome);

disp (Deff_per_outcome)
disp (Deff)
m = harmmean (accumarray (animal, 1, [], @sum));  % m is average cluster size
ICC = (Deff - 1) / (m - 1);                       % Intraclass correlation coefficient (rho)
disp (ICC)
% Out:
%  Columns 1 through 6:
%
%        1.2605        1.461       1.7643       1.6048       1.9492        1.541
%
%  Columns 7 through 11:
%
%        2.0779       1.1398      0.58569      0.75904      0.82461
% 1.3607
% 0.18318

% %%
# Get design matrix for orthogonal (helmert) contrast coding and hypothesis matrix for estimated marginal means
# This time we set display off.
MAT_H = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                'contrasts', 'helmert', 'dim', [1, 2]);
MAT_H.C
helmert_flipped = cellfun(@(x) x * -1, MAT_H.C, 'UniformOutput', false)
MAT_H = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                'contrasts', helmert_flipped, 'dim', [1, 2]);
# Get dimenions of the design matrix (which was constructed using sign-flipped helmert contrasts)
size (MAT_H.X)
# It has 75 rows (cell recordings) and 6 columns (1 intercept and 5 predictor terms, all categorical)
% Out:
% ans =
% {
%   [1,1] =
%
%             0.5
%            -0.5
%
%   [1,2] =
%
%         0.66667            0
%        -0.33333          0.5
%        -0.33333         -0.5
%
% }
%
% helmert_flipped =
% {
%   [1,1] =
%
%            -0.5
%             0.5
%
%   [1,2] =
%
%        -0.66667            0
%         0.33333         -0.5
%         0.33333          0.5
%
% }
%
% ans =
%
%            75            6

% %% [markdown]
% https://gnu-octave.github.io/statistics-resampling/function/bootridge.html

% %%
# Lets fit using ridge regression and interpret the coefficients coded with sign-flipped helmert contrasts.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_H.X, '*', 1999, .05, [], Deff);
toc
ridge_coeff = ans;
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 11
%
%  Design effect (Deff): 1.36
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 10.4536
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 5.91083
%
%  Effective residual degrees of freedom (df_lambda): 71.1
%
%  Residual variances (range, Deff-inflated):  [0.0169, 1.91e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 51.2
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     correlation   CI_lower      CI_upper
%  1             2             +0.2686       -0.01081      +0.5091
%  1             3             +0.6748       +0.4879       +0.8025
%  1             4             -0.01427      -0.2917       +0.2654
%  1             5             -0.3347       -0.5610       -0.06191
%  1             6             +0.6274       +0.4228       +0.7712
%  1             7             -0.4400       -0.6401       -0.1839
%  1             8             +0.3174       +0.04253      +0.5475
%  1             9             -0.1844       -0.4403       +0.09933
%  1             10            -0.1640       -0.4233       +0.1201
%  1             11            +0.4003       +0.1369       +0.6107
%  2             3             +0.7341       +0.5727       +0.8408
%  2             4             -0.7529       -0.8527       -0.6002
%  2             5             -0.04659      -0.3210       +0.2350
%  2             6             +0.2845       +0.006445     +0.5218
%  2             7             -0.3397       -0.5649       -0.06755
%  2             8             -0.04613      -0.3206       +0.2355
%  2             9             -0.09573      -0.3646       +0.1879
%  2             10            +0.2922       +0.01484      +0.5278
%  2             11            +0.1679       -0.1161       +0.4266
%  3             4             -0.7476       -0.8493       -0.5924
%  3             5             -0.4144       -0.6213       -0.1536
%  3             6             +0.7409       +0.5826       +0.8451
%  3             7             -0.6670       -0.7974       -0.4771
%  3             8             +0.04729      -0.2344       +0.3216
%  3             9             -0.1858       -0.4415       +0.09790
%  3             10            +0.2626       -0.01724      +0.5043
%  3             11            +0.3913       +0.1265       +0.6040
%  4             5             +0.2602       -0.01979      +0.5024
%  4             6             -0.4392       -0.6395       -0.1830
%  4             7             +0.5077       +0.2669       +0.6889
%  4             8             +0.2215       -0.06082      +0.4710
%  4             9             +0.08575      -0.1976       +0.3558
%  4             10            -0.5034       -0.6858       -0.2614
%  4             11            -0.1699       -0.4283       +0.1141
%  5             6             -0.5808       -0.7397       -0.3605
%  5             7             +0.7917       +0.6583       +0.8769
%  5             8             -0.01017      -0.2879       +0.2692
%  5             9             +0.2117       -0.07108      +0.4630
%  5             10            +0.06647      -0.2161       +0.3388
%  5             11            -0.3710       -0.5888       -0.1031
%  6             7             -0.6712       -0.8002       -0.4829
%  6             8             -0.07109      -0.3429       +0.2117
%  6             9             -0.09571      -0.3646       +0.1879
%  6             10            +0.1800       -0.1038       +0.4367
%  6             11            +0.4078       +0.1458       +0.6164
%  7             8             -0.1004       -0.3687       +0.1833
%  7             9             +0.2504       -0.03035      +0.4945
%  7             10            -0.1343       -0.3980       +0.1499
%  7             11            -0.5012       -0.6843       -0.2587
%  8             9             -0.2926       -0.5282       -0.01529
%  8             10            -0.1536       -0.4145       +0.1306
%  8             11            +0.1190       -0.1651       +0.3848
%  9             10            +0.1388       -0.1454       +0.4018
%  9             11            -0.3786       -0.5945       -0.1117
%  10            11            +0.1568       -0.1273       +0.4172
%
%  95% credible intervals and Bayes factors for regression coefficients.
%  Global ridge prior contribution to posterior precision: 41.85 %
%  Stability selection (SS): >97.5% for the (-) or (+) sign of the coefficient.
%  Deff-adjusted SS probabilities are reported in S.stability
%
%  Outcome 1:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +44.42        +43.18        +45.67        +NaN          U (-Inf, Inf)
%  -0.4787       -2.650        +1.693        -0.607        t (0, 2.19, 51.2)
%  -0.2375       -2.431        +1.956        -0.672        t (0, 2.19, 51.2)
%  +1.601        -0.9979       +4.200        +0.241        t (0, 2.19, 51.2)
%  -0.1973       -3.517        +3.122        -0.275        t (0, 2.19, 51.2)
%  +0.6037       -3.034        +4.241        -0.134        t (0, 2.19, 51.2)
%
%  Outcome 2:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  -12.10        -13.10        -11.10        +NaN          U (-Inf, Inf)
%  -1.196        -2.937        +0.5443       +0.246        t (0, 1.76, 51.2)
%  -1.274        -3.032        +0.4838       +0.361        t (0, 1.76, 51.2)
%  +0.2610       -1.822        +2.344        -0.495        t (0, 1.76, 51.2)
%  -0.4244       -3.085        +2.236        -0.230        t (0, 1.76, 51.2)
%  +0.07308      -2.842        +2.988        -0.189        t (0, 1.76, 51.2)
%
%  Outcome 3:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +81.29        +79.41        +83.17        +NaN          U (-Inf, Inf)
%  -0.2286       -3.498        +3.041        -0.696        t (0, 3.30, 51.2)
%  -2.298        -5.600        +1.004        +0.280        t (0, 3.30, 51.2)
%  +1.290        -2.623        +5.203        -0.304        t (0, 3.30, 51.2)
%  +0.01209      -4.986        +5.010        -0.282        t (0, 3.30, 51.2)
%  +0.04627      -5.430        +5.522        -0.191        t (0, 3.30, 51.2)
%
%  Outcome 4:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  -36.87        -38.26        -35.48        +NaN          U (-Inf, Inf)
%  -0.2501       -2.663        +2.163        -0.684        t (0, 2.44, 51.2)
%  +2.061        -0.3762       +4.498        +0.733        t (0, 2.44, 51.2)
%  +0.3112       -2.577        +3.199        -0.503        t (0, 2.44, 51.2)
%  -0.2094       -3.898        +3.479        -0.275        t (0, 2.44, 51.2)
%  +0.5575       -3.484        +4.599        -0.152        t (0, 2.44, 51.2)
%
%  Outcome 5:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +1.741        +1.698        +1.785        +NaN          U (-Inf, Inf)
%  -0.01760      -0.09280      +0.05761      -0.594        t (0, 0.0759, 51.2)
%  -0.08941      -0.1654       -0.01346      +2.01     (-) t (0, 0.0759, 51.2)
%  -0.02556      -0.1156       +0.06444      -0.362        t (0, 0.0759, 51.2)
%  -0.002592     -0.1175       +0.1124       -0.281        t (0, 0.0759, 51.2)
%  +0.01363      -0.1123       +0.1396       -0.167        t (0, 0.0759, 51.2)
%
%  Outcome 6:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +4.115        +3.818        +4.413        +NaN          U (-Inf, Inf)
%  -0.06573      -0.5827       +0.4512       -0.673        t (0, 0.522, 51.2)
%  +0.1390       -0.3831       +0.6610       -0.551        t (0, 0.522, 51.2)
%  +0.1384       -0.4803       +0.7571       -0.424        t (0, 0.522, 51.2)
%  -0.2039       -0.9941       +0.5863       -0.146        t (0, 0.522, 51.2)
%  -0.2630       -1.129        +0.6029       -0.00188      t (0, 0.522, 51.2)
%
%  Outcome 7:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  -0.9671       -0.9976       -0.9367       +NaN          U (-Inf, Inf)
%  -0.01020      -0.06311      +0.04270      -0.630        t (0, 0.0534, 51.2)
%  -0.02635      -0.07977      +0.02708      -0.202        t (0, 0.0534, 51.2)
%  -0.005294     -0.06861      +0.05802      -0.512        t (0, 0.0534, 51.2)
%  -0.03126      -0.1121       +0.04961      +0.0231       t (0, 0.0534, 51.2)
%  -0.03084      -0.1194       +0.05776      +0.0571       t (0, 0.0534, 51.2)
%
%  Outcome 8:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +75.54        +68.34        +82.74        +NaN          U (-Inf, Inf)
%  -3.541        -16.06        +8.973        -0.542        t (0, 12.6, 51.2)
%  -10.75        -23.39        +1.886        +0.749    (-) t (0, 12.6, 51.2)
%  +4.073        -10.90        +19.05        -0.375        t (0, 12.6, 51.2)
%  +18.04        -1.094        +37.17        +1.48     (+) t (0, 12.6, 51.2)
%  +9.970        -10.99        +30.93        +0.270        t (0, 12.6, 51.2)
%
%  Outcome 9:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +164.8        +154.6        +175.1        +NaN          U (-Inf, Inf)
%  +12.31        -5.496        +30.11        +0.257        t (0, 18.0, 51.2)
%  -4.684        -22.66        +13.29        -0.557        t (0, 18.0, 51.2)
%  -2.305        -23.61        +19.00        -0.503        t (0, 18.0, 51.2)
%  -7.243        -34.45        +19.97        -0.137        t (0, 18.0, 51.2)
%  +3.331        -26.48        +33.15        -0.165        t (0, 18.0, 51.2)
%
%  Outcome 10:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +19.64        +18.75        +20.53        +NaN          U (-Inf, Inf)
%  -0.08007      -1.627        +1.467        -0.701        t (0, 1.56, 51.2)
%  -3.862        -5.424        -2.300        +9.55     (-) t (0, 1.56, 51.2)
%  -0.9066       -2.758        +0.9447       -0.0388       t (0, 1.56, 51.2)
%  +1.120        -1.244        +3.485        +0.175        t (0, 1.56, 51.2)
%  -0.3593       -2.950        +2.231        -0.151        t (0, 1.56, 51.2)
%
%  Outcome 11:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +10.98        +10.16        +11.80        +NaN          U (-Inf, Inf)
%  -0.3424       -1.770        +1.085        -0.589        t (0, 1.44, 51.2)
%  +1.767        +0.3247       +3.209        +2.22     (+) t (0, 1.44, 51.2)
%  +0.5634       -1.145        +2.272        -0.304        t (0, 1.44, 51.2)
%  +1.600        -0.5827       +3.783        +0.799    (+) t (0, 1.44, 51.2)
%  +0.1427       -2.249        +2.534        -0.183        t (0, 1.44, 51.2)
%
% Elapsed time is 148.067 seconds.

% %%
% Stability selection probabilities of the regression coefficients
ridge_coeff.stability*100
% Out:
% ans =
%
%  Columns 1 through 6:
%
%           NaN          NaN          NaN          NaN          NaN          NaN
%        69.471       95.679       55.643       60.351       71.913       60.872
%        58.878       93.883       92.044       96.047       99.256       73.469
%        97.225       63.183         85.9       62.964       80.182       73.147
%         57.28       67.504        48.95       55.557       51.179       78.106
%        77.439       53.796        50.45       70.461        69.83       88.276
%
%  Columns 7 through 11:
%
%           NaN          NaN          NaN          NaN          NaN
%        65.555        77.06       95.752        56.16        71.05
%        87.399        97.65       71.185       99.858       99.675
%        57.409       74.439       60.785       90.783       78.585
%        87.236       99.858        77.82       92.414       98.905
%        91.437        97.06       65.687       67.682       57.841

% %% [markdown]
% ## Interpreting the coefficients from sign-flipped helmert contrasts
% 1. is the intercept so represents the grand mean
% 2. is the difference between the two genotypes (G2 - G1) averaged over the conditions
% 3. is the difference between conditions (C2C3 - C1) averaged over the genotypes
% 4. is the difference between conditions (C2 - C3) averaged over the genotypes
% 5. is the difference between the two genotypes (G2 - G1) different in C2C3 compared to C1?
% 6. is the difference between the two genotypes (G2 - G1) different in C3 compared to C2?
%
% The outcome numbers correspond to.
% 1. peak
% 2. afterhyp
% 3. amp
% 4. thresh
% 5. half
% 6. rise
% 7. fall
% 8. IR
% 9. Rh
% 10. sag
% 11. Apnum
% 12. maxApnum
%
% Things I have noticed - there is strong evidence  (lnBF10 = +9.28, BF10 = 10721, SS = 99.8%) for a 3.90 mV decrease in Ih sag, strong evidence for a 0.09 ms narrowing of the action potential (full-width half-maximum) (lnBF10 = +1.92, BF10 = 6.82, SS = 99.2%), and strong evidence for a 1.78 Hz increase in maximum AP firing frequency (lnBF10 = +2.13, BF10 = 8.41), with ketamine/memantine irrespective of genotype. For AP firing frequency, there is some (anecdotal) evidence to indicate that that the genotype effect dependence on drug is a strong predictor of maximum firing rate (lnBF10 = +0.78, BF10 = 2.18, SS = 98.8%). There is good evidence for G2 having an 18.4 Mohm difference between the genotypes depending on the drug condition C1 vs C2C3 (lnBF10 = +1.45, BF10 = 4.26, SS = 99.8%), specifically it is lower for G2 compared to G1 in the control condition, but it is also equally low for both genotypes in C2 and C3 conditions. There is also some anecdotal evidence for a 2.08 mV increase in AP firing threshold in C2C3 compared to C1 irrespective of genotype (lnBF10 = +2.68, BF10 = 14.6, SS = 95.8%).

% %%
# Lets fit using ridge regression and use the hypothesis matrix to return the group estimated marginal means.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_H.X, "*", 1999, .05, MAT_H.L, Deff);
toc
ridge_emm = ans;

# Note that we expect NaN for Bayes factors (BF10) and U (-Inf, Inf) for the prior on all the linear estimates
# of the marginal means since they all involve the intercept.
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 11
%
%  Design effect (Deff): 1.36
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 10.4536
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 5.91083
%
%  Effective residual degrees of freedom (df_lambda): 71.1
%
%  Residual variances (range, Deff-inflated):  [0.0169, 1.91e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 51.2
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     correlation   CI_lower      CI_upper
%  1             2             +0.2686       -0.01081      +0.5091
%  1             3             +0.6748       +0.4879       +0.8025
%  1             4             -0.01427      -0.2917       +0.2654
%  1             5             -0.3347       -0.5610       -0.06191
%  1             6             +0.6274       +0.4228       +0.7712
%  1             7             -0.4400       -0.6401       -0.1839
%  1             8             +0.3174       +0.04253      +0.5475
%  1             9             -0.1844       -0.4403       +0.09933
%  1             10            -0.1640       -0.4233       +0.1201
%  1             11            +0.4003       +0.1369       +0.6107
%  2             3             +0.7341       +0.5727       +0.8408
%  2             4             -0.7529       -0.8527       -0.6002
%  2             5             -0.04659      -0.3210       +0.2350
%  2             6             +0.2845       +0.006445     +0.5218
%  2             7             -0.3397       -0.5649       -0.06755
%  2             8             -0.04613      -0.3206       +0.2355
%  2             9             -0.09573      -0.3646       +0.1879
%  2             10            +0.2922       +0.01484      +0.5278
%  2             11            +0.1679       -0.1161       +0.4266
%  3             4             -0.7476       -0.8493       -0.5924
%  3             5             -0.4144       -0.6213       -0.1536
%  3             6             +0.7409       +0.5826       +0.8451
%  3             7             -0.6670       -0.7974       -0.4771
%  3             8             +0.04729      -0.2344       +0.3216
%  3             9             -0.1858       -0.4415       +0.09790
%  3             10            +0.2626       -0.01724      +0.5043
%  3             11            +0.3913       +0.1265       +0.6040
%  4             5             +0.2602       -0.01979      +0.5024
%  4             6             -0.4392       -0.6395       -0.1830
%  4             7             +0.5077       +0.2669       +0.6889
%  4             8             +0.2215       -0.06082      +0.4710
%  4             9             +0.08575      -0.1976       +0.3558
%  4             10            -0.5034       -0.6858       -0.2614
%  4             11            -0.1699       -0.4283       +0.1141
%  5             6             -0.5808       -0.7397       -0.3605
%  5             7             +0.7917       +0.6583       +0.8769
%  5             8             -0.01017      -0.2879       +0.2692
%  5             9             +0.2117       -0.07108      +0.4630
%  5             10            +0.06647      -0.2161       +0.3388
%  5             11            -0.3710       -0.5888       -0.1031
%  6             7             -0.6712       -0.8002       -0.4829
%  6             8             -0.07109      -0.3429       +0.2117
%  6             9             -0.09571      -0.3646       +0.1879
%  6             10            +0.1800       -0.1038       +0.4367
%  6             11            +0.4078       +0.1458       +0.6164
%  7             8             -0.1004       -0.3687       +0.1833
%  7             9             +0.2504       -0.03035      +0.4945
%  7             10            -0.1343       -0.3980       +0.1499
%  7             11            -0.5012       -0.6843       -0.2587
%  8             9             -0.2926       -0.5282       -0.01529
%  8             10            -0.1536       -0.4145       +0.1306
%  8             11            +0.1190       -0.1651       +0.3848
%  9             10            +0.1388       -0.1454       +0.4018
%  9             11            -0.3786       -0.5945       -0.1117
%  10            11            +0.1568       -0.1273       +0.4172
%
%  95% credible intervals and Bayes factors for linear estimates.
%  Global ridge prior contribution to posterior precision: 41.85 %
%
%  Outcome 1:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +44.76        +42.47        +47.04        +NaN          U (-Inf, Inf)
%  +44.41        +42.02        +46.80        +NaN          U (-Inf, Inf)
%  +43.97        +41.37        +46.56        +NaN          U (-Inf, Inf)
%  +43.12        +40.76        +45.48        +NaN          U (-Inf, Inf)
%  +45.27        +42.79        +47.75        +NaN          U (-Inf, Inf)
%  +45.02        +42.34        +47.71        +NaN          U (-Inf, Inf)
%
%  Outcome 2:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -10.79        -12.63        -8.964        +NaN          U (-Inf, Inf)
%  -11.71        -13.62        -9.792        +NaN          U (-Inf, Inf)
%  -11.97        -14.05        -9.888        +NaN          U (-Inf, Inf)
%  -13.34        -15.23        -11.45        +NaN          U (-Inf, Inf)
%  -11.74        -13.73        -9.755        +NaN          U (-Inf, Inf)
%  -13.05        -15.19        -10.90        +NaN          U (-Inf, Inf)
%
%  Outcome 3:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +82.94        +79.50        +86.38        +NaN          U (-Inf, Inf)
%  +82.71        +79.11        +86.31        +NaN          U (-Inf, Inf)
%  +80.00        +76.10        +83.91        +NaN          U (-Inf, Inf)
%  +79.76        +76.20        +83.31        +NaN          U (-Inf, Inf)
%  +81.27        +77.54        +85.01        +NaN          U (-Inf, Inf)
%  +81.07        +77.03        +85.11        +NaN          U (-Inf, Inf)
%
%  Outcome 4:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -38.19        -40.72        -35.65        +NaN          U (-Inf, Inf)
%  -38.30        -40.95        -35.64        +NaN          U (-Inf, Inf)
%  -36.04        -38.92        -33.15        +NaN          U (-Inf, Inf)
%  -36.64        -39.26        -34.01        +NaN          U (-Inf, Inf)
%  -36.00        -38.76        -33.25        +NaN          U (-Inf, Inf)
%  -36.05        -39.02        -33.07        +NaN          U (-Inf, Inf)
%
%  Outcome 5:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +1.809        +1.730        +1.888        +NaN          U (-Inf, Inf)
%  +1.793        +1.710        +1.876        +NaN          U (-Inf, Inf)
%  +1.737        +1.647        +1.827        +NaN          U (-Inf, Inf)
%  +1.712        +1.630        +1.793        +NaN          U (-Inf, Inf)
%  +1.705        +1.619        +1.791        +NaN          U (-Inf, Inf)
%  +1.693        +1.600        +1.786        +NaN          U (-Inf, Inf)
%
%  Outcome 6:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +3.987        +3.444        +4.531        +NaN          U (-Inf, Inf)
%  +4.058        +3.489        +4.627        +NaN          U (-Inf, Inf)
%  +4.093        +3.475        +4.711        +NaN          U (-Inf, Inf)
%  +4.091        +3.530        +4.653        +NaN          U (-Inf, Inf)
%  +4.363        +3.773        +4.954        +NaN          U (-Inf, Inf)
%  +4.098        +3.460        +4.736        +NaN          U (-Inf, Inf)
%
%  Outcome 7:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.9549       -1.011        -0.8993       +NaN          U (-Inf, Inf)
%  -0.9443       -1.003        -0.8860       +NaN          U (-Inf, Inf)
%  -0.9707       -1.034        -0.9074       +NaN          U (-Inf, Inf)
%  -0.9759       -1.033        -0.9184       +NaN          U (-Inf, Inf)
%  -0.9606       -1.021        -0.9001       +NaN          U (-Inf, Inf)
%  -0.9966       -1.062        -0.9313       +NaN          U (-Inf, Inf)
%
%  Outcome 8:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +90.49        +77.33        +103.7        +NaN          U (-Inf, Inf)
%  +74.93        +61.15        +88.70        +NaN          U (-Inf, Inf)
%  +71.18        +56.22        +86.14        +NaN          U (-Inf, Inf)
%  +68.66        +55.07        +82.26        +NaN          U (-Inf, Inf)
%  +70.26        +55.96        +84.56        +NaN          U (-Inf, Inf)
%  +77.72        +62.27        +93.17        +NaN          U (-Inf, Inf)
%
%  Outcome 9:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +159.4        +140.7        +178.1        +NaN          U (-Inf, Inf)
%  +176.5        +156.9        +196.1        +NaN          U (-Inf, Inf)
%  +160.3        +139.0        +181.6        +NaN          U (-Inf, Inf)
%  +168.6        +149.2        +187.9        +NaN          U (-Inf, Inf)
%  +156.4        +136.0        +176.7        +NaN          U (-Inf, Inf)
%  +167.9        +145.9        +189.9        +NaN          U (-Inf, Inf)
%
%  Outcome 10:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +22.63        +21.00        +24.25        +NaN          U (-Inf, Inf)
%  +21.80        +20.10        +23.50        +NaN          U (-Inf, Inf)
%  +18.57        +16.72        +20.42        +NaN          U (-Inf, Inf)
%  +19.04        +17.36        +20.72        +NaN          U (-Inf, Inf)
%  +17.84        +16.07        +19.61        +NaN          U (-Inf, Inf)
%  +17.95        +16.04        +19.86        +NaN          U (-Inf, Inf)
%
%  Outcome 11:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +10.51        +9.004        +12.01        +NaN          U (-Inf, Inf)
%  +9.097        +7.525        +10.67        +NaN          U (-Inf, Inf)
%  +11.23        +9.520        +12.93        +NaN          U (-Inf, Inf)
%  +11.35        +9.795        +12.90        +NaN          U (-Inf, Inf)
%  +11.72        +10.09        +13.35        +NaN          U (-Inf, Inf)
%  +11.98        +10.22        +13.74        +NaN          U (-Inf, Inf)
%
% Elapsed time is 146.215 seconds.

% %%
# Get the correlations for any pairs of outcomes involving column 11 of outcomes (Apnum)
RTAB = ridge_emm.RTAB;
disp(min(RTAB(:,3)));
disp(max(RTAB(:,3)));
contains_Apnum = any (RTAB(:,1:2) == 11, 2);
RTAB(contains_Apnum,:)
# Columns 1 and 2 are the column numbers of the matrix of outcomes for each pair
# Column 3 is the correlation coefficient between the pair of outcomes.
# Columns 4 and 5 are the lower and upper 95% credible intervals (flat prior)
% Out:
% -0.75291
% 0.7917
% ans =
%
%             1           11      0.40026      0.13694      0.61075
%             2           11      0.16792     -0.11611      0.42655
%             3           11       0.3913       0.1265      0.60404
%             4           11     -0.16994     -0.42825      0.11405
%             5           11     -0.37105     -0.58878     -0.10312
%             6           11      0.40778      0.14575      0.61635
%             7           11      -0.5012     -0.68425     -0.25874
%             8           11      0.11899     -0.16507      0.38483
%             9           11     -0.37855     -0.59445     -0.11175
%            10           11      0.15682     -0.12733      0.41719

% %% [markdown]
% ## Notes
%
% The outcome numbers correspond to.
% 1. peak
% 2. afterhyp
% 3. amp
% 4. thresh
% 5. half
% 6. rise
% 7. fall
% 8. IR
% 9. Rh
% 10. sag
% 11. Apnum
% 12. maxApnum
%
% maxApnum is negatively correlated with rheobase (9, -.38), fall ( 7, -.50), and half (5, -.37). Therefore, lower rheobase, faster AP repolarization and shorter AP full-width half-maximum are associated with higher AP frequency at the highest current injection.
%
% Apnum is positively correlated with AP amplitude (1, +.40), peak (3, +.39) and rise (6, +.41). Therefore, larger amplitude, peak and faster rise of APs are associated with higher AP frequency at the highest current injection.

% %%
# Now lets fit the data again to get the hypothesis matrix for specific group comparisons we are interested in.
comparisons = [2 1; 4 3; 6 5; 3 1; 5 1; 5 3; 4 2; 6 2; 6 4]

# Get design matrix hypothesis matrix for estimated marginal means. We could use any outcome but we'll pick 11.
# This time we set display off. 
MAT_H_PAIRS = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                      'contrasts', 'helmert', 'dim', [1, 2], 'posthoc', comparisons);
% Out:
% comparisons =
%
%             2            1
%             4            3
%             6            5
%             3            1
%             5            1
%             5            3
%             4            2
%             6            2
%             6            4

% %%
# Lets fit using ridge regression and use the hypothesis matrix to return the comparisons of interest.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_H_PAIRS.X, [2:6], 1999, .05, MAT_H_PAIRS.L, Deff);
toc
ridge_pairs = ans;
# Note that outcome 8 is input resistance
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 11
%
%  Design effect (Deff): 1.36
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 10.4536
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 5.91083
%
%  Effective residual degrees of freedom (df_lambda): 71.1
%
%  Residual variances (range, Deff-inflated):  [0.0169, 1.91e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 51.2
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     correlation   CI_lower      CI_upper
%  1             2             +0.2686       -0.01081      +0.5091
%  1             3             +0.6748       +0.4879       +0.8025
%  1             4             -0.01427      -0.2917       +0.2654
%  1             5             -0.3347       -0.5610       -0.06191
%  1             6             +0.6274       +0.4228       +0.7712
%  1             7             -0.4400       -0.6401       -0.1839
%  1             8             +0.3174       +0.04253      +0.5475
%  1             9             -0.1844       -0.4403       +0.09933
%  1             10            -0.1640       -0.4233       +0.1201
%  1             11            +0.4003       +0.1369       +0.6107
%  2             3             +0.7341       +0.5727       +0.8408
%  2             4             -0.7529       -0.8527       -0.6002
%  2             5             -0.04659      -0.3210       +0.2350
%  2             6             +0.2845       +0.006445     +0.5218
%  2             7             -0.3397       -0.5649       -0.06755
%  2             8             -0.04613      -0.3206       +0.2355
%  2             9             -0.09573      -0.3646       +0.1879
%  2             10            +0.2922       +0.01484      +0.5278
%  2             11            +0.1679       -0.1161       +0.4266
%  3             4             -0.7476       -0.8493       -0.5924
%  3             5             -0.4144       -0.6213       -0.1536
%  3             6             +0.7409       +0.5826       +0.8451
%  3             7             -0.6670       -0.7974       -0.4771
%  3             8             +0.04729      -0.2344       +0.3216
%  3             9             -0.1858       -0.4415       +0.09790
%  3             10            +0.2626       -0.01724      +0.5043
%  3             11            +0.3913       +0.1265       +0.6040
%  4             5             +0.2602       -0.01979      +0.5024
%  4             6             -0.4392       -0.6395       -0.1830
%  4             7             +0.5077       +0.2669       +0.6889
%  4             8             +0.2215       -0.06082      +0.4710
%  4             9             +0.08575      -0.1976       +0.3558
%  4             10            -0.5034       -0.6858       -0.2614
%  4             11            -0.1699       -0.4283       +0.1141
%  5             6             -0.5808       -0.7397       -0.3605
%  5             7             +0.7917       +0.6583       +0.8769
%  5             8             -0.01017      -0.2879       +0.2692
%  5             9             +0.2117       -0.07108      +0.4630
%  5             10            +0.06647      -0.2161       +0.3388
%  5             11            -0.3710       -0.5888       -0.1031
%  6             7             -0.6712       -0.8002       -0.4829
%  6             8             -0.07109      -0.3429       +0.2117
%  6             9             -0.09571      -0.3646       +0.1879
%  6             10            +0.1800       -0.1038       +0.4367
%  6             11            +0.4078       +0.1458       +0.6164
%  7             8             -0.1004       -0.3687       +0.1833
%  7             9             +0.2504       -0.03035      +0.4945
%  7             10            -0.1343       -0.3980       +0.1499
%  7             11            -0.5012       -0.6843       -0.2587
%  8             9             -0.2926       -0.5282       -0.01529
%  8             10            -0.1536       -0.4145       +0.1306
%  8             11            +0.1190       -0.1651       +0.3848
%  9             10            +0.1388       -0.1454       +0.4018
%  9             11            -0.3786       -0.5945       -0.1117
%  10            11            +0.1568       -0.1273       +0.4172
%
%  95% credible intervals and Bayes factors for linear estimates.
%  Global ridge prior contribution to posterior precision: 41.85 %
%
%  Outcome 1:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.3472       -3.320        +2.625        -0.548        t (0, 2.64, 51.2)
%  -0.8463       -3.909        +2.216        -0.360        t (0, 2.56, 51.2)
%  -0.2426       -3.388        +2.903        -0.478        t (0, 2.56, 51.2)
%  -0.7885       -3.974        +2.397        -0.421        t (0, 2.74, 51.2)
%  +0.5109       -2.609        +3.631        -0.512        t (0, 2.74, 51.2)
%  +1.299        -1.878        +4.476        -0.0962       t (0, 2.45, 51.2)
%  -1.288        -4.389        +1.814        -0.221        t (0, 2.74, 51.2)
%  +0.6154       -2.675        +3.906        -0.442        t (0, 2.74, 51.2)
%  +1.903        -1.264        +5.071        +0.291        t (0, 2.45, 51.2)
%
%  Outcome 2:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.9133       -3.295        +1.469        -0.276        t (0, 2.11, 51.2)
%  -1.374        -3.829        +1.080        +0.119        t (0, 2.05, 51.2)
%  -1.301        -3.822        +1.220        +0.0514       t (0, 2.05, 51.2)
%  -1.174        -3.727        +1.379        -0.116        t (0, 2.20, 51.2)
%  -0.9495       -3.450        +1.551        -0.273        t (0, 2.20, 51.2)
%  +0.2244       -2.322        +2.771        -0.422        t (0, 1.96, 51.2)
%  -1.635        -4.120        +0.8506       +0.301        t (0, 2.20, 51.2)
%  -1.337        -3.975        +1.300        +0.00898      t (0, 2.20, 51.2)
%  +0.2975       -2.241        +2.836        -0.412        t (0, 1.96, 51.2)
%
%  Outcome 3:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.2367       -4.712        +4.238        -0.571        t (0, 3.97, 51.2)
%  -0.2477       -4.859        +4.363        -0.511        t (0, 3.85, 51.2)
%  -0.2015       -4.937        +4.534        -0.486        t (0, 3.85, 51.2)
%  -2.938        -7.733        +1.857        +0.213        t (0, 4.13, 51.2)
%  -1.671        -6.368        +3.026        -0.309        t (0, 4.13, 51.2)
%  +1.267        -3.516        +6.050        -0.294        t (0, 3.69, 51.2)
%  -2.949        -7.618        +1.720        +0.234        t (0, 4.13, 51.2)
%  -1.636        -6.590        +3.318        -0.291        t (0, 4.13, 51.2)
%  +1.313        -3.455        +6.082        -0.285        t (0, 3.69, 51.2)
%
%  Outcome 4:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.1105       -3.413        +3.192        -0.574        t (0, 2.93, 51.2)
%  -0.5986       -4.002        +2.805        -0.453        t (0, 2.84, 51.2)
%  -0.04114      -3.537        +3.454        -0.490        t (0, 2.84, 51.2)
%  +2.149        -1.390        +5.689        +0.200        t (0, 3.05, 51.2)
%  +2.182        -1.285        +5.649        +0.234        t (0, 3.05, 51.2)
%  +0.03243      -3.498        +3.563        -0.437        t (0, 2.72, 51.2)
%  +1.661        -1.785        +5.108        -0.100        t (0, 3.05, 51.2)
%  +2.251        -1.406        +5.908        +0.253        t (0, 3.05, 51.2)
%  +0.5899       -2.930        +4.110        -0.383        t (0, 2.72, 51.2)
%
%  Outcome 5:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.01587      -0.1188       +0.08706      -0.528        t (0, 0.0913, 51.2)
%  -0.02527      -0.1313       +0.08079      -0.400        t (0, 0.0886, 51.2)
%  -0.01165      -0.1206       +0.09729      -0.467        t (0, 0.0886, 51.2)
%  -0.07193      -0.1822       +0.03837      +0.313        t (0, 0.0949, 51.2)
%  -0.1043       -0.2123       +0.003736     +1.28         t (0, 0.0949, 51.2)
%  -0.03238      -0.1424       +0.07764      -0.260        t (0, 0.0849, 51.2)
%  -0.08133      -0.1887       +0.02607      +0.579        t (0, 0.0949, 51.2)
%  -0.1001       -0.2140       +0.01388      +1.02         t (0, 0.0949, 51.2)
%  -0.01875      -0.1284       +0.09094      -0.381        t (0, 0.0849, 51.2)
%
%  Outcome 6:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +0.07019      -0.6373       +0.7777       -0.556        t (0, 0.627, 51.2)
%  -0.002215     -0.7313       +0.7268       -0.517        t (0, 0.609, 51.2)
%  -0.2652       -1.014        +0.4836       -0.234        t (0, 0.609, 51.2)
%  +0.1060       -0.6522       +0.8641       -0.506        t (0, 0.652, 51.2)
%  +0.3759       -0.3668       +1.118        -0.0464       t (0, 0.652, 51.2)
%  +0.2699       -0.4863       +1.026        -0.177        t (0, 0.584, 51.2)
%  +0.03355      -0.7047       +0.7718       -0.569        t (0, 0.652, 51.2)
%  +0.04049      -0.7428       +0.8238       -0.508        t (0, 0.652, 51.2)
%  +0.006937     -0.7470       +0.7609       -0.440        t (0, 0.584, 51.2)
%
%  Outcome 7:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +0.01063      -0.06177      +0.08304      -0.532        t (0, 0.0642, 51.2)
%  -0.005201     -0.07981      +0.06941      -0.507        t (0, 0.0623, 51.2)
%  -0.03605      -0.1127       +0.04058      -0.0394       t (0, 0.0623, 51.2)
%  -0.01578      -0.09337      +0.06181      -0.462        t (0, 0.0668, 51.2)
%  -0.005653     -0.08165      +0.07034      -0.556        t (0, 0.0668, 51.2)
%  +0.01013      -0.06726      +0.08752      -0.402        t (0, 0.0597, 51.2)
%  -0.03162      -0.1072       +0.04393      -0.216        t (0, 0.0668, 51.2)
%  -0.05233      -0.1325       +0.02783      +0.347        t (0, 0.0668, 51.2)
%  -0.02072      -0.09788      +0.05644      -0.293        t (0, 0.0597, 51.2)
%
%  Outcome 8:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -15.56        -32.69        +1.563        +1.07         t (0, 15.2, 51.2)
%  -2.515        -20.16        +15.13        -0.475        t (0, 14.7, 51.2)
%  +7.456        -10.67        +25.58        -0.145        t (0, 14.7, 51.2)
%  -19.31        -37.67        -0.9600       +1.63         t (0, 15.8, 51.2)
%  -20.23        -38.20        -2.248        +1.91         t (0, 15.8, 51.2)
%  -0.9124       -19.22        +17.39        -0.432        t (0, 14.1, 51.2)
%  -6.264        -24.14        +11.61        -0.322        t (0, 15.8, 51.2)
%  +2.794        -16.17        +21.76        -0.469        t (0, 15.8, 51.2)
%  +9.058        -9.195        +27.31        +0.0605       t (0, 14.1, 51.2)
%
%  Outcome 9:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +17.13        -7.230        +41.50        +0.420        t (0, 21.6, 51.2)
%  +8.225        -16.88        +33.33        -0.297        t (0, 21.0, 51.2)
%  +11.56        -14.23        +37.34        -0.0806       t (0, 21.0, 51.2)
%  +0.9226       -25.18        +27.03        -0.544        t (0, 22.5, 51.2)
%  -3.048        -28.62        +22.52        -0.538        t (0, 22.5, 51.2)
%  -3.971        -30.01        +22.07        -0.390        t (0, 20.1, 51.2)
%  -7.986        -33.41        +17.44        -0.371        t (0, 22.5, 51.2)
%  -8.625        -35.60        +18.35        -0.305        t (0, 22.5, 51.2)
%  -0.6396       -26.60        +25.32        -0.439        t (0, 20.1, 51.2)
%
%  Outcome 10:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.8270       -2.944        +1.290        -0.265        t (0, 1.88, 51.2)
%  +0.4730       -1.709        +2.655        -0.420        t (0, 1.82, 51.2)
%  +0.1137       -2.127        +2.354        -0.485        t (0, 1.82, 51.2)
%  -4.059        -6.328        -1.790        +5.32         t (0, 1.95, 51.2)
%  -4.786        -7.008        -2.564        +7.56         t (0, 1.95, 51.2)
%  -0.7269       -2.990        +1.536        -0.226        t (0, 1.75, 51.2)
%  -2.759        -4.968        -0.5500       +2.45         t (0, 1.95, 51.2)
%  -3.845        -6.189        -1.501        +4.50         t (0, 1.95, 51.2)
%  -1.086        -3.342        +1.170        +0.0313       t (0, 1.75, 51.2)
%
%  Outcome 11:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -1.409        -3.363        +0.5452       +0.470        t (0, 1.73, 51.2)
%  +0.1196       -1.894        +2.133        -0.509        t (0, 1.68, 51.2)
%  +0.2623       -1.806        +2.331        -0.457        t (0, 1.68, 51.2)
%  +0.7208       -1.373        +2.815        -0.304        t (0, 1.80, 51.2)
%  +1.213        -0.8384       +3.264        +0.141        t (0, 1.80, 51.2)
%  +0.4920       -1.597        +2.581        -0.324        t (0, 1.61, 51.2)
%  +2.249        +0.2103       +4.288        +1.81         t (0, 1.80, 51.2)
%  +2.884        +0.7205       +5.048        +2.90         t (0, 1.80, 51.2)
%  +0.6347       -1.448        +2.717        -0.250        t (0, 1.61, 51.2)
%
% Elapsed time is 170.646 seconds.
