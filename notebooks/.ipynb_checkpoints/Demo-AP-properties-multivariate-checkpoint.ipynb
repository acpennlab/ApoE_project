% %% [markdown]
% My Octave Notebook
% ============
%
% Interact with Octave and the statistics-resampling package online in Jupyter Notebook with Binder. All commands are interpreted by Octave.  Since this is a [MetaKernel](https://github.com/Calysto/metakernel), a standard set of magics are available.  Help on commands is available using the `%help` magic or using `?` with a command. For the best experience, run this notebook in [Jupyter Lab](https://mybinder.org/v2/gh/acpennlab/statistics-resampling-online/master?labpath=statistics-resampling.ipynb).
%
% The code cells and their output below illustrate some examples of loading data and then performing analysis using functions from the **statistics-resampling** package. Follow the links in the **Quick start** section of the [README page](https://gnu-octave.github.io/statistics-resampling/readme.html), or on the [Function reference page](https://gnu-octave.github.io/statistics-resampling/function_reference), to find further examples. The example data files provided, **data1.tsv** and **data2.csv**, can be edited directly in this instance of JupyterLab.
%
% The statistics-resampling package already comes installed and loaded at **statistics-resampling-online**. Visit [GNU Octave Packages](https://gnu-octave.github.io/packages/) to see what other packages are available and how to install them. To load a newly installed package called `<package-name>`, use the command `pkg load <package-name>`. To preview demonstration number `X` of a function called `<function-name>`, use the command `demo ('<function-name>', X)`. To get more information about a particular function called `<function-name>`, use the command `help <function-name>`. Note that the **parallel** package cannot be installed at **statistics-resampling-online**, and that additions to the binder environment may be required to build or run some other Octave packages.

% %%
# Number formatting for outputs
format short g

% %% [markdown]
% Some Octave packages come already installed and in this statistics-resampling-online Binder environment. If you were running Octave on your own machine, you would need to install and load the statistics-resampling package first by running the code in the following two cells:

% %%
# Run this command once to install the package
pkg install "https://github.com/gnu-octave/statistics-resampling/archive/refs/heads/master.zip"

% %%
# Run this command in each new Octave session
pkg load statistics-resampling

% %% [markdown]
% Run the code in the next code cell if you wish to know:
% 1) The version of GNU Octave that you are running
% 2) What packages (and their version) are already installed (and loaded*) here
% 3) More information about the statistics-resampling package

% %%
ver('Octave');
pkg list;
pkg describe -verbose statistics-resampling
% Out:
% ----------------------------------------------------------------------
% GNU Octave Version: 8.3.0 (hg id: 6fc591af58ba)
% GNU Octave License: GNU General Public License
% Operating System: Linux 6.8.0-86-generic #87-Ubuntu SMP PREEMPT_DYNAMIC Mon Sep 22 18:03:36 UTC 2025 x86_64
% ----------------------------------------------------------------------
% Package Name           | Version   | Installation directory
% -----------------------+-----------+-----------------------
%                 coder  |     1.9.1 | .../octave/api-v58/packages/coder-1.9.1
%               control  |     4.0.0 | .../octave/api-v58/packages/control-4.0.0
%        data-smoothing  |     1.3.0 | .../api-v58/packages/data-smoothing-1.3.0
%             dataframe  |     1.2.0 | .../api-v58/packages/dataframe-1.2.0
%                fileio  |     1.2.2 | .../octave/api-v58/packages/fileio-1.2.2
%                    ga  |    0.10.4 | .../octave/api-v58/packages/ga-0.10.4
%                    io *|     2.6.4 | .../share/octave/api-v58/packages/io-2.6.4
%         miscellaneous  |     1.3.0 | .../api-v58/packages/miscellaneous-1.3.0
%                 optim  |     1.6.2 | .../octave/api-v58/packages/optim-1.6.2
%           optiminterp  |     0.3.7 | .../api-v58/packages/optiminterp-0.3.7
%                signal  |     1.4.5 | .../octave/api-v58/packages/signal-1.4.5
%               splines  |     1.3.5 | .../octave/api-v58/packages/splines-1.3.5
%            statistics *|     1.6.6 | .../api-v58/packages/statistics-1.6.6
% statistics-resampling *| 5.6.1-dev | .../statistics-resampling-5.6.1-dev
%               strings  |     1.3.1 | .../octave/api-v58/packages/strings-1.3.1
%                struct  |    1.0.18 | .../octave/api-v58/packages/struct-1.0.18
%              symbolic  |     3.2.1 | .../octave/api-v58/packages/symbolic-3.2.1
%            tablicious *|     0.4.2 | .../api-v58/packages/tablicious-0.4.2
% ---
% Package name:
% 	statistics-resampling
% Version:
% 	5.6.1-dev
% Short description:
% 	The statistics-resampling package is an Octave  package and Matlab toolbox that can be used to perform a wide  variety of statistics tasks using non-parametric resampling  methods. In particular, the functions included can be used to  estimate bias, uncertainty (standard errors and confidence  intervals), prediction error, information criteria, and  calculate p-values for null hypothesis significance tests.  Variations of the resampling methods are included that  improve the accuracy of the statistics for small samples  and samples with complex dependence structures.
% Depends on:
% 	octave >= 4.4.0
% Depended on by:
%
% Status:
% 	Loaded
% ---
% Provides:
% Cloned Matlab functions
% 	bootstrp
% 	bootci
% Main functions
% 	bootridge
% 	bootknife
% 	bootclust
% 	bootwild
% 	bootbayes
% 	randtest
% 	randtest1
% 	randtest2
% 	bootlm
% 	boot1way
% 	bootmode
% Utility Functions
% 	boot
% 	bootcdf
% 	bootint
% 	credint
% 	deffcalc
% 	sampszcalc
% Parameter functions
% 	smoothmedian
% 	smoothmad
% 	cor

% %%
# Load the predictor genotype - it has two levels: G1 and G2
[~, genotype]  = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'E2:E77');

# Load the predictor condition - it has three levels: C1, C2 and C3
[~, condition] = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'F2:F77');

# Load the animal cluster ids
animal = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'B2:B77');

# Fetch matrix of all the outcome measures
outcomes = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'G2:R77');

# Get size of the data
disp(size(genotype))
disp(size(condition))
disp(size(animal))
disp(size(outcomes))

# Note that outcomes has 12 columns: a different outcome measure for each of the 76 rows (cell recordings)
% Out:
%    76    1
%    76    1
%    76    1
%    76   12

% %%
# Fit multiple univariate linear models by ordinary least squares to each of the outcomes and save the diagnostic plots
for i = 1:size(outcomes, 2)

  # By default bootlm assumes variables listed in cell array of second input argument are categorical.
  # Set 'model' to 'full' so that it includes the interaction.
  # Set 'nboot' to 0 to bypass bootstrap resampling.
  # Set 'display' to 'on' to create diagnostic plots.
  # Set 'contrasts' to 'treatment' (dummy) coding
  MAT_T = bootlm (outcomes(:,i), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'on', ...
                  'contrasts', 'treatment');

  # Save the figure of the diagnostic plots
  print (sprintf('../output/Demo/outcome%d.png', i),'-dpng','-r300')
  
end

# Diagnostic plots shown in the output below are just for the last column.
# Figures of the diagnostic plots have been saved.

% %%
# Remove outlier (row 6) from the original data
genotype(6,:) = [];
condition(6,:) = [];
animal(6,:) = []; 
outcomes(6,:) = [];

# ... and the design matrix (X) in MAT_T
MAT_T.X(6,:) = [];

# Remove the Apnum (column 11) - it is mostly redundant with column 12 (maxApnum)
outcomes(:,11) = [];

# Get size of the data now - all should have 75 rows) 
disp(size(genotype))
disp(size(condition))
disp(size(animal))
disp(size(outcomes))
disp(size(MAT.X))
% Out:
%    75    1
%    75    1
%    75    1
%    75   11
% error: 'MAT' undefined near line 1, column 11

% %%
# Get bayesian bootstrap summary statistics of all outcomes (Simple Random Sampling)
STATS_SRS = bootbayes (outcomes, MAT_T.X);

% %%
# Get bayesian cluster bootstrap summary statistics
STATS = bootbayes (outcomes, MAT_T.X, animal);

% %%
# Estimate design effect per outcome
Deff_per_outcome = mean (STATS.stdev.^2 ./ STATS_SRS.stdev.^2, 1);
Deff = mean (Deff_per_outcome);

disp (Deff_per_outcome)
disp (Deff)
m = harmmean (accumarray (animal, 1, [], @sum));  % m is average cluster size
ICC = (Deff - 1) / (m - 1);                       % Intraclass correlation coefficient (rho)
disp (ICC)
% Out:
%  Columns 1 through 8:
%
%    1.3079   1.5383   1.8573   1.6489   1.9734   1.6451   2.1209   1.1689
%
%  Columns 9 through 11:
%
%    0.6119   0.7569   0.8611
% 1.4082
% 0.2073

% %%
# Get design matrix for orthogonal (helmert) contrast coding and hypothesis matrix for estimated marginal means
# This time we set display off. 
MAT_H = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                'contrasts', 'helmert', 'dim', [1, 2]);
                
# Get dimenions of the design matrix (which was constructed using helmert contrasts)
size (MAT_H.X)
# It has 75 rows (cell recordings) and 6 columns (1 intercept and 5 predictor terms, all categorical)
% Out:
% ans =
%
%    75    6

% %% [markdown]
% https://gnu-octave.github.io/statistics-resampling/function/bootridge.html

% %%
# Lets fit using ridge regression and use the hypothesis matrix to return the group estimated marginal means.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_H.X, [2:6], 1999, .05, MAT_H.L, Deff);
toc
ridge_emm = ans;

# Note that we expect NaN for Bayes factors (BF10) and U (-Inf, Inf) for the prior on all the linear estimates
# of the marginal means since they all involve the intercept.
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 11
%
%  Design effect (Deff): 1.41
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 10.4536
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 5.71124
%
%  Effective residual degrees of freedom (df_lambda): 71.1
%
%  Residual variances (range, Deff-inflated):  [0.0174, 1.98e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 49.3
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     Correlation   CI_lower      CI_upper
%  1             2             +0.2686       -0.01992      +0.5158
%  1             3             +0.6748       +0.4810       +0.8057
%  1             4             -0.01436      -0.3001       +0.2737
%  1             5             -0.3348       -0.5673       -0.05298
%  1             6             +0.6277       +0.4156       +0.7750
%  1             7             -0.4401       -0.6455       -0.1753
%  1             8             +0.3175       +0.03365      +0.5540
%  1             9             -0.1844       -0.4477       +0.1083
%  1             10            -0.1640       -0.4307       +0.1290
%  1             11            +0.4006       +0.1284       +0.6166
%  2             3             +0.7342       +0.5666       +0.8434
%  2             4             -0.7530       -0.8552       -0.5945
%  2             5             -0.04692      -0.3294       +0.2433
%  2             6             +0.2846       -0.002584     +0.5284
%  2             7             -0.3402       -0.5714       -0.05900
%  2             8             -0.04616      -0.3288       +0.2440
%  2             9             -0.09576      -0.3725       +0.1966
%  2             10            +0.2922       +0.005778     +0.5344
%  2             11            +0.1685       -0.1244       +0.4345
%  3             4             -0.7476       -0.8518       -0.5865
%  3             5             -0.4148       -0.6271       -0.1451
%  3             6             +0.7412       +0.5769       +0.8478
%  3             7             -0.6674       -0.8010       -0.4706
%  3             8             +0.04711      -0.2431       +0.3296
%  3             9             -0.1858       -0.4488       +0.1068
%  3             10            +0.2625       -0.02642      +0.5110
%  3             11            +0.3918       +0.1182       +0.6102
%  4             5             +0.2606       -0.02844      +0.5095
%  4             6             -0.4393       -0.6450       -0.1744
%  4             7             +0.5082       +0.2590       +0.6940
%  4             8             +0.2219       -0.06945      +0.4784
%  4             9             +0.08582      -0.2062       +0.3638
%  4             10            -0.5033       -0.6905       -0.2528
%  4             11            -0.1704       -0.4361       +0.1225
%  5             6             -0.5809       -0.7438       -0.3527
%  5             7             +0.7920       +0.6536       +0.8792
%  5             8             -0.01049      -0.2965       +0.2773
%  5             9             +0.2117       -0.08014      +0.4701
%  5             10            +0.06561      -0.2256       +0.3460
%  5             11            -0.3709       -0.5946       -0.09392
%  6             7             -0.6720       -0.8039       -0.4770
%  6             8             -0.07040      -0.3503       +0.2210
%  6             9             -0.09571      -0.3724       +0.1966
%  6             10            +0.1806       -0.1121       +0.4445
%  6             11            +0.4084       +0.1376       +0.6224
%  7             8             -0.09962      -0.3758       +0.1928
%  7             9             +0.2504       -0.03938      +0.5013
%  7             10            -0.1348       -0.4061       +0.1583
%  7             11            -0.5010       -0.6889       -0.2500
%  8             9             -0.2928       -0.5348       -0.006335
%  8             10            -0.1550       -0.4232       +0.1380
%  8             11            +0.1182       -0.1747       +0.3919
%  9             10            +0.1390       -0.1541       +0.4096
%  9             11            -0.3784       -0.6002       -0.1026
%  10            11            +0.1577       -0.1354       +0.4254
%
%  95% credible intervals and Bayes factors for linear estimates:
%  (Global ridge prior contribution to posterior precision: 41.12 %)
%
%  Outcome 1:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +44.76        +42.42        +47.09        +NaN          U (-Inf, Inf)
%  +44.41        +41.97        +46.86        +NaN          U (-Inf, Inf)
%  +43.96        +41.31        +46.62        +NaN          U (-Inf, Inf)
%  +43.11        +40.69        +45.52        +NaN          U (-Inf, Inf)
%  +45.28        +42.74        +47.81        +NaN          U (-Inf, Inf)
%  +45.04        +42.29        +47.78        +NaN          U (-Inf, Inf)
%
%  Outcome 2:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -10.79        -12.66        -8.916        +NaN          U (-Inf, Inf)
%  -11.70        -13.66        -9.744        +NaN          U (-Inf, Inf)
%  -11.97        -14.10        -9.836        +NaN          U (-Inf, Inf)
%  -13.35        -15.29        -11.42        +NaN          U (-Inf, Inf)
%  -11.74        -13.78        -9.706        +NaN          U (-Inf, Inf)
%  -13.06        -15.26        -10.85        +NaN          U (-Inf, Inf)
%
%  Outcome 3:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +82.95        +79.44        +86.47        +NaN          U (-Inf, Inf)
%  +82.72        +79.04        +86.40        +NaN          U (-Inf, Inf)
%  +79.99        +75.99        +83.99        +NaN          U (-Inf, Inf)
%  +79.74        +76.11        +83.37        +NaN          U (-Inf, Inf)
%  +81.27        +77.45        +85.09        +NaN          U (-Inf, Inf)
%  +81.07        +76.93        +85.20        +NaN          U (-Inf, Inf)
%
%  Outcome 4:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -38.20        -40.79        -35.60        +NaN          U (-Inf, Inf)
%  -38.31        -41.02        -35.59        +NaN          U (-Inf, Inf)
%  -36.03        -38.98        -33.07        +NaN          U (-Inf, Inf)
%  -36.63        -39.32        -33.95        +NaN          U (-Inf, Inf)
%  -36.00        -38.82        -33.17        +NaN          U (-Inf, Inf)
%  -36.03        -39.09        -32.98        +NaN          U (-Inf, Inf)
%
%  Outcome 5:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +1.809        +1.729        +1.890        +NaN          U (-Inf, Inf)
%  +1.794        +1.709        +1.878        +NaN          U (-Inf, Inf)
%  +1.737        +1.645        +1.829        +NaN          U (-Inf, Inf)
%  +1.711        +1.628        +1.795        +NaN          U (-Inf, Inf)
%  +1.704        +1.616        +1.792        +NaN          U (-Inf, Inf)
%  +1.693        +1.597        +1.788        +NaN          U (-Inf, Inf)
%
%  Outcome 6:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +3.986        +3.430        +4.542        +NaN          U (-Inf, Inf)
%  +4.058        +3.476        +4.640        +NaN          U (-Inf, Inf)
%  +4.092        +3.460        +4.725        +NaN          U (-Inf, Inf)
%  +4.091        +3.517        +4.666        +NaN          U (-Inf, Inf)
%  +4.367        +3.763        +4.971        +NaN          U (-Inf, Inf)
%  +4.097        +3.443        +4.750        +NaN          U (-Inf, Inf)
%
%  Outcome 7:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.9549       -1.012        -0.8980       +NaN          U (-Inf, Inf)
%  -0.9440       -1.004        -0.8844       +NaN          U (-Inf, Inf)
%  -0.9708       -1.036        -0.9060       +NaN          U (-Inf, Inf)
%  -0.9759       -1.035        -0.9172       +NaN          U (-Inf, Inf)
%  -0.9604       -1.022        -0.8985       +NaN          U (-Inf, Inf)
%  -0.9971       -1.064        -0.9302       +NaN          U (-Inf, Inf)
%
%  Outcome 8:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +90.66        +77.22        +104.1        +NaN          U (-Inf, Inf)
%  +74.86        +60.78        +88.93        +NaN          U (-Inf, Inf)
%  +71.12        +55.82        +86.42        +NaN          U (-Inf, Inf)
%  +68.61        +54.72        +82.50        +NaN          U (-Inf, Inf)
%  +70.15        +55.53        +84.76        +NaN          U (-Inf, Inf)
%  +77.84        +62.02        +93.65        +NaN          U (-Inf, Inf)
%
%  Outcome 9:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +159.3        +140.2        +178.5        +NaN          U (-Inf, Inf)
%  +176.7        +156.6        +196.7        +NaN          U (-Inf, Inf)
%  +160.3        +138.5        +182.1        +NaN          U (-Inf, Inf)
%  +168.6        +148.8        +188.3        +NaN          U (-Inf, Inf)
%  +156.3        +135.5        +177.1        +NaN          U (-Inf, Inf)
%  +167.9        +145.4        +190.4        +NaN          U (-Inf, Inf)
%
%  Outcome 10:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +22.65        +20.99        +24.31        +NaN          U (-Inf, Inf)
%  +21.81        +20.07        +23.55        +NaN          U (-Inf, Inf)
%  +18.55        +16.66        +20.44        +NaN          U (-Inf, Inf)
%  +19.04        +17.32        +20.75        +NaN          U (-Inf, Inf)
%  +17.82        +16.01        +19.63        +NaN          U (-Inf, Inf)
%  +17.94        +15.98        +19.89        +NaN          U (-Inf, Inf)
%
%  Outcome 11:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +10.51        +8.973        +12.04        +NaN          U (-Inf, Inf)
%  +9.076        +7.470        +10.68        +NaN          U (-Inf, Inf)
%  +11.22        +9.478        +12.97        +NaN          U (-Inf, Inf)
%  +11.35        +9.766        +12.94        +NaN          U (-Inf, Inf)
%  +11.72        +10.05        +13.39        +NaN          U (-Inf, Inf)
%  +12.00        +10.19        +13.80        +NaN          U (-Inf, Inf)
%
% Elapsed time is 186.142 seconds.

% %%
# Get the correlations for any pairs of outcomes involving column 11 of outcomes (Apnum)
RTAB = ridge_emm.RTAB;
contains_Apnum = any (RTAB(:,1:2) == 11, 2);
RTAB(contains_Apnum,:)
# Columns 1 and 2 are the column numbers of the matrix of outcomes for each pair
# Column 3 is the correlation coefficient between the pair of outcomes.
# Columns 4 and 5 are the lower and upper 95% credible intervals (flat prior)
% Out:
% ans =
%
%             1           11      0.40056      0.12836      0.61663
%             2           11      0.16852     -0.12445      0.43447
%             3           11      0.39184      0.11818      0.61018
%             4           11     -0.17043     -0.43606      0.12251
%             5           11     -0.37088     -0.59456    -0.093922
%             6           11       0.4084      0.13757      0.62241
%             7           11     -0.50098      -0.6889     -0.24996
%             8           11      0.11819     -0.17469      0.39185
%             9           11     -0.37843     -0.60021     -0.10263
%            10           11      0.15771     -0.13537      0.42541

% %% [markdown]
% ## Notes
%
% The outcome numbers correspond to.
% 1. peak
% 2. afterhyp
% 3. amp
% 4. thresh
% 5. half
% 6. rise
% 7. fall
% 8. IR
% 9. Rh
% 10. sag
% 11. Apnum
% 12. maxApnum
%
% maxApnum is negatively correlated with rheobase (9, -.38), fall ( 7, -.50), and half (5, -.37). Therefore, lower rheobase, faster AP repolarization and shorter AP full-width half-maximum are associated with higher AP frequency at the highest current injection.
%
% Apnum is positively correlated with AP amplitude (1, +.40), peak (3, +.39) and rise (6, +.41). Therefore, larger amplitude, peak and faster rise of APs are associated with higher AP frequency at the highest current injection.

% %%
# The contrasts coded where helmert. Lets check what those look like for genotype and condition variables
disp (MAT_H.C)
% Out:
% {
%   [1,1] =
%
%             0.5
%            -0.5
%
%   [1,2] =
%
%         0.66667            0
%        -0.33333          0.5
%        -0.33333         -0.5
%
% }

% %%
# Lets fit using ridge regression and interpret the coefficients coded with helmert contrasts.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_H.X, [2:6], 1999, .05, [], Deff);
toc
ridge_coeff = ans;
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 11
%
%  Design effect (Deff): 1.38
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 10.4536
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 5.84894
%
%  Effective residual degrees of freedom (df_lambda): 71.1
%
%  Residual variances (range, Deff-inflated):  [0.017, 1.93e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 50.6
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     Correlation   CI_lower      CI_upper
%  1             2             +0.2686       -0.01563      +0.5126
%  1             3             +0.6748       +0.4842       +0.8042
%  1             4             -0.01430      -0.2961       +0.2698
%  1             5             -0.3348       -0.5643       -0.05716
%  1             6             +0.6275       +0.4189       +0.7732
%  1             7             -0.4400       -0.6430       -0.1793
%  1             8             +0.3174       +0.03778      +0.5509
%  1             9             -0.1844       -0.4442       +0.1041
%  1             10            -0.1640       -0.4272       +0.1248
%  1             11            +0.4004       +0.1323       +0.6138
%  2             3             +0.7341       +0.5694       +0.8422
%  2             4             -0.7529       -0.8540       -0.5972
%  2             5             -0.04669      -0.3254       +0.2395
%  2             6             +0.2845       +0.001650     +0.5253
%  2             7             -0.3399       -0.5682       -0.06291
%  2             8             -0.04614      -0.3249       +0.2400
%  2             9             -0.09574      -0.3688       +0.1925
%  2             10            +0.2922       +0.01003      +0.5313
%  2             11            +0.1681       -0.1207       +0.4306
%  3             4             -0.7476       -0.8506       -0.5892
%  3             5             -0.4145       -0.6243       -0.1490
%  3             6             +0.7410       +0.5795       +0.8465
%  3             7             -0.6671       -0.7992       -0.4735
%  3             8             +0.04723      -0.2390       +0.3259
%  3             9             -0.1858       -0.4454       +0.1026
%  3             10            +0.2626       -0.02208      +0.5079
%  3             11            +0.3915       +0.1220       +0.6072
%  4             5             +0.2604       -0.02447      +0.5061
%  4             6             -0.4392       -0.6424       -0.1784
%  4             7             +0.5079       +0.2626       +0.6915
%  4             8             +0.2216       -0.06548      +0.4749
%  4             9             +0.08578      -0.2022       +0.3601
%  4             10            -0.5033       -0.6883       -0.2569
%  4             11            -0.1701       -0.4323       +0.1186
%  5             6             -0.5808       -0.7419       -0.3564
%  5             7             +0.7918       +0.6557       +0.8781
%  5             8             -0.01026      -0.2924       +0.2736
%  5             9             +0.2117       -0.07587      +0.4668
%  5             10            +0.06620      -0.2210       +0.3428
%  5             11            -0.3710       -0.5919       -0.09829
%  6             7             -0.6714       -0.8020       -0.4795
%  6             8             -0.07088      -0.3469       +0.2165
%  6             9             -0.09571      -0.3687       +0.1925
%  6             10            +0.1802       -0.1083       +0.4408
%  6             11            +0.4080       +0.1413       +0.6195
%  7             8             -0.1002       -0.3726       +0.1882
%  7             9             +0.2504       -0.03514      +0.4981
%  7             10            -0.1345       -0.4022       +0.1544
%  7             11            -0.5011       -0.6868       -0.2542
%  8             9             -0.2927       -0.5317       -0.01052
%  8             10            -0.1540       -0.4188       +0.1349
%  8             11            +0.1187       -0.1700       +0.3887
%  9             10            +0.1389       -0.1501       +0.4059
%  9             11            -0.3785       -0.5975       -0.1069
%  10            11            +0.1571       -0.1318       +0.4214
%
%  95% credible intervals and Bayes factors for regression coefficients:
%  (Global ridge prior contribution to posterior precision: 41.62 %)
%
%  Outcome 1:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +44.42        +43.17        +45.68        +NaN          U (-Inf, Inf)
%  +0.4795       -1.707        +2.666        -0.6117       t (0, 2.22, 50.6)
%  +0.2378       -1.971        +2.446        -0.6766       t (0, 2.22, 50.6)
%  -1.607        -4.225        +1.012        +0.2326       t (0, 2.22, 50.6)
%  -0.1982       -3.546        +3.150        -0.2771       t (0, 2.22, 50.6)
%  +0.6079       -3.063        +4.279        -0.1360       t (0, 2.22, 50.6)
%
%  Outcome 2:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  -12.10        -13.11        -11.09        +NaN          U (-Inf, Inf)
%  +1.199        -0.5533       +2.952        +0.2347       t (0, 1.78, 50.6)
%  +1.277        -0.4927       +3.047        +0.3484       t (0, 1.78, 50.6)
%  -0.2614       -2.360        +1.837        -0.4983       t (0, 1.78, 50.6)
%  -0.4273       -3.111        +2.256        -0.2322       t (0, 1.78, 50.6)
%  +0.07317      -2.869        +3.015        -0.1911       t (0, 1.78, 50.6)
%
%  Outcome 3:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +81.29        +79.40        +83.18        +NaN          U (-Inf, Inf)
%  +0.2287       -3.063        +3.521        -0.7004       t (0, 3.34, 50.6)
%  +2.304        -1.021        +5.629        +0.2685       t (0, 3.34, 50.6)
%  -1.295        -5.237        +2.648        -0.3094       t (0, 3.34, 50.6)
%  +0.01221      -5.029        +5.053        -0.2843       t (0, 3.34, 50.6)
%  +0.04608      -5.480        +5.573        -0.1922       t (0, 3.34, 50.6)
%
%  Outcome 4:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  -36.87        -38.26        -35.47        +NaN          U (-Inf, Inf)
%  +0.2508       -2.179        +2.681        -0.6885       t (0, 2.46, 50.6)
%  -2.066        -4.521        +0.3876       +0.7175       t (0, 2.46, 50.6)
%  -0.3124       -3.222        +2.597        -0.5065       t (0, 2.46, 50.6)
%  -0.2104       -3.931        +3.510        -0.2777       t (0, 2.46, 50.6)
%  +0.5619       -3.517        +4.641        -0.1534       t (0, 2.46, 50.6)
%
%  Outcome 5:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +1.741        +1.698        +1.785        +NaN          U (-Inf, Inf)
%  +0.01764      -0.05808      +0.09336      -0.5990       t (0, 0.0767, 50.6)
%  +0.08964      +0.01317      +0.1661       +1.980        t (0, 0.0767, 50.6)
%  +0.02567      -0.06500      +0.1163       -0.3659       t (0, 0.0767, 50.6)
%  -0.002625     -0.1186       +0.1133       -0.2833       t (0, 0.0767, 50.6)
%  +0.01370      -0.1134       +0.1408       -0.1685       t (0, 0.0767, 50.6)
%
%  Outcome 6:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +4.115        +3.816        +4.414        +NaN          U (-Inf, Inf)
%  +0.06597      -0.4545       +0.5865       -0.6774       t (0, 0.527, 50.6)
%  -0.1393       -0.6650       +0.3864       -0.5566       t (0, 0.527, 50.6)
%  -0.1389       -0.7622       +0.4844       -0.4283       t (0, 0.527, 50.6)
%  -0.2051       -1.002        +0.5919       -0.1485       t (0, 0.527, 50.6)
%  -0.2648       -1.139        +0.6089       -0.004155     t (0, 0.527, 50.6)
%
%  Outcome 7:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  -0.9672       -0.9978       -0.9366       +NaN          U (-Inf, Inf)
%  +0.01024      -0.04302      +0.06351      -0.6344       t (0, 0.0540, 50.6)
%  +0.02642      -0.02737      +0.08022      -0.2092       t (0, 0.0540, 50.6)
%  +0.005325     -0.05846      +0.06911      -0.5158       t (0, 0.0540, 50.6)
%  -0.03146      -0.1130       +0.05010      +0.01967      t (0, 0.0540, 50.6)
%  -0.03108      -0.1205       +0.05834      +0.05479      t (0, 0.0540, 50.6)
%
%  Outcome 8:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +75.54        +68.30        +82.78        +NaN          U (-Inf, Inf)
%  +3.542        -9.056        +16.14        -0.5484       t (0, 12.8, 50.6)
%  +10.78        -1.946        +23.50        +0.7339       t (0, 12.8, 50.6)
%  -4.090        -19.17        +10.99        -0.3795       t (0, 12.8, 50.6)
%  +18.14        -1.145        +37.43        +1.473        t (0, 12.8, 50.6)
%  +10.04        -11.11        +31.19        +0.2670       t (0, 12.8, 50.6)
%
%  Outcome 9:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +164.8        +154.5        +175.1        +NaN          U (-Inf, Inf)
%  -12.33        -30.26        +5.590        +0.2452       t (0, 18.2, 50.6)
%  +4.697        -13.41        +22.80        -0.5624       t (0, 18.2, 50.6)
%  +2.312        -19.15        +23.78        -0.5063       t (0, 18.2, 50.6)
%  -7.283        -34.73        +20.16        -0.1400       t (0, 18.2, 50.6)
%  +3.355        -26.73        +33.44        -0.1668       t (0, 18.2, 50.6)
%
%  Outcome 10:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +19.64        +18.74        +20.53        +NaN          U (-Inf, Inf)
%  +0.07992      -1.477        +1.637        -0.7049       t (0, 1.58, 50.6)
%  +3.872        +2.300        +5.445        +9.471        t (0, 1.58, 50.6)
%  +0.9100       -0.9545       +2.774        -0.04505      t (0, 1.58, 50.6)
%  +1.126        -1.258        +3.511        +0.1706       t (0, 1.58, 50.6)
%  -0.3626       -2.976        +2.251        -0.1528       t (0, 1.58, 50.6)
%
%  Outcome 11:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +10.98        +10.15        +11.81        +NaN          U (-Inf, Inf)
%  +0.3427       -1.095        +1.780        -0.5938       t (0, 1.46, 50.6)
%  -1.772        -3.223        -0.3199       +2.193        t (0, 1.46, 50.6)
%  -0.5659       -2.287        +1.155        -0.3089       t (0, 1.46, 50.6)
%  +1.610        -0.5913       +3.811        +0.7925       t (0, 1.46, 50.6)
%  +0.1442       -2.269        +2.557        -0.1850       t (0, 1.46, 50.6)
%
% Elapsed time is 176.718 seconds.

% %% [markdown]
% ## Interpreting the coefficients
% 1. is the intercept so represents the grand mean
% 2. is the difference between the two genotypes (G1 - G2) averaged over the conditions
% 3. is the difference between conditions (C1 - C2C3) averaged over the genotypes
% 4. is the difference between conditions (C2 - C3) averaged over the genotypes
% 5. is the difference between the two genotypes (G1 - G2) different in C1 compared to C2C3?
% 6. is the difference between the two genotypes (G1 - G2) different in C2 compared to C3?
%
% The outcome numbers correspond to.
% 1. peak
% 2. afterhyp
% 3. amp
% 4. thresh
% 5. half
% 6. rise
% 7. fall
% 8. IR
% 9. Rh
% 10. sag
% 11. Apnum
% 12. maxApnum
%
% Things I have noticed - there is strong evidence  (lnBF10 = +9.47, BF10 = 12965) for a 3.87 mV decrease in Ih sag, strong evidence for a 0.09 ms narrowing of the action potential (full-width half-maximum), and strong evidence for a 1.77 Hz increase in maximum AP firing frequency (lnBF10 = +2.19, BF10 = 8.96), with ketamine/memantine irrespective of genotype. For AP firing frequency, there is some (anecdotal) evidence to indicate that that change in firing frequency depends on genotype (lnBF10 = +0.79, BF10 = 2.21). There is good evidence for G2 having an 18 Mohm lower input resistance than G1, depending on whether the condition is C1 or C2C3 (lnBF10 = +1.47, BF10 = 4.35), specifically it is lower for G2 compared to G1 in the control condition, but not in either the C2 or C3 condition. There is also some anecdotal evidence for a 2 mV increase in AP firing threshold in C2C3 compared to C1 irrespective of genotype.

% %%
# Now lets fit the data again to get the hypothesis matrix for specific group comparisons we are interested in.
comparisons = [2 1; 4 3; 6 5; 3 1; 5 1; 5 3; 4 2; 6 2; 6 4]

# Get design matrix hypothesis matrix for estimated marginal means. We could use any outcome but we'll pick 11.
# This time we set display off. 
MAT_H_PAIRS = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                      'contrasts', 'helmert', 'dim', [1, 2], 'posthoc', comparisons);
% Out:
% comparisons =
%
%             2            1
%             4            3
%             6            5
%             3            1
%             5            1
%             5            3
%             4            2
%             6            2
%             6            4

% %%
# Lets fit using ridge regression and use the hypothesis matrix to return the comparisons of interest.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_H_PAIRS.X, [2:6], 1999, .05, MAT_H_PAIRS.L, Deff);
toc
ridge_pairs = ans;
# Note that outcome 8 is input resistance
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 11
%
%  Design effect (Deff): 1.38
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 10.4536
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 5.84894
%
%  Effective residual degrees of freedom (df_lambda): 71.1
%
%  Residual variances (range, Deff-inflated):  [0.017, 1.93e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 50.6
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     Correlation   CI_lower      CI_upper
%  1             2             +0.2686       -0.01563      +0.5126
%  1             3             +0.6748       +0.4842       +0.8042
%  1             4             -0.01430      -0.2961       +0.2698
%  1             5             -0.3348       -0.5643       -0.05716
%  1             6             +0.6275       +0.4189       +0.7732
%  1             7             -0.4400       -0.6430       -0.1793
%  1             8             +0.3174       +0.03778      +0.5509
%  1             9             -0.1844       -0.4442       +0.1041
%  1             10            -0.1640       -0.4272       +0.1248
%  1             11            +0.4004       +0.1323       +0.6138
%  2             3             +0.7341       +0.5694       +0.8422
%  2             4             -0.7529       -0.8540       -0.5972
%  2             5             -0.04669      -0.3254       +0.2395
%  2             6             +0.2845       +0.001650     +0.5253
%  2             7             -0.3399       -0.5682       -0.06291
%  2             8             -0.04614      -0.3249       +0.2400
%  2             9             -0.09574      -0.3688       +0.1925
%  2             10            +0.2922       +0.01003      +0.5313
%  2             11            +0.1681       -0.1207       +0.4306
%  3             4             -0.7476       -0.8506       -0.5892
%  3             5             -0.4145       -0.6243       -0.1490
%  3             6             +0.7410       +0.5795       +0.8465
%  3             7             -0.6671       -0.7992       -0.4735
%  3             8             +0.04723      -0.2390       +0.3259
%  3             9             -0.1858       -0.4454       +0.1026
%  3             10            +0.2626       -0.02208      +0.5079
%  3             11            +0.3915       +0.1220       +0.6072
%  4             5             +0.2604       -0.02447      +0.5061
%  4             6             -0.4392       -0.6424       -0.1784
%  4             7             +0.5079       +0.2626       +0.6915
%  4             8             +0.2216       -0.06548      +0.4749
%  4             9             +0.08578      -0.2022       +0.3601
%  4             10            -0.5033       -0.6883       -0.2569
%  4             11            -0.1701       -0.4323       +0.1186
%  5             6             -0.5808       -0.7419       -0.3564
%  5             7             +0.7918       +0.6557       +0.8781
%  5             8             -0.01026      -0.2924       +0.2736
%  5             9             +0.2117       -0.07587      +0.4668
%  5             10            +0.06620      -0.2210       +0.3428
%  5             11            -0.3710       -0.5919       -0.09829
%  6             7             -0.6714       -0.8020       -0.4795
%  6             8             -0.07088      -0.3469       +0.2165
%  6             9             -0.09571      -0.3687       +0.1925
%  6             10            +0.1802       -0.1083       +0.4408
%  6             11            +0.4080       +0.1413       +0.6195
%  7             8             -0.1002       -0.3726       +0.1882
%  7             9             +0.2504       -0.03514      +0.4981
%  7             10            -0.1345       -0.4022       +0.1544
%  7             11            -0.5011       -0.6868       -0.2542
%  8             9             -0.2927       -0.5317       -0.01052
%  8             10            -0.1540       -0.4188       +0.1349
%  8             11            +0.1187       -0.1700       +0.3887
%  9             10            +0.1389       -0.1501       +0.4059
%  9             11            -0.3785       -0.5975       -0.1069
%  10            11            +0.1571       -0.1318       +0.4214
%
%  95% credible intervals and Bayes factors for linear estimates:
%  (Global ridge prior contribution to posterior precision: 41.62 %)
%
%  Outcome 1:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.3473       -3.342        +2.648        -0.5521       t (0, 2.66, 50.6)
%  -0.8495       -3.937        +2.238        -0.3645       t (0, 2.59, 50.6)
%  -0.2416       -3.413        +2.930        -0.4809       t (0, 2.59, 50.6)
%  -0.7902       -4.000        +2.419        -0.4255       t (0, 2.77, 50.6)
%  +0.5128       -2.631        +3.656        -0.5160       t (0, 2.77, 50.6)
%  +1.303        -1.899        +4.505        -0.1024       t (0, 2.48, 50.6)
%  -1.292        -4.417        +1.832        -0.2273       t (0, 2.77, 50.6)
%  +0.6185       -2.698        +3.935        -0.4456       t (0, 2.77, 50.6)
%  +1.911        -1.282        +5.104        +0.2826       t (0, 2.48, 50.6)
%
%  Outcome 2:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.9143       -3.314        +1.486        -0.2831       t (0, 2.13, 50.6)
%  -1.378        -3.852        +1.096        +0.1105       t (0, 2.07, 50.6)
%  -1.305        -3.847        +1.236        +0.04368      t (0, 2.07, 50.6)
%  -1.176        -3.748        +1.396        -0.1237       t (0, 2.22, 50.6)
%  -0.9511       -3.470        +1.568        -0.2793       t (0, 2.22, 50.6)
%  +0.2248       -2.342        +2.791        -0.4247       t (0, 1.99, 50.6)
%  -1.640        -4.144        +0.8643       +0.2902       t (0, 2.22, 50.6)
%  -1.342        -4.000        +1.316        +0.001707     t (0, 2.22, 50.6)
%  +0.2980       -2.261        +2.857        -0.4155       t (0, 1.99, 50.6)
%
%  Outcome 3:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.2368       -4.746        +4.272        -0.5740       t (0, 4.01, 50.6)
%  -0.2477       -4.896        +4.400        -0.5138       t (0, 3.89, 50.6)
%  -0.2016       -4.976        +4.573        -0.4891       t (0, 3.89, 50.6)
%  -2.946        -7.778        +1.886        +0.2034       t (0, 4.17, 50.6)
%  -1.675        -6.407        +3.058        -0.3145       t (0, 4.17, 50.6)
%  +1.272        -3.550        +6.093        -0.2978       t (0, 3.73, 50.6)
%  -2.957        -7.661        +1.747        +0.2232       t (0, 4.17, 50.6)
%  -1.639        -6.632        +3.354        -0.2963       t (0, 4.17, 50.6)
%  +1.318        -3.489        +6.125        -0.2894       t (0, 3.73, 50.6)
%
%  Outcome 4:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.1105       -3.438        +3.217        -0.5775       t (0, 2.96, 50.6)
%  -0.6018       -4.032        +2.829        -0.4565       t (0, 2.87, 50.6)
%  -0.04000      -3.564        +3.484        -0.4925       t (0, 2.87, 50.6)
%  +2.156        -1.411        +5.723        +0.1907       t (0, 3.08, 50.6)
%  +2.187        -1.306        +5.680        +0.2233       t (0, 3.08, 50.6)
%  +0.03143      -3.527        +3.590        -0.4403       t (0, 2.75, 50.6)
%  +1.665        -1.808        +5.137        -0.1083       t (0, 3.08, 50.6)
%  +2.258        -1.427        +5.943        +0.2434       t (0, 3.08, 50.6)
%  +0.5933       -2.955        +4.141        -0.3860       t (0, 2.75, 50.6)
%
%  Outcome 5:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.01589      -0.1196       +0.08782      -0.5315       t (0, 0.0922, 50.6)
%  -0.02537      -0.1323       +0.08154      -0.4041       t (0, 0.0895, 50.6)
%  -0.01166      -0.1215       +0.09815      -0.4696       t (0, 0.0895, 50.6)
%  -0.07207      -0.1832       +0.03907      +0.3004       t (0, 0.0959, 50.6)
%  -0.1046       -0.2134       +0.004258     +1.261        t (0, 0.0959, 50.6)
%  -0.03252      -0.1434       +0.07837      -0.2642       t (0, 0.0858, 50.6)
%  -0.08154      -0.1897       +0.02666      +0.5654       t (0, 0.0959, 50.6)
%  -0.1004       -0.2152       +0.01448      +1.007        t (0, 0.0959, 50.6)
%  -0.01882      -0.1294       +0.09175      -0.3839       t (0, 0.0858, 50.6)
%
%  Outcome 6:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +0.07077      -0.6421       +0.7837       -0.5595       t (0, 0.634, 50.6)
%  -0.001911     -0.7368       +0.7329       -0.5196       t (0, 0.615, 50.6)
%  -0.2668       -1.022        +0.4881       -0.2373       t (0, 0.615, 50.6)
%  +0.1062       -0.6578       +0.8702       -0.5101       t (0, 0.659, 50.6)
%  +0.3775       -0.3707       +1.126        -0.05263      t (0, 0.659, 50.6)
%  +0.2713       -0.4910       +1.034        -0.1813       t (0, 0.590, 50.6)
%  +0.03349      -0.7103       +0.7773       -0.5724       t (0, 0.659, 50.6)
%  +0.03994      -0.7495       +0.8294       -0.5117       t (0, 0.659, 50.6)
%  +0.006449     -0.7536       +0.7665       -0.4433       t (0, 0.590, 50.6)
%
%  Outcome 7:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +0.01073      -0.06222      +0.08368      -0.5353       t (0, 0.0649, 50.6)
%  -0.005190     -0.08039      +0.07001      -0.5099       t (0, 0.0630, 50.6)
%  -0.03627      -0.1135       +0.04098      -0.04359      t (0, 0.0630, 50.6)
%  -0.01580      -0.09398      +0.06238      -0.4659       t (0, 0.0675, 50.6)
%  -0.005590     -0.08216      +0.07098      -0.5597       t (0, 0.0675, 50.6)
%  +0.01021      -0.06779      +0.08822      -0.4052       t (0, 0.0603, 50.6)
%  -0.03172      -0.1078       +0.04439      -0.2220       t (0, 0.0675, 50.6)
%  -0.05258      -0.1334       +0.02820      +0.3396       t (0, 0.0675, 50.6)
%  -0.02086      -0.09864      +0.05691      -0.2959       t (0, 0.0603, 50.6)
%
%  Outcome 8:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -15.64        -32.89        +1.615        +1.056        t (0, 15.3, 50.6)
%  -2.514        -20.30        +15.27        -0.4786       t (0, 14.9, 50.6)
%  +7.527        -10.74        +25.80        -0.1462       t (0, 14.9, 50.6)
%  -19.38        -37.87        -0.8931       +1.616        t (0, 16.0, 50.6)
%  -20.31        -38.42        -2.206        +1.895        t (0, 16.0, 50.6)
%  -0.9307       -19.38        +17.52        -0.4352       t (0, 14.3, 50.6)
%  -6.260        -24.26        +11.74        -0.3291       t (0, 16.0, 50.6)
%  +2.850        -16.26        +21.96        -0.4713       t (0, 16.0, 50.6)
%  +9.110        -9.283        +27.50        +0.05605      t (0, 14.3, 50.6)
%
%  Outcome 9:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +17.19        -7.359        +41.74        +0.4091       t (0, 21.8, 50.6)
%  +8.229        -17.08        +33.53        -0.3031       t (0, 21.2, 50.6)
%  +11.58        -14.41        +37.58        -0.08771      t (0, 21.2, 50.6)
%  +0.9390       -25.37        +27.25        -0.5471       t (0, 22.7, 50.6)
%  -3.051        -28.82        +22.71        -0.5418       t (0, 22.7, 50.6)
%  -3.990        -30.24        +22.26        -0.3930       t (0, 20.3, 50.6)
%  -8.021        -33.63        +17.59        -0.3757       t (0, 22.7, 50.6)
%  -8.656        -35.84        +18.53        -0.3094       t (0, 22.7, 50.6)
%  -0.6350       -26.81        +25.54        -0.4422       t (0, 20.3, 50.6)
%
%  Outcome 10:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.8309       -2.963        +1.302        -0.2695       t (0, 1.90, 50.6)
%  +0.4769       -1.721        +2.675        -0.4231       t (0, 1.84, 50.6)
%  +0.1143       -2.144        +2.372        -0.4875       t (0, 1.84, 50.6)
%  -4.071        -6.357        -1.786        +5.267        t (0, 1.97, 50.6)
%  -4.800        -7.038        -2.562        +7.486        t (0, 1.97, 50.6)
%  -0.7287       -3.009        +1.552        -0.2313       t (0, 1.76, 50.6)
%  -2.764        -4.988        -0.5387       +2.415        t (0, 1.97, 50.6)
%  -3.855        -6.216        -1.493        +4.451        t (0, 1.97, 50.6)
%  -1.091        -3.365        +1.182        +0.02596      t (0, 1.76, 50.6)
%
%  Outcome 11:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -1.416        -3.385        +0.5529       +0.4622       t (0, 1.75, 50.6)
%  +0.1217       -1.908        +2.151        -0.5122       t (0, 1.70, 50.6)
%  +0.2660       -1.819        +2.351        -0.4594       t (0, 1.70, 50.6)
%  +0.7199       -1.390        +2.830        -0.3115       t (0, 1.82, 50.6)
%  +1.214        -0.8526       +3.280        +0.1290       t (0, 1.82, 50.6)
%  +0.4938       -1.611        +2.599        -0.3276       t (0, 1.63, 50.6)
%  +2.257        +0.2035       +4.311        +1.794        t (0, 1.82, 50.6)
%  +2.895        +0.7153       +5.076        +2.876        t (0, 1.82, 50.6)
%  +0.6380       -1.461        +2.737        -0.2541       t (0, 1.63, 50.6)
%
% Elapsed time is 269.435 seconds.
