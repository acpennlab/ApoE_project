% %% [markdown]
% My Octave Notebook
% ============
%
% Interact with Octave and the statistics-resampling package online in Jupyter Notebook with Binder. All commands are interpreted by Octave.  Since this is a [MetaKernel](https://github.com/Calysto/metakernel), a standard set of magics are available.  Help on commands is available using the `%help` magic or using `?` with a command. For the best experience, run this notebook in [Jupyter Lab](https://mybinder.org/v2/gh/acpennlab/statistics-resampling-online/master?labpath=statistics-resampling.ipynb).
%
% The code cells and their output below illustrate some examples of loading data and then performing analysis using functions from the **statistics-resampling** package. Follow the links in the **Quick start** section of the [README page](https://gnu-octave.github.io/statistics-resampling/readme.html), or on the [Function reference page](https://gnu-octave.github.io/statistics-resampling/function_reference), to find further examples. The example data files provided, **data1.tsv** and **data2.csv**, can be edited directly in this instance of JupyterLab.
%
% The statistics-resampling package already comes installed and loaded at **statistics-resampling-online**. Visit [GNU Octave Packages](https://gnu-octave.github.io/packages/) to see what other packages are available and how to install them. To load a newly installed package called `<package-name>`, use the command `pkg load <package-name>`. To preview demonstration number `X` of a function called `<function-name>`, use the command `demo ('<function-name>', X)`. To get more information about a particular function called `<function-name>`, use the command `help <function-name>`. Note that the **parallel** package cannot be installed at **statistics-resampling-online**, and that additions to the binder environment may be required to build or run some other Octave packages.

% %%
# Number formatting for outputs
format short g

% %% [markdown]
% Some Octave packages come already installed and in this statistics-resampling-online Binder environment. If you were running Octave on your own machine, you would need to install and load the statistics-resampling package first by running the code in the following two cells:

% %%
# Run this command once to install the package
pkg install "https://github.com/gnu-octave/statistics-resampling/archive/refs/heads/master.zip"
% Out:
% The statistics-resampling package was installed into the directory:
% /home/jovyan/.local/share/octave/api-v58/packages/statistics-resampling-5.6.1-dev
% License and copyright information can be found at:
% https://github.com/gnu-octave/statistics-resampling/blob/master/COPYING

% %%
# Run this command in each new Octave session
pkg load statistics-resampling

% %% [markdown]
% Run the code in the next code cell if you wish to know:
% 1) The version of GNU Octave that you are running
% 2) What packages (and their version) are already installed (and loaded*) here
% 3) More information about the statistics-resampling package

% %%
ver('Octave');
pkg list;
pkg describe -verbose statistics-resampling
% Out:
% ----------------------------------------------------------------------
% GNU Octave Version: 8.3.0 (hg id: 6fc591af58ba)
% GNU Octave License: GNU General Public License
% Operating System: Linux 6.8.0-86-generic #87-Ubuntu SMP PREEMPT_DYNAMIC Mon Sep 22 18:03:36 UTC 2025 x86_64
% ----------------------------------------------------------------------
% Package Name           | Version   | Installation directory
% -----------------------+-----------+-----------------------
%                 coder  |     1.9.1 | .../octave/api-v58/packages/coder-1.9.1
%               control  |     4.0.0 | .../octave/api-v58/packages/control-4.0.0
%        data-smoothing  |     1.3.0 | .../api-v58/packages/data-smoothing-1.3.0
%             dataframe  |     1.2.0 | .../api-v58/packages/dataframe-1.2.0
%                fileio  |     1.2.2 | .../octave/api-v58/packages/fileio-1.2.2
%                    ga  |    0.10.4 | .../octave/api-v58/packages/ga-0.10.4
%                    io *|     2.6.4 | .../share/octave/api-v58/packages/io-2.6.4
%         miscellaneous  |     1.3.0 | .../api-v58/packages/miscellaneous-1.3.0
%                 optim  |     1.6.2 | .../octave/api-v58/packages/optim-1.6.2
%           optiminterp  |     0.3.7 | .../api-v58/packages/optiminterp-0.3.7
%                signal  |     1.4.5 | .../octave/api-v58/packages/signal-1.4.5
%               splines  |     1.3.5 | .../octave/api-v58/packages/splines-1.3.5
%            statistics *|     1.6.6 | .../api-v58/packages/statistics-1.6.6
% statistics-resampling *| 5.6.1-dev | .../statistics-resampling-5.6.1-dev
%               strings  |     1.3.1 | .../octave/api-v58/packages/strings-1.3.1
%                struct  |    1.0.18 | .../octave/api-v58/packages/struct-1.0.18
%              symbolic  |     3.2.1 | .../octave/api-v58/packages/symbolic-3.2.1
%            tablicious *|     0.4.2 | .../api-v58/packages/tablicious-0.4.2
% ---
% Package name:
% 	statistics-resampling
% Version:
% 	5.6.1-dev
% Short description:
% 	The statistics-resampling package is an Octave  package and Matlab toolbox that can be used to perform a wide  variety of statistics tasks using non-parametric resampling  methods. In particular, the functions included can be used to  estimate bias, uncertainty (standard errors and confidence  intervals), prediction error, information criteria, and  calculate p-values for null hypothesis significance tests.  Variations of the resampling methods are included that  improve the accuracy of the statistics for small samples  and samples with complex dependence structures.
% Depends on:
% 	octave >= 4.4.0
% Depended on by:
%
% Status:
% 	Loaded
% ---
% Provides:
% Cloned Matlab functions
% 	bootstrp
% 	bootci
% Main functions
% 	bootridge
% 	bootknife
% 	bootclust
% 	bootwild
% 	bootbayes
% 	randtest
% 	randtest1
% 	randtest2
% 	bootlm
% 	boot1way
% 	bootmode
% Utility Functions
% 	boot
% 	bootcdf
% 	bootint
% 	credint
% 	deffcalc
% 	sampszcalc
% Parameter functions
% 	smoothmedian
% 	smoothmad
% 	cor

% %%
# Load the predictor genotype - it has two levels: G1 and G2
[~, genotype]  = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'E2:E77');

# Load the predictor condition - it has three levels: C1, C2 and C3
[~, condition] = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'F2:F77');

# Fetch matrix of all the outcome measures
outcomes = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'G2:Q77');

# Get size of the data
disp(size(genotype))
disp(size(condition))
disp(size(outcomes))

# Note that outcomes has 11 columns: a different outcome measure for each of the 76 rows (cell recordings)
% Out:
%    76    1
%    76    1
%    76   11

% %%
# Fit multiple univariate linear models by ordinary least squares to each of the outcomes and save the diagnostic plots
for i = 1:size(outcomes, 2)

  # By default bootlm assumes variables listed in cell array of second input argument are categorical.
  # Set 'model' to 'full' so that it includes the interaction.
  # Set 'nboot' to 0 to bypass bootstrap resampling.
  # Set 'display' to 'on' to create diagnostic plots.
  MAT = bootlm (outcomes(:,i), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'on', ...
                'contrasts', 'treatment');

  # Save the figure of the diagnostic plots
  print (sprintf('../output/Demo/outcome%d.png', i),'-dpng','-r300')
  
end

% %%
# Get bayesian bootstrap summary statistics of all outcomes (Simple Random Sampling)
STATS_SRS = bootbayes (outcomes, MAT.X);

% %%
# Load the animal cluster ids
animal = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'B2:B77');

# Get bayesian cluster bootstrap summary statistics
STATS = bootbayes (outcomes, MAT.X, animal);

% %%
# Estimate design effect per outcome
Deff_per_outcome = mean (STATS.stdev.^2 ./ STATS_SRS.stdev.^2, 1);
Deff = mean (Deff_per_outcome);

disp (Deff_per_outcome)
disp (Deff)
% Out:
%  Columns 1 through 6:
%
%        1.4784       1.5473        1.836       1.1855       2.0271       1.6123
%
%  Columns 7 through 11:
%
%        2.2155       1.2989      0.64056       1.0072       1.1965
% 1.4587

% %%
# Get design matrix for orthogonal (helmert) contrast coding and hypothesis matrix for estimated marginal means
# This time we set display off. 
MAT_EMM = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                'contrasts', 'helmert', 'dim', [1, 2]);
                
# Get dimenions of the design matrix (which was constructed using helmert contrasts)
size (MAT_EMM.X)
# It has 76 rows (cell recordings) and 6 columns (1 intercept and 5 predictor terms, all categorical)
% Out:
% ans =
%
%            76            6

% %% [markdown]
% https://gnu-octave.github.io/statistics-resampling/function/bootridge.html

% %%
# Lets fit using ridge regression and use the hypothesis matrix to return the group estimated marginal means.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_EMM.X, [2:6], 1999, .05, MAT_EMM.L, Deff)
toc
ridge_emm = ans;
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 11
%
%  Design effect (Deff): 1.46
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 10.8655
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 7.42553
%
%  Effective residual degrees of freedom (df_lambda): 72.3
%
%  Residual variances (range, Deff-inflated):  [0.018, 2.04e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 48.4
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     Correlation   CI_lower      CI_upper
%  1             2             +0.2054       -0.08964      +0.4673
%  1             3             +0.5617       +0.3249       +0.7323
%  1             4             +0.2571       -0.03524      +0.5089
%  1             5             -0.3617       -0.5896       -0.08038
%  1             6             +0.5436       +0.3013       +0.7199
%  1             7             -0.4285       -0.6389       -0.1584
%  1             8             +0.1993       -0.09599      +0.4623
%  1             9             -0.1884       -0.4534       +0.1071
%  1             10            -0.5304       -0.7109       -0.2844
%  1             11            +0.4182       +0.1463       +0.6314
%  2             3             +0.7350       +0.5658       +0.8448
%  2             4             -0.6710       -0.8043       -0.4733
%  2             5             -0.03411      -0.3206       +0.2582
%  2             6             +0.2794       -0.01119      +0.5265
%  2             7             -0.3318       -0.5670       -0.04652
%  2             8             -0.03168      -0.3185       +0.2604
%  2             9             -0.09164      -0.3715       +0.2035
%  2             10            +0.1746       -0.1212       +0.4420
%  2             11            +0.1215       -0.1743       +0.3973
%  3             4             -0.6551       -0.7941       -0.4510
%  3             5             -0.3939       -0.6136       -0.1176
%  3             6             +0.7322       +0.5616       +0.8431
%  3             7             -0.6569       -0.7952       -0.4535
%  3             8             +0.05959      -0.2342       +0.3434
%  3             9             -0.1835       -0.4493       +0.1122
%  3             10            +0.1426       -0.1534       +0.4152
%  3             11            +0.3648       +0.08394      +0.5919
%  4             5             +0.1298       -0.1661       +0.4043
%  4             6             -0.3589       -0.5875       -0.07717
%  4             7             +0.3760       +0.09683      +0.6003
%  4             8             +0.1124       -0.1833       +0.3894
%  4             9             +0.04225      -0.2505       +0.3279
%  4             10            -0.6510       -0.7915       -0.4453
%  4             11            -0.04414      -0.3296       +0.2487
%  5             6             -0.5794       -0.7442       -0.3481
%  5             7             +0.7873       +0.6446       +0.8770
%  5             8             +0.03196      -0.2602       +0.3187
%  5             9             +0.2167       -0.07786      +0.4765
%  5             10            +0.1857       -0.1099       +0.4512
%  5             11            -0.3502       -0.5810       -0.06733
%  6             7             -0.6642       -0.8000       -0.4637
%  6             8             -0.09076      -0.3707       +0.2043
%  6             9             -0.09183      -0.3717       +0.2033
%  6             10            +0.04941      -0.2438       +0.3343
%  6             11            +0.4246       +0.1538       +0.6361
%  7             8             -0.09379      -0.3734       +0.2014
%  7             9             +0.2617       -0.03028      +0.5126
%  7             10            +0.03706      -0.2554       +0.3233
%  7             11            -0.4674       -0.6668       -0.2055
%  8             9             -0.2910       -0.5355       -0.001395
%  8             10            +0.06102      -0.2328       +0.3446
%  8             11            +0.07060      -0.2237       +0.3531
%  9             10            +0.1134       -0.1823       +0.3903
%  9             11            -0.3168       -0.5555       -0.02982
%  10            11            -0.08604      -0.3666       +0.2089
%
%  95% credible intervals and Bayes factors for regression coefficients:
%  (Global ridge prior contribution to posterior precision: 46.48 %)
%
%  Outcome 1:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +45.54        +43.21        +47.87        +NaN          U (-Inf, Inf)
%  -0.7926       -3.584        +1.999        -0.3687       t (0, 2.37, 48.4)
%  -1.220        -4.289        +1.848        -0.1159       t (0, 2.37, 48.4)
%  +0.1293       -2.901        +3.160        -0.4485       t (0, 2.37, 48.4)
%  -0.7426       -4.303        +2.817        -0.2017       t (0, 2.37, 48.4)
%  +0.4701       -3.227        +4.168        -0.2201       t (0, 2.37, 48.4)
%
%  Outcome 2:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  -10.99        -12.57        -9.404        +NaN          U (-Inf, Inf)
%  -0.7833       -2.682        +1.115        -0.1857       t (0, 1.61, 48.4)
%  -0.8242       -2.911        +1.262        -0.1202       t (0, 1.61, 48.4)
%  -0.6013       -2.662        +1.460        -0.2773       t (0, 1.61, 48.4)
%  -0.8008       -3.222        +1.620        -0.06667      t (0, 1.61, 48.4)
%  -0.6297       -3.144        +1.885        -0.1244       t (0, 1.61, 48.4)
%
%  Outcome 3:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +82.51        +79.53        +85.49        +NaN          U (-Inf, Inf)
%  +0.03518      -3.536        +3.606        -0.5342       t (0, 3.03, 48.4)
%  -2.149        -6.073        +1.776        +0.1706       t (0, 3.03, 48.4)
%  -0.8602       -4.737        +3.016        -0.3509       t (0, 3.03, 48.4)
%  -0.7877       -5.341        +3.766        -0.2296       t (0, 3.03, 48.4)
%  -0.3212       -5.050        +4.408        -0.2439       t (0, 3.03, 48.4)
%
%  Outcome 4:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  -36.97        -39.52        -34.42        +NaN          U (-Inf, Inf)
%  -0.8278       -3.885        +2.229        -0.3836       t (0, 2.59, 48.4)
%  +0.9286       -2.431        +4.288        -0.2829       t (0, 2.59, 48.4)
%  +0.9895       -2.329        +4.308        -0.2696       t (0, 2.59, 48.4)
%  +0.04512      -3.853        +3.943        -0.2910       t (0, 2.59, 48.4)
%  +0.7912       -3.257        +4.840        -0.1748       t (0, 2.59, 48.4)
%
%  Outcome 5:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +1.787        +1.717        +1.856        +NaN          U (-Inf, Inf)
%  -0.002473     -0.08603      +0.08109      -0.5326       t (0, 0.0709, 48.4)
%  -0.03790      -0.1297       +0.05393      -0.09109      t (0, 0.0709, 48.4)
%  -0.07144      -0.1622       +0.01927      +0.7947       t (0, 0.0709, 48.4)
%  -0.03097      -0.1375       +0.07558      -0.1177       t (0, 0.0709, 48.4)
%  -0.02116      -0.1318       +0.08950      -0.1781       t (0, 0.0709, 48.4)
%
%  Outcome 6:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +4.068        +3.597        +4.540        +NaN          U (-Inf, Inf)
%  -0.02461      -0.5896       +0.5404       -0.5305       t (0, 0.480, 48.4)
%  -0.01491      -0.6359       +0.6060       -0.4387       t (0, 0.480, 48.4)
%  +0.2513       -0.3620       +0.8646       -0.1084       t (0, 0.480, 48.4)
%  +0.06955      -0.6509       +0.7900       -0.2721       t (0, 0.480, 48.4)
%  -0.2097       -0.9580       +0.5385       -0.09191      t (0, 0.480, 48.4)
%
%  Outcome 7:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  -0.9552       -1.004        -0.9067       +NaN          U (-Inf, Inf)
%  +0.002933     -0.05515      +0.06101      -0.5291       t (0, 0.0493, 48.4)
%  -0.01553      -0.07937      +0.04830      -0.3181       t (0, 0.0493, 48.4)
%  -0.006892     -0.06994      +0.05616      -0.4276       t (0, 0.0493, 48.4)
%  -0.003093     -0.07716      +0.07097      -0.2877       t (0, 0.0493, 48.4)
%  -0.04177      -0.1187       +0.03515      +0.3473       t (0, 0.0493, 48.4)
%
%  Outcome 8:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +83.07        +71.17        +94.96        +NaN          U (-Inf, Inf)
%  -5.836        -20.09        +8.415        -0.1909       t (0, 12.1, 48.4)
%  -8.523        -24.19        +7.140        +0.1633       t (0, 12.1, 48.4)
%  -9.149        -24.62        +6.322        +0.2586       t (0, 12.1, 48.4)
%  -1.923        -20.10        +16.25        -0.2682       t (0, 12.1, 48.4)
%  +11.45        -7.421        +30.33        +0.4945       t (0, 12.1, 48.4)
%
%  Outcome 9:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +160.3        +144.0        +176.6        +NaN          U (-Inf, Inf)
%  +13.10        -6.410        +32.60        +0.3780       t (0, 16.6, 48.4)
%  -0.5668       -22.00        +20.87        -0.4385       t (0, 16.6, 48.4)
%  -4.350        -25.53        +16.83        -0.3654       t (0, 16.6, 48.4)
%  -3.597        -28.47        +21.28        -0.2482       t (0, 16.6, 48.4)
%  -0.09464      -25.93        +25.74        -0.2534       t (0, 16.6, 48.4)
%
%  Outcome 10:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +19.93        +16.84        +23.03        +NaN          U (-Inf, Inf)
%  +1.025        -2.683        +4.734        -0.3773       t (0, 3.15, 48.4)
%  -1.370        -5.446        +2.706        -0.2080       t (0, 3.15, 48.4)
%  -2.133        -6.159        +1.893        +0.1198       t (0, 3.15, 48.4)
%  -0.2544       -4.983        +4.474        -0.2853       t (0, 3.15, 48.4)
%  -0.9264       -5.838        +3.985        -0.1801       t (0, 3.15, 48.4)
%
%  Outcome 11:
%  Coefficient   CI_lower      CI_upper      lnBF10        Prior
%  +9.792        +8.372        +11.21        +NaN          U (-Inf, Inf)
%  -0.7322       -2.434        +0.9694       -0.1555       t (0, 1.44, 48.4)
%  +0.9528       -0.9173       +2.823        +0.08966      t (0, 1.44, 48.4)
%  +1.512        -0.3351       +3.359        +0.8924       t (0, 1.44, 48.4)
%  +0.8785       -1.291        +3.048        +0.04447      t (0, 1.44, 48.4)
%  +1.330        -0.9232       +3.584        +0.4550       t (0, 1.44, 48.4)
%
% ans =
%
%   scalar structure containing the fields:
%
%     Coefficient =
%
%      Columns 1 through 5:
%
%            45.544      -10.988       82.512      -36.968       1.7867
%          -0.79264     -0.78335     0.035177     -0.82781   -0.0024727
%           -1.2202     -0.82424      -2.1487      0.92856    -0.037905
%           0.12928     -0.60134     -0.86024      0.98952    -0.071439
%          -0.74261     -0.80079     -0.78773     0.045123     -0.03097
%           0.47008      -0.6297     -0.32116      0.79124    -0.021163
%
%      Columns 6 through 10:
%
%            4.0684     -0.95523       83.069       160.32       19.935
%         -0.024611    0.0029325      -5.8362       13.095       1.0253
%         -0.014914    -0.015532      -8.5233     -0.56677      -1.3699
%            0.2513   -0.0068917      -9.1489        -4.35      -2.1328
%          0.069554   -0.0030931       -1.923      -3.5971     -0.25442
%          -0.20974    -0.041771       11.453    -0.094636     -0.92644
%
%      Column 11:
%
%             9.792
%          -0.73215
%           0.95279
%            1.5121
%            0.8785
%            1.3304
%
%     CI_lower =
%
%      Columns 1 through 5:
%
%            43.214      -12.573       79.531      -39.519        1.717
%           -3.5844      -2.6818      -3.5356      -3.8847    -0.086031
%           -4.2885      -2.9108      -6.0733      -2.4313     -0.12974
%           -2.9015      -2.6623      -4.7368      -2.3291     -0.16215
%           -4.3026      -3.2216      -5.3411       -3.853     -0.13752
%           -3.2274       -3.144      -5.0504      -3.2574     -0.13183
%
%      Columns 6 through 10:
%
%            3.5969      -1.0037       71.174       144.04       16.839
%          -0.58957    -0.055147      -20.087      -6.4104      -2.6831
%          -0.63585    -0.079366      -24.186      -22.005      -5.4457
%          -0.36204    -0.069944       -24.62      -25.526      -6.1587
%          -0.65087    -0.077155      -20.095       -28.47      -4.9833
%          -0.95798     -0.11869      -7.4207      -25.928      -5.8379
%
%      Column 11:
%
%            8.3718
%           -2.4337
%          -0.91733
%          -0.33508
%           -1.2912
%          -0.92319
%
%     CI_upper =
%
%      Columns 1 through 5:
%
%            47.874      -9.4036       85.492      -34.416       1.8565
%            1.9991       1.1151        3.606       2.2291     0.081086
%            1.8482       1.2623       1.7759       4.2884     0.053933
%              3.16       1.4597       3.0163       4.3082     0.019274
%            2.8173       1.6201       3.7656       3.9432     0.075582
%            4.1675       1.8846       4.4081       4.8399     0.089504
%
%      Columns 6 through 10:
%
%              4.54     -0.90675       94.964        176.6        23.03
%           0.54035     0.061012       8.4146         32.6       4.7336
%           0.60603     0.048303       7.1395       20.871       2.7059
%           0.86463     0.056161        6.322       16.825       1.8931
%           0.78998     0.070969       16.249       21.276       4.4744
%           0.53851     0.035151       30.327       25.739        3.985
%
%      Column 11:
%
%            11.212
%           0.96938
%            2.8229
%            3.3593
%            3.0483
%            3.5839
%
%     BF10 =
%
%      Columns 1 through 5:
%
%               NaN          NaN          NaN          NaN          NaN
%           0.69164      0.83049      0.58615       0.6814       0.5871
%           0.89053      0.88675       1.1861       0.7536      0.91294
%            0.6386      0.75783      0.70407      0.76371       2.2138
%           0.81732       0.9355      0.79481      0.74751      0.88897
%           0.80245      0.88303      0.78357      0.83966      0.83686
%
%      Columns 6 through 10:
%
%               NaN          NaN          NaN          NaN          NaN
%           0.58833      0.58913       0.8262       1.4594      0.68574
%           0.64487      0.72752       1.1774      0.64503      0.81218
%           0.89723      0.65207       1.2951      0.69395       1.1273
%            0.7618      0.74999      0.76475      0.78021      0.75177
%           0.91219       1.4153       1.6397      0.77618      0.83516
%
%      Column 11:
%
%               NaN
%             0.856
%            1.0938
%            2.4409
%            1.0455
%            1.5762
%
%     lnBF10 =
%
%      Columns 1 through 5:
%
%               NaN          NaN          NaN          NaN          NaN
%           -0.3687     -0.18574     -0.53417     -0.38361     -0.53257
%          -0.11594     -0.12019      0.17064     -0.28289    -0.091088
%          -0.44847     -0.27729     -0.35088     -0.26957      0.79472
%          -0.20172    -0.066673     -0.22965     -0.29101     -0.11769
%          -0.22009     -0.12439     -0.24389     -0.17476      -0.1781
%
%      Columns 6 through 10:
%
%               NaN          NaN          NaN          NaN          NaN
%          -0.53046     -0.52912     -0.19092      0.37801     -0.37725
%          -0.43871     -0.31812      0.16333     -0.43845     -0.20804
%          -0.10844      -0.4276       0.2586     -0.36535      0.11985
%          -0.27208     -0.28769     -0.26821      -0.2482     -0.28532
%         -0.091905      0.34732      0.49453     -0.25337     -0.18013
%
%      Column 11:
%
%               NaN
%          -0.15549
%          0.089655
%           0.89238
%          0.044472
%             0.455
%
%     prior =
%     {
%       [1,1] = U (-Inf, Inf)
%       [2,1] = t (0, 2.37, 48.4)
%       [3,1] = t (0, 2.37, 48.4)
%       [4,1] = t (0, 2.37, 48.4)
%       [5,1] = t (0, 2.37, 48.4)
%       [6,1] = t (0, 2.37, 48.4)
%       [1,2] = U (-Inf, Inf)
%       [2,2] = t (0, 1.61, 48.4)
%       [3,2] = t (0, 1.61, 48.4)
%       [4,2] = t (0, 1.61, 48.4)
%       [5,2] = t (0, 1.61, 48.4)
%       [6,2] = t (0, 1.61, 48.4)
%       [1,3] = U (-Inf, Inf)
%       [2,3] = t (0, 3.03, 48.4)
%       [3,3] = t (0, 3.03, 48.4)
%       [4,3] = t (0, 3.03, 48.4)
%       [5,3] = t (0, 3.03, 48.4)
%       [6,3] = t (0, 3.03, 48.4)
%       [1,4] = U (-Inf, Inf)
%       [2,4] = t (0, 2.59, 48.4)
%       [3,4] = t (0, 2.59, 48.4)
%       [4,4] = t (0, 2.59, 48.4)
%       [5,4] = t (0, 2.59, 48.4)
%       [6,4] = t (0, 2.59, 48.4)
%       [1,5] = U (-Inf, Inf)
%       [2,5] = t (0, 0.0709, 48.4)
%       [3,5] = t (0, 0.0709, 48.4)
%       [4,5] = t (0, 0.0709, 48.4)
%       [5,5] = t (0, 0.0709, 48.4)
%       [6,5] = t (0, 0.0709, 48.4)
%       [1,6] = U (-Inf, Inf)
%       [2,6] = t (0, 0.480, 48.4)
%       [3,6] = t (0, 0.480, 48.4)
%       [4,6] = t (0, 0.480, 48.4)
%       [5,6] = t (0, 0.480, 48.4)
%       [6,6] = t (0, 0.480, 48.4)
%       [1,7] = U (-Inf, Inf)
%       [2,7] = t (0, 0.0493, 48.4)
%       [3,7] = t (0, 0.0493, 48.4)
%       [4,7] = t (0, 0.0493, 48.4)
%       [5,7] = t (0, 0.0493, 48.4)
%       [6,7] = t (0, 0.0493, 48.4)
%       [1,8] = U (-Inf, Inf)
%       [2,8] = t (0, 12.1, 48.4)
%       [3,8] = t (0, 12.1, 48.4)
%       [4,8] = t (0, 12.1, 48.4)
%       [5,8] = t (0, 12.1, 48.4)
%       [6,8] = t (0, 12.1, 48.4)
%       [1,9] = U (-Inf, Inf)
%       [2,9] = t (0, 16.6, 48.4)
%       [3,9] = t (0, 16.6, 48.4)
%       [4,9] = t (0, 16.6, 48.4)
%       [5,9] = t (0, 16.6, 48.4)
%       [6,9] = t (0, 16.6, 48.4)
%       [1,10] = U (-Inf, Inf)
%       [2,10] = t (0, 3.15, 48.4)
%       [3,10] = t (0, 3.15, 48.4)
%       [4,10] = t (0, 3.15, 48.4)
%       [5,10] = t (0, 3.15, 48.4)
%       [6,10] = t (0, 3.15, 48.4)
%       [1,11] = U (-Inf, Inf)
%       [2,11] = t (0, 1.44, 48.4)
%       [3,11] = t (0, 1.44, 48.4)
%       [4,11] = t (0, 1.44, 48.4)
%       [5,11] = t (0, 1.44, 48.4)
%       [6,11] = t (0, 1.44, 48.4)
%     }
%
%     lambda = 7.4255
%     Sigma_Y_hat =
%
%      Columns 1 through 5:
%
%            41.702        5.825       29.962        11.74     -0.45142
%             5.825       19.284        26.66      -20.835     -0.02895
%            29.962        26.66       68.224      -38.261     -0.62889
%             11.74      -20.835      -38.261       50.001      0.17746
%          -0.45142     -0.02895     -0.62889      0.17746     0.037359
%            4.5874       1.6036       7.9036      -3.3162     -0.14635
%          -0.37173     -0.19573     -0.72892      0.35719     0.020444
%            42.418      -4.5855       16.224       26.194      0.20361
%           -54.903      -18.158      -68.382       13.478       1.8902
%           -29.383       6.5778       10.106      -39.488      0.30795
%             10.63       2.1005       11.859      -1.2285     -0.26642
%
%      Columns 6 through 10:
%
%            4.5874     -0.37173       42.418      -54.903      -29.383
%            1.6036     -0.19573      -4.5855      -18.158       6.5778
%            7.9036     -0.72892       16.224      -68.382       10.106
%           -3.3162      0.35719       26.194       13.478      -39.488
%          -0.14635     0.020444      0.20361       1.8902      0.30795
%            1.7078     -0.11661      -3.9099      -5.4145      0.55387
%          -0.11661     0.018049     -0.41537       1.5865     0.042712
%           -3.9099     -0.41537       1086.6      -432.79       17.255
%           -5.4145       1.5865      -432.79       2035.7       43.894
%           0.55387     0.042712       17.255       43.894       73.583
%            2.1839     -0.24715       9.1605      -56.258      -2.9048
%
%      Column 11:
%
%             10.63
%            2.1005
%            11.859
%           -1.2285
%          -0.26642
%            2.1839
%          -0.24715
%            9.1605
%           -56.258
%           -2.9048
%            15.491
%
%     df_lambda = 72.324
%     tau2_hat =
%
%      Columns 1 through 5:
%
%             5.616      0.78445       4.0351        1.581    -0.060793
%           0.78445        2.597       3.5904      -2.8059   -0.0038987
%            4.0351       3.5904       9.1877      -5.1527    -0.084692
%             1.581      -2.8059      -5.1527       6.7336     0.023899
%         -0.060793   -0.0038987    -0.084692     0.023899    0.0050311
%           0.61779      0.21595       1.0644     -0.44659    -0.019709
%         -0.050061    -0.026359    -0.098164     0.048103    0.0027532
%            5.7124     -0.61754       2.1849       3.5275      0.02742
%           -7.3939      -2.4453       -9.209       1.8152      0.25455
%            -3.957      0.88583       1.3609      -5.3179     0.041472
%            1.4316      0.28287        1.597     -0.16544    -0.035879
%
%      Columns 6 through 10:
%
%           0.61779    -0.050061       5.7124      -7.3939       -3.957
%           0.21595    -0.026359     -0.61754      -2.4453      0.88583
%            1.0644    -0.098164       2.1849       -9.209       1.3609
%          -0.44659     0.048103       3.5275       1.8152      -5.3179
%         -0.019709    0.0027532      0.02742      0.25455     0.041472
%              0.23    -0.015704     -0.52655     -0.72918      0.07459
%         -0.015704    0.0024307    -0.055938      0.21365    0.0057521
%          -0.52655    -0.055938       146.34      -58.284       2.3237
%          -0.72918      0.21365      -58.284       274.15       5.9112
%           0.07459    0.0057521       2.3237       5.9112       9.9095
%            0.2941    -0.033284       1.2337      -7.5762     -0.39119
%
%      Column 11:
%
%            1.4316
%           0.28287
%             1.597
%          -0.16544
%         -0.035879
%            0.2941
%         -0.033284
%            1.2337
%           -7.5762
%          -0.39119
%            2.0862
%
%     Sigma_Beta =
%     {
%       [1,1] =
%
%        Columns 1 through 5:
%
%              1.3438     -0.79462      -0.7228     -0.78145      0.11347
%            -0.79462       1.9288      0.10967      0.20945     -0.81275
%             -0.7228      0.10967       2.3299      0.47536      -1.1218
%            -0.78145      0.20945      0.47536       2.2732     0.063146
%             0.11347     -0.81275      -1.1218     0.063146       3.1363
%             0.12728      -0.7362     0.075487     -0.93213      0.34856
%
%        Column 6:
%
%             0.12728
%             -0.7362
%            0.075487
%            -0.93213
%             0.34856
%              3.3832
%
%       [1,2] =
%
%        Columns 1 through 5:
%
%              0.6214     -0.36746     -0.33425     -0.36137      0.05247
%            -0.36746      0.89193     0.050716     0.096858     -0.37584
%            -0.33425     0.050716       1.0774      0.21982     -0.51876
%            -0.36137     0.096858      0.21982       1.0512     0.029201
%             0.05247     -0.37584     -0.51876     0.029201       1.4503
%             0.05886     -0.34044     0.034907     -0.43105      0.16118
%
%        Column 6:
%
%             0.05886
%            -0.34044
%            0.034907
%            -0.43105
%             0.16118
%              1.5645
%
%       [1,3] =
%
%        Columns 1 through 5:
%
%              2.1984         -1.3      -1.1825      -1.2784      0.18563
%                -1.3       3.1554      0.17942      0.34266      -1.3296
%             -1.1825      0.17942       3.8117      0.77768      -1.8352
%             -1.2784      0.34266      0.77768       3.7189       0.1033
%             0.18563      -1.3296      -1.8352       0.1033       5.1309
%             0.20823      -1.2044      0.12349      -1.5249      0.57023
%
%        Column 6:
%
%             0.20823
%             -1.2044
%             0.12349
%             -1.5249
%             0.57023
%              5.5349
%
%       [1,4] =
%
%        Columns 1 through 5:
%
%              1.6112     -0.95275     -0.86664     -0.93696      0.13605
%            -0.95275       2.3126       0.1315      0.25113     -0.97449
%            -0.86664       0.1315       2.7936      0.56996       -1.345
%            -0.93696      0.25113      0.56996       2.7256     0.075712
%             0.13605     -0.97449       -1.345     0.075712       3.7604
%             0.15261      -0.8827     0.090509      -1.1176      0.41792
%
%        Column 6:
%
%             0.15261
%             -0.8827
%            0.090509
%             -1.1176
%             0.41792
%              4.0565
%
%       [1,5] =
%
%        Columns 1 through 5:
%
%           0.0012038  -0.00071185  -0.00064752  -0.00070006   0.00010165
%         -0.00071185    0.0017279   9.8249e-05   0.00018764   -0.0007281
%         -0.00064752   9.8249e-05    0.0020872   0.00042585    -0.001005
%         -0.00070006   0.00018764   0.00042585    0.0020364   5.6569e-05
%          0.00010165   -0.0007281    -0.001005   5.6569e-05    0.0028097
%          0.00011403  -0.00065952   6.7624e-05  -0.00083504   0.00031225
%
%        Column 6:
%
%          0.00011403
%         -0.00065952
%          6.7624e-05
%         -0.00083504
%          0.00031225
%           0.0030309
%
%       [1,6] =
%
%        Columns 1 through 5:
%
%            0.055032    -0.032542    -0.029601    -0.032003    0.0046468
%           -0.032542      0.07899    0.0044914    0.0085778    -0.033285
%           -0.029601    0.0044914     0.095418     0.019468    -0.045941
%           -0.032003    0.0085778     0.019468     0.093095     0.002586
%           0.0046468    -0.033285    -0.045941     0.002586      0.12844
%           0.0052126     -0.03015    0.0030914    -0.038174     0.014275
%
%        Column 6:
%
%           0.0052126
%            -0.03015
%           0.0030914
%           -0.038174
%            0.014275
%             0.13855
%
%       [1,7] =
%
%        Columns 1 through 5:
%
%           0.0005816  -0.00034392  -0.00031284  -0.00033822    4.911e-05
%         -0.00034392    0.0008348   4.7468e-05   9.0655e-05  -0.00035177
%         -0.00031284   4.7468e-05    0.0010084   0.00020574  -0.00048553
%         -0.00033822   9.0655e-05   0.00020574   0.00098387    2.733e-05
%           4.911e-05  -0.00035177  -0.00048553    2.733e-05    0.0013574
%           5.509e-05  -0.00031864   3.2672e-05  -0.00040344   0.00015086
%
%        Column 6:
%
%           5.509e-05
%         -0.00031864
%          3.2672e-05
%         -0.00040344
%          0.00015086
%           0.0014643
%
%       [1,8] =
%
%        Columns 1 through 5:
%
%              35.015      -20.706      -18.834      -20.362       2.9566
%             -20.706       50.259       2.8577       5.4578      -21.178
%             -18.834       2.8577       60.711       12.387      -29.231
%             -20.362       5.4578       12.387       59.233       1.6454
%              2.9566      -21.178      -29.231       1.6454       81.724
%              3.3166      -19.183        1.967      -24.289       9.0824
%
%        Column 6:
%
%              3.3166
%             -19.183
%               1.967
%             -24.289
%              9.0824
%              88.158
%
%       [1,9] =
%
%        Columns 1 through 5:
%
%              65.597       -38.79      -35.284      -38.147       5.5389
%              -38.79       94.155       5.3537       10.225      -39.675
%             -35.284       5.3537       113.74       23.205      -54.762
%             -38.147       10.225       23.205       110.97       3.0825
%              5.5389      -39.675      -54.762       3.0825        153.1
%              6.2134      -35.938        3.685      -45.503       17.015
%
%        Column 6:
%
%              6.2134
%             -35.938
%               3.685
%             -45.503
%              17.015
%              165.16
%
%       [1,10] =
%
%        Columns 1 through 5:
%
%              2.3711      -1.4021      -1.2754      -1.3789      0.20021
%             -1.4021       3.4033      0.19352      0.36958      -1.4341
%             -1.2754      0.19352       4.1111      0.83877      -1.9794
%             -1.3789      0.36958      0.83877        4.011      0.11142
%             0.20021      -1.4341      -1.9794      0.11142        5.534
%             0.22459       -1.299       0.1332      -1.6447      0.61503
%
%        Column 6:
%
%             0.22459
%              -1.299
%              0.1332
%             -1.6447
%             0.61503
%              5.9697
%
%       [1,11] =
%
%        Columns 1 through 5:
%
%             0.49918     -0.29518      -0.2685     -0.29029      0.04215
%            -0.29518      0.71649      0.04074     0.077807     -0.30192
%             -0.2685      0.04074      0.86551      0.17658     -0.41672
%            -0.29029     0.077807      0.17658      0.84443     0.023457
%             0.04215     -0.30192     -0.41672     0.023457       1.1651
%            0.047282     -0.27348     0.028041     -0.34626      0.12948
%
%        Column 6:
%
%            0.047282
%            -0.27348
%            0.028041
%            -0.34626
%             0.12948
%              1.2568
%
%     }
%
%     nboot =  1999
%     Deff = 1.4587
%     tol = 5.8504e+08
%     iter =    17
%     pred_err = 10.866
%     R_table =
%
%                 1            2      0.20541    -0.089638      0.46731
%                 1            3      0.56173       0.3249      0.73227
%                 1            4      0.25709    -0.035243       0.5089
%                 1            5     -0.36167      -0.5896     -0.08038
%                 1            6      0.54358      0.30133      0.71992
%                 1            7     -0.42847     -0.63887     -0.15843
%                 1            8      0.19926    -0.095988      0.46229
%                 1            9     -0.18843     -0.45339      0.10712
%                 1           10     -0.53042     -0.71089     -0.28442
%                 1           11      0.41824      0.14625      0.63144
%                 2            3      0.73501      0.56578      0.84483
%                 2            4     -0.67098     -0.80433     -0.47327
%                 2            5    -0.034107     -0.32065      0.25815
%                 2            6      0.27942    -0.011191      0.52651
%                 2            7     -0.33176     -0.56697    -0.046519
%                 2            8    -0.031677     -0.31846      0.26042
%                 2            9    -0.091642     -0.37149      0.20347
%                 2           10      0.17462     -0.12123      0.44197
%                 2           11      0.12153     -0.17432      0.39725
%                 3            4     -0.65509     -0.79409     -0.45097
%                 3            5     -0.39392      -0.6136     -0.11764
%                 3            6      0.73221      0.56163      0.84308
%                 3            7     -0.65687     -0.79525     -0.45346
%                 3            8     0.059587     -0.23417      0.34337
%                 3            9     -0.18349     -0.44931      0.11218
%                 3           10      0.14263     -0.15342      0.41518
%                 3           11      0.36478     0.083944      0.59194
%                 4            5      0.12984     -0.16611      0.40434
%                 4            6     -0.35886     -0.58749    -0.077172
%                 4            7      0.37599      0.09683      0.60031
%                 4            8      0.11237      -0.1833      0.38941
%                 4            9     0.042247     -0.25053      0.32794
%                 4           10     -0.65101     -0.79145     -0.44528
%                 4           11    -0.044141     -0.32964      0.24875
%                 5            6     -0.57941      -0.7442     -0.34813
%                 5            7       0.7873      0.64462      0.87698
%                 5            8     0.031957     -0.26016      0.31872
%                 5            9      0.21674    -0.077855      0.47653
%                 5           10      0.18574     -0.10989      0.45117
%                 5           11     -0.35021     -0.58097    -0.067331
%                 6            7     -0.66419     -0.79997     -0.46371
%                 6            8    -0.090761     -0.37072      0.20432
%                 6            9    -0.091828     -0.37165      0.20329
%                 6           10     0.049408     -0.24379      0.33433
%                 6           11      0.42458      0.15379      0.63605
%                 7            8     -0.09379     -0.37336      0.20139
%                 7            9      0.26173     -0.03028      0.51257
%                 7           10     0.037062     -0.25539       0.3233
%                 7           11     -0.46741     -0.66682     -0.20553
%                 8            9     -0.29099     -0.53555   -0.0013946
%                 8           10      0.06102      -0.2328      0.34464
%                 8           11     0.070605     -0.22368      0.35309
%                 9           10      0.11341     -0.18229       0.3903
%                 9           11     -0.31679     -0.55552    -0.029822
%                10           11    -0.086036     -0.36661      0.20888
%
%
% Elapsed time is 165.904 seconds.

% %%
# Get the correlations for any pairs of outcomes involving column 11 of outcomes (Apnum)
rtab = ridge_emm.R_table;
contains_Apnum = any(rtab(:,1:2) == 11, 2);
format short g
rtab(contains_Apnum,:)
# Columns 1 and 2 are the column numbers of the matrix of outcomes for each pair
# Column 3 is the correlation coefficient between the pair of outcomes.
# Columns 4 and 5 are the lower and upper 95% credible intervals (flat prior)
% Out:
% ans =
%
%             1           11      0.41481      0.20041       0.5913
%             2           11      0.10856     -0.12854      0.33393
%             3           11      0.35748      0.13491       0.5457
%             4           11    -0.037484     -0.26897      0.19809
%             5           11     -0.35969     -0.54748      -0.1374
%             6           11      0.41852      0.20472      0.59421
%             7           11     -0.47223     -0.63586     -0.26799
%             8           11     0.074563     -0.16211      0.30312
%             9           11     -0.31152     -0.50833    -0.083781
%            10           11    -0.094045     -0.32083      0.14294

% %% [markdown]
% ## Notes
%
% Apnum is negatively correlated with rheobase (9, -.31), fall ( 7, -.47), and half (5, -.36). Therefore, lower rheobase, faster AP repolarization and shorter AP full-width half-maximum are associated with higher AP frequency at the highest current injection.
%
% Apnum is positively correlated with AP amplitude (1, +.41), peak (3, +.36) and rise (6, +.42). Therefore, larger amplitude, peak and faster rise of APs are associated with higher AP frequency at the highest current injection.

% %%
# Now lets fit the data and get the comparisons
comparisons = [1 2; 3 4; 5 6; 1 3; 1 5; 3 5; 2 4; 2 6; 4 6]
% Out:
% comparisons =
%
%             1            2
%             3            4
%             5            6
%             1            3
%             1            5
%             2            4
%             2            6

% %%
MAT = bootlm (maxApnum, {genotype, condition}, 'model', 'full', 'display', 'on', 'nboot', 0, ...
              'contrasts', 'helmert', 'seed', 1, 'dim', [1, 2], 'posthoc', comparisons)
