% %% [markdown]
% My Octave Notebook
% ============
%
% Interact with Octave and the statistics-resampling package online in Jupyter Notebook with Binder. All commands are interpreted by Octave.  Since this is a [MetaKernel](https://github.com/Calysto/metakernel), a standard set of magics are available.  Help on commands is available using the `%help` magic or using `?` with a command. For the best experience, run this notebook in [Jupyter Lab](https://mybinder.org/v2/gh/acpennlab/statistics-resampling-online/master?labpath=statistics-resampling.ipynb).
%
% The code cells and their output below illustrate some examples of loading data and then performing analysis using functions from the **statistics-resampling** package. Follow the links in the **Quick start** section of the [README page](https://gnu-octave.github.io/statistics-resampling/readme.html), or on the [Function reference page](https://gnu-octave.github.io/statistics-resampling/function_reference), to find further examples. The example data files provided, **data1.tsv** and **data2.csv**, can be edited directly in this instance of JupyterLab.
%
% The statistics-resampling package already comes installed and loaded at **statistics-resampling-online**. Visit [GNU Octave Packages](https://gnu-octave.github.io/packages/) to see what other packages are available and how to install them. To load a newly installed package called `<package-name>`, use the command `pkg load <package-name>`. To preview demonstration number `X` of a function called `<function-name>`, use the command `demo ('<function-name>', X)`. To get more information about a particular function called `<function-name>`, use the command `help <function-name>`. Note that the **parallel** package cannot be installed at **statistics-resampling-online**, and that additions to the binder environment may be required to build or run some other Octave packages.

% %%
# Number formatting for outputs
format short g

% %% [markdown]
% Some Octave packages come already installed and in this statistics-resampling-online Binder environment. If you were running Octave on your own machine, you would need to install and load the statistics-resampling package first by running the code in the following two cells:

% %%
# Run this command once to install the package
pkg install "https://github.com/gnu-octave/statistics-resampling/archive/refs/heads/master.zip"
% Out:
% The statistics-resampling package was installed into the directory:
% /home/jovyan/.local/share/octave/api-v58/packages/statistics-resampling-5.6.1-dev
% License and copyright information can be found at:
% https://github.com/gnu-octave/statistics-resampling/blob/master/COPYING

% %%
# Run this command in each new Octave session
pkg load statistics-resampling

% %% [markdown]
% Run the code in the next code cell if you wish to know:
% 1) The version of GNU Octave that you are running
% 2) What packages (and their version) are already installed (and loaded*) here
% 3) More information about the statistics-resampling package

% %%
ver('Octave');
pkg list;
pkg describe -verbose statistics-resampling
% Out:
% ----------------------------------------------------------------------
% GNU Octave Version: 8.3.0 (hg id: 6fc591af58ba)
% GNU Octave License: GNU General Public License
% Operating System: Linux 6.8.0-86-generic #87-Ubuntu SMP PREEMPT_DYNAMIC Mon Sep 22 18:03:36 UTC 2025 x86_64
% ----------------------------------------------------------------------
% Package Name           | Version   | Installation directory
% -----------------------+-----------+-----------------------
%                 coder  |     1.9.1 | .../octave/api-v58/packages/coder-1.9.1
%               control  |     4.0.0 | .../octave/api-v58/packages/control-4.0.0
%        data-smoothing  |     1.3.0 | .../api-v58/packages/data-smoothing-1.3.0
%             dataframe  |     1.2.0 | .../api-v58/packages/dataframe-1.2.0
%                fileio  |     1.2.2 | .../octave/api-v58/packages/fileio-1.2.2
%                    ga  |    0.10.4 | .../octave/api-v58/packages/ga-0.10.4
%                    io *|     2.6.4 | .../share/octave/api-v58/packages/io-2.6.4
%         miscellaneous  |     1.3.0 | .../api-v58/packages/miscellaneous-1.3.0
%                 optim  |     1.6.2 | .../octave/api-v58/packages/optim-1.6.2
%           optiminterp  |     0.3.7 | .../api-v58/packages/optiminterp-0.3.7
%                signal  |     1.4.5 | .../octave/api-v58/packages/signal-1.4.5
%               splines  |     1.3.5 | .../octave/api-v58/packages/splines-1.3.5
%            statistics *|     1.6.6 | .../api-v58/packages/statistics-1.6.6
% statistics-resampling *| 5.6.1-dev | .../statistics-resampling-5.6.1-dev
%               strings  |     1.3.1 | .../octave/api-v58/packages/strings-1.3.1
%                struct  |    1.0.18 | .../octave/api-v58/packages/struct-1.0.18
%              symbolic  |     3.2.1 | .../octave/api-v58/packages/symbolic-3.2.1
%            tablicious *|     0.4.2 | .../api-v58/packages/tablicious-0.4.2
% ---
% Package name:
% 	statistics-resampling
% Version:
% 	5.6.1-dev
% Short description:
% 	The statistics-resampling package is an Octave  package and Matlab toolbox that can be used to perform a wide  variety of statistics tasks using non-parametric resampling  methods. In particular, the functions included can be used to  estimate bias, uncertainty (standard errors and confidence  intervals), prediction error, information criteria, and  calculate p-values for null hypothesis significance tests.  Variations of the resampling methods are included that  improve the accuracy of the statistics for small samples  and samples with complex dependence structures.
% Depends on:
% 	octave >= 4.4.0
% Depended on by:
%
% Status:
% 	Loaded
% ---
% Provides:
% Cloned Matlab functions
% 	bootstrp
% 	bootci
% Main functions
% 	bootridge
% 	bootknife
% 	bootclust
% 	bootwild
% 	bootbayes
% 	randtest
% 	randtest1
% 	randtest2
% 	bootlm
% 	boot1way
% 	bootmode
% Utility Functions
% 	boot
% 	bootcdf
% 	bootint
% 	credint
% 	deffcalc
% 	sampszcalc
% Parameter functions
% 	smoothmedian
% 	smoothmad
% 	cor

% %%
# Load the predictor genotype - it has two levels: G1 and G2
[~, genotype]  = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'E2:E77');

# Load the predictor condition - it has three levels: C1, C2 and C3
[~, condition] = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'F2:F77');

# Fetch matrix of all the outcome measures
outcomes = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'G2:Q77');

# Get size of the data
disp(size(genotype))
disp(size(condition))
disp(size(outcomes))

# Note that outcomes has 11 columns: a different outcome measure for each of the 76 rows (cell recordings)
% Out:
%    76    1
%    76    1
%    76   11

% %%
# Fit multiple univariate linear models by ordinary least squares to each of the outcomes and save the diagnostic plots
for i = 1:size(outcomes, 2)

  # By default bootlm assumes variables listed in cell array of second input argument are categorical.
  # Set 'model' to 'full' so that it includes the interaction.
  # Set 'nboot' to 0 to bypass bootstrap resampling.
  # Set 'display' to 'on' to create diagnostic plots.
  MAT = bootlm (outcomes(:,i), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'on', ...
                'contrasts', 'treatment');

  # Save the figure of the diagnostic plots
  print (sprintf('../output/Demo/outcome%d.png', i),'-dpng','-r300')
  
end

# Diagnostic plots shown in the output below are just for the last column, Apnum.
# Figures of the diagnostic plots have been saved.

% %%
# Get bayesian bootstrap summary statistics of all outcomes (Simple Random Sampling)
STATS_SRS = bootbayes (outcomes, MAT.X);

% %%
# Load the animal cluster ids
animal = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'B2:B77');

# Get bayesian cluster bootstrap summary statistics
STATS = bootbayes (outcomes, MAT.X, animal);

% %%
# Estimate design effect per outcome
Deff_per_outcome = mean (STATS.stdev.^2 ./ STATS_SRS.stdev.^2, 1);
Deff = mean (Deff_per_outcome);

disp (Deff_per_outcome)
disp (Deff)
% Out:
%  Columns 1 through 6:
%
%        1.4784       1.5473        1.836       1.1855       2.0271       1.6123
%
%  Columns 7 through 11:
%
%        2.2155       1.2989      0.64056       1.0072       1.1965
% 1.4587

% %%
# Get design matrix for orthogonal (helmert) contrast coding and hypothesis matrix for estimated marginal means
# This time we set display off. 
MAT_EMM = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                'contrasts', 'helmert', 'dim', [1, 2]);
                
# Get dimenions of the design matrix (which was constructed using helmert contrasts)
size (MAT_EMM.X)
# It has 76 rows (cell recordings) and 6 columns (1 intercept and 5 predictor terms, all categorical)
% Out:
% ans =
%
%            76            6

% %% [markdown]
% https://gnu-octave.github.io/statistics-resampling/function/bootridge.html

% %%
# Lets fit using ridge regression and use the hypothesis matrix to return the group estimated marginal means.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_EMM.X, [2:6], 1999, .05, MAT_EMM.L, Deff);
toc
ridge_emm = ans;

# Note that we expect NaN for Bayes factors (BF10) and U (-Inf, Inf) for the prior on all the linear estimates
# of the marginal means since they all involve the intercept.
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 11
%
%  Design effect (Deff): 1.46
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 10.7885
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 9.30848
%
%  Effective residual degrees of freedom (df_lambda): 72.6
%
%  Residual variances (range, Deff-inflated):  [0.0181, 2.02e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 48.7
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     Correlation   CI_lower      CI_upper
%  1             2             +0.2059       -0.08833      +0.4670
%  1             3             +0.5619       +0.3259       +0.7320
%  1             4             +0.2595       -0.03181      +0.5102
%  1             5             -0.3655       -0.5919       -0.08562
%  1             6             +0.5444       +0.3031       +0.7201
%  1             7             -0.4281       -0.6381       -0.1588
%  1             8             +0.1987       -0.09574      +0.4612
%  1             9             -0.1853       -0.4502       +0.1095
%  1             10            -0.5346       -0.7133       -0.2905
%  1             11            +0.4193       +0.1483       +0.6317
%  2             3             +0.7337       +0.5645       +0.8438
%  2             4             -0.6682       -0.8022       -0.4699
%  2             5             -0.03350      -0.3193       +0.2579
%  2             6             +0.2819       -0.007611     +0.5279
%  2             7             -0.3260       -0.5620       -0.04096
%  2             8             -0.03918      -0.3244       +0.2526
%  2             9             -0.09300      -0.3719       +0.2014
%  2             10            +0.1724       -0.1227       +0.4394
%  2             11            +0.1178       -0.1771       +0.3934
%  3             4             -0.6530       -0.7924       -0.4487
%  3             5             -0.3997       -0.6173       -0.1252
%  3             6             +0.7364       +0.5684       +0.8454
%  3             7             -0.6549       -0.7936       -0.4513
%  3             8             +0.05227      -0.2403       +0.3361
%  3             9             -0.1830       -0.4483       +0.1118
%  3             10            +0.1383       -0.1569       +0.4108
%  3             11            +0.3674       +0.08783      +0.5934
%  4             5             +0.1320       -0.1632       +0.4055
%  4             6             -0.3613       -0.5888       -0.08078
%  4             7             +0.3726       +0.09377      +0.5972
%  4             8             +0.1209       -0.1741       +0.3960
%  4             9             +0.04402      -0.2481       +0.3288
%  4             10            -0.6509       -0.7911       -0.4458
%  4             11            -0.04510      -0.3297       +0.2471
%  5             6             -0.5761       -0.7416       -0.3445
%  5             7             +0.7903       +0.6497       +0.8786
%  5             8             +0.01579      -0.2744       +0.3033
%  5             9             +0.2181       -0.07557      +0.4770
%  5             10            +0.1828       -0.1121       +0.4481
%  5             11            -0.3535       -0.5829       -0.07186
%  6             7             -0.6602       -0.7971       -0.4587
%  6             8             -0.08311      -0.3633       +0.2109
%  6             9             -0.09734      -0.3757       +0.1971
%  6             10            +0.05302      -0.2396       +0.3368
%  6             11            +0.4244       +0.1544       +0.6354
%  7             8             -0.09446      -0.3732       +0.1999
%  7             9             +0.2541       -0.03759      +0.5059
%  7             10            +0.04029      -0.2516       +0.3254
%  7             11            -0.4690       -0.6675       -0.2083
%  8             9             -0.2812       -0.5273       +0.008418
%  8             10            +0.04986      -0.2426       +0.3340
%  8             11            +0.07058      -0.2229       +0.3523
%  9             10            +0.1133       -0.1816       +0.3894
%  9             11            -0.3093       -0.5492       -0.02236
%  10            11            -0.08609      -0.3659       +0.2080
%
%  95% credible intervals and Bayes factors for linear estimates:
%  (Global ridge prior contribution to posterior:precision: 51.41 %)
%
%  Outcome 1:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +45.71        +43.13        +48.28        +NaN          U (-Inf, Inf)
%  +44.65        +41.92        +47.38        +NaN          U (-Inf, Inf)
%  +44.25        +41.34        +47.16        +NaN          U (-Inf, Inf)
%  +43.32        +40.63        +46.02        +NaN          U (-Inf, Inf)
%  +45.36        +42.54        +48.17        +NaN          U (-Inf, Inf)
%  +44.88        +41.88        +47.87        +NaN          U (-Inf, Inf)
%
%  Outcome 2:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -10.96        -12.71        -9.210        +NaN          U (-Inf, Inf)
%  -11.78        -13.63        -9.926        +NaN          U (-Inf, Inf)
%  -12.00        -13.98        -10.02        +NaN          U (-Inf, Inf)
%  -13.18        -15.01        -11.34        +NaN          U (-Inf, Inf)
%  -11.79        -13.71        -9.880        +NaN          U (-Inf, Inf)
%  -12.91        -14.94        -10.87        +NaN          U (-Inf, Inf)
%
%  Outcome 3:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +82.74        +79.46        +86.02        +NaN          U (-Inf, Inf)
%  +82.53        +79.05        +86.01        +NaN          U (-Inf, Inf)
%  +80.21        +76.50        +83.92        +NaN          U (-Inf, Inf)
%  +79.97        +76.53        +83.41        +NaN          U (-Inf, Inf)
%  +81.27        +77.68        +84.86        +NaN          U (-Inf, Inf)
%  +81.08        +77.26        +84.90        +NaN          U (-Inf, Inf)
%
%  Outcome 4:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -37.03        -39.85        -34.22        +NaN          U (-Inf, Inf)
%  -37.88        -40.86        -34.90        +NaN          U (-Inf, Inf)
%  -35.96        -39.14        -32.78        +NaN          U (-Inf, Inf)
%  -36.65        -39.59        -33.70        +NaN          U (-Inf, Inf)
%  -35.91        -38.98        -32.84        +NaN          U (-Inf, Inf)
%  -36.20        -39.48        -32.93        +NaN          U (-Inf, Inf)
%
%  Outcome 5:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +1.793        +1.717        +1.870        +NaN          U (-Inf, Inf)
%  +1.785        +1.704        +1.866        +NaN          U (-Inf, Inf)
%  +1.735        +1.648        +1.822        +NaN          U (-Inf, Inf)
%  +1.716        +1.636        +1.796        +NaN          U (-Inf, Inf)
%  +1.709        +1.625        +1.793        +NaN          U (-Inf, Inf)
%  +1.700        +1.611        +1.790        +NaN          U (-Inf, Inf)
%
%  Outcome 6:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +4.018        +3.499        +4.537        +NaN          U (-Inf, Inf)
%  +4.059        +3.508        +4.609        +NaN          U (-Inf, Inf)
%  +4.106        +3.519        +4.693        +NaN          U (-Inf, Inf)
%  +4.092        +3.548        +4.636        +NaN          U (-Inf, Inf)
%  +4.317        +3.749        +4.885        +NaN          U (-Inf, Inf)
%  +4.114        +3.509        +4.719        +NaN          U (-Inf, Inf)
%
%  Outcome 7:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.9593       -1.013        -0.9057       +NaN          U (-Inf, Inf)
%  -0.9492       -1.006        -0.8924       +NaN          U (-Inf, Inf)
%  -0.9706       -1.031        -0.9101       +NaN          U (-Inf, Inf)
%  -0.9750       -1.031        -0.9189       +NaN          U (-Inf, Inf)
%  -0.9636       -1.022        -0.9051       +NaN          U (-Inf, Inf)
%  -0.9899       -1.052        -0.9276       +NaN          U (-Inf, Inf)
%
%  Outcome 8:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +87.27        +74.44        +100.1        +NaN          U (-Inf, Inf)
%  +75.47        +61.87        +89.07        +NaN          U (-Inf, Inf)
%  +71.77        +57.26        +86.28        +NaN          U (-Inf, Inf)
%  +69.49        +56.04        +82.93        +NaN          U (-Inf, Inf)
%  +71.51        +57.48        +85.55        +NaN          U (-Inf, Inf)
%  +76.43        +61.49        +91.37        +NaN          U (-Inf, Inf)
%
%  Outcome 9:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +159.5        +141.6        +177.4        +NaN          U (-Inf, Inf)
%  +174.6        +155.7        +193.6        +NaN          U (-Inf, Inf)
%  +160.4        +140.2        +180.6        +NaN          U (-Inf, Inf)
%  +168.4        +149.6        +187.1        +NaN          U (-Inf, Inf)
%  +157.2        +137.7        +176.8        +NaN          U (-Inf, Inf)
%  +167.6        +146.8        +188.5        +NaN          U (-Inf, Inf)
%
%  Outcome 10:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +20.14        +16.74        +23.55        +NaN          U (-Inf, Inf)
%  +21.05        +17.44        +24.66        +NaN          U (-Inf, Inf)
%  +18.29        +14.43        +22.14        +NaN          U (-Inf, Inf)
%  +19.08        +15.51        +22.65        +NaN          U (-Inf, Inf)
%  +17.68        +13.96        +21.41        +NaN          U (-Inf, Inf)
%  +18.23        +14.26        +22.19        +NaN          U (-Inf, Inf)
%
%  Outcome 11:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +9.855        +8.292        +11.42        +NaN          U (-Inf, Inf)
%  +8.900        +7.244        +10.56        +NaN          U (-Inf, Inf)
%  +10.92        +9.153        +12.69        +NaN          U (-Inf, Inf)
%  +11.00        +9.365        +12.64        +NaN          U (-Inf, Inf)
%  +11.36        +9.649        +13.07        +NaN          U (-Inf, Inf)
%  +11.59        +9.775        +13.41        +NaN          U (-Inf, Inf)
%
% Elapsed time is 238.8 seconds.

% %%
# Get the correlations for any pairs of outcomes involving column 11 of outcomes (Apnum)
rtab = ridge_emm.R_table;
contains_Apnum = any(rtab(:,1:2) == 11, 2);
format short g
rtab(contains_Apnum,:)
# Columns 1 and 2 are the column numbers of the matrix of outcomes for each pair
# Column 3 is the correlation coefficient between the pair of outcomes.
# Columns 4 and 5 are the lower and upper 95% credible intervals (flat prior)
% Out:
% ans =
%
%             1           11      0.41929      0.14832       0.6317
%             2           11      0.11783     -0.17714      0.39337
%             3           11      0.36744     0.087833      0.59338
%             4           11    -0.045099     -0.32974      0.24706
%             5           11     -0.35346     -0.58287    -0.071863
%             6           11       0.4244       0.1544      0.63542
%             7           11       -0.469     -0.66749     -0.20829
%             8           11     0.070581      -0.2229      0.35233
%             9           11     -0.30929     -0.54915    -0.022356
%            10           11    -0.086094     -0.36593      0.20802

% %% [markdown]
% ## Notes
%
% Apnum is negatively correlated with rheobase (9, -.31), fall ( 7, -.47), and half (5, -.36). Therefore, lower rheobase, faster AP repolarization and shorter AP full-width half-maximum are associated with higher AP frequency at the highest current injection.
%
% Apnum is positively correlated with AP amplitude (1, +.41), peak (3, +.36) and rise (6, +.42). Therefore, larger amplitude, peak and faster rise of APs are associated with higher AP frequency at the highest current injection.

% %%
# Now lets fit the data again to get the hypothesis matrix for specific group comparisons we are interested in.
comparisons = [1 2; 3 4; 5 6; 1 3; 1 5; 3 5; 2 4; 2 6; 4 6]
# Get design matrix hypothesis matrix for estimated marginal means
# This time we set display off. 
MAT_PAIRS = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                'contrasts', 'helmert', 'dim', [1, 2], 'posthoc', comparisons);
% Out:
% comparisons =
%
%             1            2
%             3            4
%             5            6
%             1            3
%             1            5
%             3            5
%             2            4
%             2            6
%             4            6

% %%
# Lets fit using ridge regression and use the hypothesis matrix to return the comparisons of interest.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_PAIRS.X, [2:6], 1999, .05, MAT_PAIRS.L, Deff);
toc
ridge_pairs = ans;
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 11
%
%  Design effect (Deff): 1.46
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 10.7885
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 9.30848
%
%  Effective residual degrees of freedom (df_lambda): 72.6
%
%  Residual variances (range, Deff-inflated):  [0.0181, 2.02e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 48.7
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     Correlation   CI_lower      CI_upper
%  1             2             +0.2059       -0.08833      +0.4670
%  1             3             +0.5619       +0.3259       +0.7320
%  1             4             +0.2595       -0.03181      +0.5102
%  1             5             -0.3655       -0.5919       -0.08562
%  1             6             +0.5444       +0.3031       +0.7201
%  1             7             -0.4281       -0.6381       -0.1588
%  1             8             +0.1987       -0.09574      +0.4612
%  1             9             -0.1853       -0.4502       +0.1095
%  1             10            -0.5346       -0.7133       -0.2905
%  1             11            +0.4193       +0.1483       +0.6317
%  2             3             +0.7337       +0.5645       +0.8438
%  2             4             -0.6682       -0.8022       -0.4699
%  2             5             -0.03350      -0.3193       +0.2579
%  2             6             +0.2819       -0.007611     +0.5279
%  2             7             -0.3260       -0.5620       -0.04096
%  2             8             -0.03918      -0.3244       +0.2526
%  2             9             -0.09300      -0.3719       +0.2014
%  2             10            +0.1724       -0.1227       +0.4394
%  2             11            +0.1178       -0.1771       +0.3934
%  3             4             -0.6530       -0.7924       -0.4487
%  3             5             -0.3997       -0.6173       -0.1252
%  3             6             +0.7364       +0.5684       +0.8454
%  3             7             -0.6549       -0.7936       -0.4513
%  3             8             +0.05227      -0.2403       +0.3361
%  3             9             -0.1830       -0.4483       +0.1118
%  3             10            +0.1383       -0.1569       +0.4108
%  3             11            +0.3674       +0.08783      +0.5934
%  4             5             +0.1320       -0.1632       +0.4055
%  4             6             -0.3613       -0.5888       -0.08078
%  4             7             +0.3726       +0.09377      +0.5972
%  4             8             +0.1209       -0.1741       +0.3960
%  4             9             +0.04402      -0.2481       +0.3288
%  4             10            -0.6509       -0.7911       -0.4458
%  4             11            -0.04510      -0.3297       +0.2471
%  5             6             -0.5761       -0.7416       -0.3445
%  5             7             +0.7903       +0.6497       +0.8786
%  5             8             +0.01579      -0.2744       +0.3033
%  5             9             +0.2181       -0.07557      +0.4770
%  5             10            +0.1828       -0.1121       +0.4481
%  5             11            -0.3535       -0.5829       -0.07186
%  6             7             -0.6602       -0.7971       -0.4587
%  6             8             -0.08311      -0.3633       +0.2109
%  6             9             -0.09734      -0.3757       +0.1971
%  6             10            +0.05302      -0.2396       +0.3368
%  6             11            +0.4244       +0.1544       +0.6354
%  7             8             -0.09446      -0.3732       +0.1999
%  7             9             +0.2541       -0.03759      +0.5059
%  7             10            +0.04029      -0.2516       +0.3254
%  7             11            -0.4690       -0.6675       -0.2083
%  8             9             -0.2812       -0.5273       +0.008418
%  8             10            +0.04986      -0.2426       +0.3340
%  8             11            +0.07058      -0.2229       +0.3523
%  9             10            +0.1133       -0.1816       +0.3894
%  9             11            -0.3093       -0.5492       -0.02236
%  10            11            -0.08609      -0.3659       +0.2080
%
%  95% credible intervals and Bayes factors for linear estimates:
%  (Global ridge prior contribution to posterior:precision: 51.41 %)
%
%  Outcome 1:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +1.056        -2.201        +4.314        -0.2357       t (0, 2.55, 48.7)
%  +0.9288       -2.398        +4.256        -0.2406       t (0, 2.47, 48.7)
%  +0.4812       -2.914        +3.877        -0.3390       t (0, 2.47, 48.7)
%  +1.456        -2.018        +4.930        -0.06688      t (0, 2.65, 48.7)
%  +0.3485       -3.076        +3.773        -0.4196       t (0, 2.65, 48.7)
%  -1.108        -4.544        +2.329        -0.1125       t (0, 2.37, 48.7)
%  +1.329        -2.098        +4.755        -0.1322       t (0, 2.65, 48.7)
%  -0.2268       -3.817        +3.364        -0.3853       t (0, 2.65, 48.7)
%  -1.555        -4.983        +1.872        +0.09252      t (0, 2.37, 48.7)
%
%  Outcome 2:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +0.8199       -1.396        +3.035        -0.1708       t (0, 1.73, 48.7)
%  +1.178        -1.084        +3.441        +0.1523       t (0, 1.68, 48.7)
%  +1.112        -1.198        +3.421        +0.09267      t (0, 1.68, 48.7)
%  +1.038        -1.324        +3.401        -0.03143      t (0, 1.80, 48.7)
%  +0.8335       -1.495        +3.162        -0.1783       t (0, 1.80, 48.7)
%  -0.2049       -2.542        +2.132        -0.3099       t (0, 1.61, 48.7)
%  +1.397        -0.9334       +3.728        +0.2898       t (0, 1.80, 48.7)
%  +1.125        -1.317        +3.567        +0.04033      t (0, 1.80, 48.7)
%  -0.2719       -2.603        +2.059        -0.3004       t (0, 1.61, 48.7)
%
%  Outcome 3:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +0.2096       -3.944        +4.364        -0.4463       t (0, 3.25, 48.7)
%  +0.2394       -4.003        +4.482        -0.3942       t (0, 3.15, 48.7)
%  +0.1884       -4.142        +4.518        -0.3764       t (0, 3.15, 48.7)
%  +2.532        -1.898        +6.962        +0.2382       t (0, 3.38, 48.7)
%  +1.472        -2.894        +5.839        -0.2076       t (0, 3.38, 48.7)
%  -1.060        -5.442        +3.322        -0.2054       t (0, 3.02, 48.7)
%  +2.562        -1.807        +6.932        +0.2587       t (0, 3.38, 48.7)
%  +1.451        -3.127        +6.030        -0.1873       t (0, 3.38, 48.7)
%  -1.111        -5.482        +3.260        -0.1956       t (0, 3.02, 48.7)
%
%  Outcome 4:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +0.8468       -2.711        +4.405        -0.3350       t (0, 2.78, 48.7)
%  +0.6893       -2.944        +4.323        -0.3267       t (0, 2.70, 48.7)
%  +0.2928       -3.416        +4.001        -0.3675       t (0, 2.70, 48.7)
%  -1.076        -4.870        +2.718        -0.2612       t (0, 2.89, 48.7)
%  -1.124        -4.864        +2.616        -0.2554       t (0, 2.89, 48.7)
%  -0.04786      -3.801        +3.706        -0.3254       t (0, 2.59, 48.7)
%  -1.234        -4.976        +2.509        -0.2172       t (0, 2.89, 48.7)
%  -1.678        -5.599        +2.243        -0.01891      t (0, 2.89, 48.7)
%  -0.4444       -4.188        +3.299        -0.2994       t (0, 2.59, 48.7)
%
%  Outcome 5:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +0.008449     -0.08867      +0.1056       -0.4359       t (0, 0.0759, 48.7)
%  +0.01929      -0.07989      +0.1185       -0.3229       t (0, 0.0737, 48.7)
%  +0.008888     -0.09234      +0.1101       -0.3645       t (0, 0.0737, 48.7)
%  +0.05823      -0.04534      +0.1618       +0.2168       t (0, 0.0789, 48.7)
%  +0.08412      -0.01796      +0.1862       +0.9209       t (0, 0.0789, 48.7)
%  +0.02589      -0.07656      +0.1283       -0.1945       t (0, 0.0706, 48.7)
%  +0.06907      -0.03308      +0.1712       +0.4848       t (0, 0.0789, 48.7)
%  +0.08456      -0.02248      +0.1916       +0.8608       t (0, 0.0789, 48.7)
%  +0.01549      -0.08670      +0.1177       -0.2811       t (0, 0.0706, 48.7)
%
%  Outcome 6:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.04045      -0.6980       +0.6171       -0.4437       t (0, 0.514, 48.7)
%  +0.01420      -0.6573       +0.6857       -0.3998       t (0, 0.499, 48.7)
%  +0.2031       -0.4823       +0.8885       -0.2000       t (0, 0.499, 48.7)
%  -0.08763      -0.7888       +0.6136       -0.3943       t (0, 0.534, 48.7)
%  -0.2990       -0.9901       +0.3922       -0.05818      t (0, 0.534, 48.7)
%  -0.2113       -0.9050       +0.4823       -0.1351       t (0, 0.478, 48.7)
%  -0.03298      -0.7246       +0.6587       -0.4355       t (0, 0.534, 48.7)
%  -0.05543      -0.7801       +0.6693       -0.3815       t (0, 0.534, 48.7)
%  -0.02245      -0.7143       +0.6693       -0.3262       t (0, 0.478, 48.7)
%
%  Outcome 7:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.01010      -0.07791      +0.05772      -0.4059       t (0, 0.0530, 48.7)
%  +0.004393     -0.06486      +0.07365      -0.3925       t (0, 0.0514, 48.7)
%  +0.02628      -0.04441      +0.09696      -0.09705      t (0, 0.0514, 48.7)
%  +0.01136      -0.06096      +0.08368      -0.3756       t (0, 0.0551, 48.7)
%  +0.004361     -0.06692      +0.07564      -0.4332       t (0, 0.0551, 48.7)
%  -0.007002     -0.07854      +0.06454      -0.3060       t (0, 0.0493, 48.7)
%  +0.02585      -0.04548      +0.09719      -0.1709       t (0, 0.0551, 48.7)
%  +0.04074      -0.03401      +0.1155       +0.2114       t (0, 0.0551, 48.7)
%  +0.01488      -0.05647      +0.08623      -0.2389       t (0, 0.0493, 48.7)
%
%  Outcome 8:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +11.81        -4.442        +28.05        +0.6136       t (0, 12.7, 48.7)
%  +2.283        -14.31        +18.88        -0.3618       t (0, 12.3, 48.7)
%  -4.914        -21.85        +12.02        -0.2074       t (0, 12.3, 48.7)
%  +15.50        -1.823        +32.83        +1.171        t (0, 13.2, 48.7)
%  +15.76        -1.319        +32.84        +1.255        t (0, 13.2, 48.7)
%  +0.2552       -16.89        +17.40        -0.3253       t (0, 11.8, 48.7)
%  +5.982        -11.11        +23.07        -0.1890       t (0, 13.2, 48.7)
%  -0.9602       -18.87        +16.95        -0.3876       t (0, 13.2, 48.7)
%  -6.942        -24.04        +10.15        +0.009199     t (0, 11.8, 48.7)
%
%  Outcome 9:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -15.18        -37.85        +7.478        +0.4570       t (0, 17.7, 48.7)
%  -7.999        -31.14        +15.15        -0.1557       t (0, 17.2, 48.7)
%  -10.39        -34.01        +13.23        +0.01522      t (0, 17.2, 48.7)
%  -0.9343       -25.10        +23.23        -0.4234       t (0, 18.4, 48.7)
%  +2.229        -21.59        +26.05        -0.4229       t (0, 18.4, 48.7)
%  +3.164        -20.74        +27.07        -0.2897       t (0, 16.5, 48.7)
%  +6.251        -17.59        +30.09        -0.2989       t (0, 18.4, 48.7)
%  +7.025        -17.95        +32.00        -0.2310       t (0, 18.4, 48.7)
%  +0.7741       -23.07        +24.62        -0.3262       t (0, 16.5, 48.7)
%
%  Outcome 10:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  -0.9061       -5.219        +3.407        -0.3607       t (0, 3.37, 48.7)
%  -0.7962       -5.201        +3.608        -0.3335       t (0, 3.27, 48.7)
%  -0.5430       -5.038        +3.952        -0.3503       t (0, 3.27, 48.7)
%  +1.858        -2.741        +6.458        -0.09225      t (0, 3.51, 48.7)
%  +2.459        -2.074        +6.992        +0.1584       t (0, 3.51, 48.7)
%  +0.6010       -3.949        +5.151        -0.2898       t (0, 3.14, 48.7)
%  +1.968        -2.568        +6.505        -0.05521      t (0, 3.51, 48.7)
%  +2.822        -1.931        +7.576        +0.3228       t (0, 3.51, 48.7)
%  +0.8542       -3.683        +5.392        -0.2555       t (0, 3.14, 48.7)
%
%  Outcome 11:
%  Estimate      CI_lower      CI_upper      lnBF10        Prior
%  +0.9551       -1.024        +2.934        +0.02406      t (0, 1.55, 48.7)
%  -0.08190      -2.103        +1.939        -0.3974       t (0, 1.50, 48.7)
%  -0.2368       -2.300        +1.826        -0.3532       t (0, 1.50, 48.7)
%  -1.065        -3.175        +1.045        +0.09293      t (0, 1.61, 48.7)
%  -1.502        -3.582        +0.5776       +0.6119       t (0, 1.61, 48.7)
%  -0.4375       -2.525        +1.650        -0.2354       t (0, 1.44, 48.7)
%  -2.102        -4.184        -0.02026      +1.577        t (0, 1.61, 48.7)
%  -2.694        -4.875        -0.5133       +2.568        t (0, 1.61, 48.7)
%  -0.5924       -2.675        +1.490        -0.1621       t (0, 1.44, 48.7)
%
% Elapsed time is 177.194 seconds.
