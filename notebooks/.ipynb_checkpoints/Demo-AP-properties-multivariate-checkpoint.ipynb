% %% [markdown]
% My Octave Notebook
% ============
%
% Interact with Octave and the statistics-resampling package online in Jupyter Notebook with Binder. All commands are interpreted by Octave.  Since this is a [MetaKernel](https://github.com/Calysto/metakernel), a standard set of magics are available.  Help on commands is available using the `%help` magic or using `?` with a command. For the best experience, run this notebook in [Jupyter Lab](https://mybinder.org/v2/gh/acpennlab/statistics-resampling-online/master?labpath=statistics-resampling.ipynb).
%
% The code cells and their output below illustrate some examples of loading data and then performing analysis using functions from the **statistics-resampling** package. Follow the links in the **Quick start** section of the [README page](https://gnu-octave.github.io/statistics-resampling/readme.html), or on the [Function reference page](https://gnu-octave.github.io/statistics-resampling/function_reference), to find further examples. The example data files provided, **data1.tsv** and **data2.csv**, can be edited directly in this instance of JupyterLab.
%
% The statistics-resampling package already comes installed and loaded at **statistics-resampling-online**. Visit [GNU Octave Packages](https://gnu-octave.github.io/packages/) to see what other packages are available and how to install them. To load a newly installed package called `<package-name>`, use the command `pkg load <package-name>`. To preview demonstration number `X` of a function called `<function-name>`, use the command `demo ('<function-name>', X)`. To get more information about a particular function called `<function-name>`, use the command `help <function-name>`. Note that the **parallel** package cannot be installed at **statistics-resampling-online**, and that additions to the binder environment may be required to build or run some other Octave packages.

% %%
# Number formatting for outputs
format short g

% %% [markdown]
% Some Octave packages come already installed and in this statistics-resampling-online Binder environment. If you were running Octave on your own machine, you would need to install and load the statistics-resampling package first by running the code in the following two cells:

% %%
# Run this command once to install the package
pkg install "https://github.com/gnu-octave/statistics-resampling/archive/refs/heads/master.zip"
% Out:
% The statistics-resampling package was installed into the directory:
% /home/jovyan/.local/share/octave/api-v58/packages/statistics-resampling-5.6.1-dev
% License and copyright information can be found at:
% https://github.com/gnu-octave/statistics-resampling/blob/master/COPYING

% %%
# Run this command in each new Octave session
pkg load statistics-resampling

% %% [markdown]
% Run the code in the next code cell if you wish to know:
% 1) The version of GNU Octave that you are running
% 2) What packages (and their version) are already installed (and loaded*) here
% 3) More information about the statistics-resampling package

% %%
ver('Octave');
pkg list;
pkg describe -verbose statistics-resampling
% Out:
% ----------------------------------------------------------------------
% GNU Octave Version: 8.3.0 (hg id: 6fc591af58ba)
% GNU Octave License: GNU General Public License
% Operating System: Linux 6.8.0-86-generic #87-Ubuntu SMP PREEMPT_DYNAMIC Mon Sep 22 18:03:36 UTC 2025 x86_64
% ----------------------------------------------------------------------
% Package Name           | Version   | Installation directory
% -----------------------+-----------+-----------------------
%                 coder  |     1.9.1 | .../octave/api-v58/packages/coder-1.9.1
%               control  |     4.0.0 | .../octave/api-v58/packages/control-4.0.0
%        data-smoothing  |     1.3.0 | .../api-v58/packages/data-smoothing-1.3.0
%             dataframe  |     1.2.0 | .../api-v58/packages/dataframe-1.2.0
%                fileio  |     1.2.2 | .../octave/api-v58/packages/fileio-1.2.2
%                    ga  |    0.10.4 | .../octave/api-v58/packages/ga-0.10.4
%                    io *|     2.6.4 | .../share/octave/api-v58/packages/io-2.6.4
%         miscellaneous  |     1.3.0 | .../api-v58/packages/miscellaneous-1.3.0
%                 optim  |     1.6.2 | .../octave/api-v58/packages/optim-1.6.2
%           optiminterp  |     0.3.7 | .../api-v58/packages/optiminterp-0.3.7
%                signal  |     1.4.5 | .../octave/api-v58/packages/signal-1.4.5
%               splines  |     1.3.5 | .../octave/api-v58/packages/splines-1.3.5
%            statistics *|     1.6.6 | .../api-v58/packages/statistics-1.6.6
% statistics-resampling *| 5.6.1-dev | .../statistics-resampling-5.6.1-dev
%               strings  |     1.3.1 | .../octave/api-v58/packages/strings-1.3.1
%                struct  |    1.0.18 | .../octave/api-v58/packages/struct-1.0.18
%              symbolic  |     3.2.1 | .../octave/api-v58/packages/symbolic-3.2.1
%            tablicious *|     0.4.2 | .../api-v58/packages/tablicious-0.4.2
% ---
% Package name:
% 	statistics-resampling
% Version:
% 	5.6.1-dev
% Short description:
% 	The statistics-resampling package is an Octave  package and Matlab toolbox that can be used to perform a wide  variety of statistics tasks using non-parametric resampling  methods. In particular, the functions included can be used to  estimate bias, uncertainty (standard errors and confidence  intervals), prediction error, information criteria, and  calculate p-values for null hypothesis significance tests.  Variations of the resampling methods are included that  improve the accuracy of the statistics for small samples  and samples with complex dependence structures.
% Depends on:
% 	octave >= 4.4.0
% Depended on by:
%
% Status:
% 	Loaded
% ---
% Provides:
% Cloned Matlab functions
% 	bootstrp
% 	bootci
% Main functions
% 	bootridge
% 	bootknife
% 	bootclust
% 	bootwild
% 	bootbayes
% 	randtest
% 	randtest1
% 	randtest2
% 	bootlm
% 	boot1way
% 	bootmode
% Utility Functions
% 	boot
% 	bootcdf
% 	bootint
% 	credint
% 	deffcalc
% 	sampszcalc
% Parameter functions
% 	smoothmedian
% 	smoothmad
% 	cor

% %%
# Load the predictor genotype - it has two levels: G1 and G2
[~, genotype]  = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'E2:E77');

# Load the predictor condition - it has three levels: C1, C2 and C3
[~, condition] = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'F2:F77');

# Load the animal cluster ids
animal = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'B2:B77');

# Fetch matrix of all the outcome measures
outcomes = xlsread ('../data/basic_properties_data_coded.xlsx', 'OGS', 'G2:R77');

# Get size of the data
disp(size(genotype))
disp(size(condition))
disp(size(animal))
disp(size(outcomes))

# Note that outcomes has 12 columns: a different outcome measure for each of the 76 rows (cell recordings)
% Out:
%            76            1
%            76            1
%            76            1
%            76           12

% %%
# Fit multiple univariate linear models by ordinary least squares to each of the outcomes and save the diagnostic plots
for i = 1:size(outcomes, 2)

  # By default bootlm assumes variables listed in cell array of second input argument are categorical.
  # Set 'model' to 'full' so that it includes the interaction.
  # Set 'nboot' to 0 to bypass bootstrap resampling.
  # Set 'display' to 'on' to create diagnostic plots.
  # Set 'contrasts' to 'treatment' (dummy) coding
  MAT_T = bootlm (outcomes(:,i), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'on', ...
                  'contrasts', 'treatment');

  # Save the figure of the diagnostic plots
  print (sprintf('../output/Demo/outcome%d.png', i),'-dpng','-r300')
  
end

# Diagnostic plots shown in the output below are just for the last column.
# Figures of the diagnostic plots have been saved.

% %%
if (size (outcomes, 1) > 75)

  # Remove outlier (row 6) from the original data
  genotype(6,:) = [];
  condition(6,:) = [];
  animal(6,:) = []; 
  outcomes(6,:) = [];

  # ... and the design matrix (X) in MAT_T
  MAT_T.X(6,:) = [];

  # Remove the Apnum (column 11) - it is mostly redundant with column 12 (maxApnum)
  outcomes(:,11) = [];

end

# Get size of the data now - all should have 75 rows) 
disp(size(genotype))
disp(size(condition))
disp(size(animal))
disp(size(outcomes))
disp(size(MAT_T.X))
% Out:
%            75            1
%            75            1
%            75            1
%            75           11
%            75            6

% %%
# Get bayesian bootstrap summary statistics of all outcomes (Simple Random Sampling)
STATS_SRS = bootbayes (outcomes, MAT_T.X);

% %%
# Get bayesian cluster bootstrap summary statistics
STATS = bootbayes (outcomes, MAT_T.X, animal);

% %%
# Estimate design effect per outcome
Deff_per_outcome = mean (STATS.stdev.^2 ./ STATS_SRS.stdev.^2, 1);
Deff = mean (Deff_per_outcome);

disp (Deff_per_outcome)
disp (Deff)
m = harmmean (accumarray (animal, 1, [], @sum));  % m is average cluster size
ICC = (Deff - 1) / (m - 1);                       % Intraclass correlation coefficient (rho)
disp (ICC)
% Out:
%  Columns 1 through 6:
%
%        1.3904       1.5368       1.8988       1.5905       2.0372       1.6315
%
%  Columns 7 through 11:
%
%        2.1756        1.235      0.61728      0.74737      0.87976
% 1.4309
% 0.21885

% %%
# Get design matrix for orthogonal (helmert) contrast coding and hypothesis matrix for estimated marginal means
# This time we set display off.
MAT_H = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                'contrasts', 'helmert', 'dim', [1, 2]);
MAT_H.C
MAT_H = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                'contrasts', MAT_H.C, 'dim', [1, 2]);
# Get dimenions of the design matrix (which was constructed using sign-flipped helmert contrasts)
size (MAT_H.X)
# It has 75 rows (cell recordings) and 6 columns (1 intercept and 5 predictor terms, all categorical)
% Out:
% ans =
% {
%   [1,1] =
%
%            -0.5
%             0.5
%
%   [1,2] =
%
%        -0.66667            0
%         0.33333         -0.5
%         0.33333          0.5
%
% }
%
% ans =
%
%            75            6

% %% [markdown]
% https://gnu-octave.github.io/statistics-resampling/function/bootridge.html

% %%
# Lets fit using ridge regression and interpret the coefficients coded with sign-flipped helmert contrasts.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_H.X, '*', 1999, .05, [], Deff);
toc
ridge_coeff = ans;
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 11
%
%  Design effect (Deff): 1.43
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 10.4536
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 5.62071
%
%  Effective residual degrees of freedom (df_lambda): 71.0
%
%  Residual variances (range, Deff-inflated):  [0.0177, 2.01e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 48.5
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     correlation   CI_lower      CI_upper
%  1             2             +0.2686       -0.01962      +0.5155
%  1             3             +0.6748       +0.4812       +0.8056
%  1             4             -0.01441      -0.2998       +0.2734
%  1             5             -0.3349       -0.5671       -0.05335
%  1             6             +0.6278       +0.4160       +0.7750
%  1             7             -0.4401       -0.6454       -0.1756
%  1             8             +0.3176       +0.03405      +0.5539
%  1             9             -0.1844       -0.4475       +0.1079
%  1             10            -0.1640       -0.4304       +0.1287
%  1             11            +0.4007       +0.1288       +0.6165
%  2             3             +0.7342       +0.5668       +0.8434
%  2             4             -0.7531       -0.8551       -0.5948
%  2             5             -0.04708      -0.3293       +0.2429
%  2             6             +0.2846       -0.002247     +0.5282
%  2             7             -0.3404       -0.5713       -0.05954
%  2             8             -0.04617      -0.3285       +0.2437
%  2             9             -0.09577      -0.3722       +0.1963
%  2             10            +0.2923       +0.006102     +0.5342
%  2             11            +0.1688       -0.1239       +0.4344
%  3             4             -0.7476       -0.8517       -0.5867
%  3             5             -0.4149       -0.6270       -0.1456
%  3             6             +0.7413       +0.5773       +0.8478
%  3             7             -0.6676       -0.8010       -0.4711
%  3             8             +0.04703      -0.2429       +0.3293
%  3             9             -0.1859       -0.4486       +0.1065
%  3             10            +0.2625       -0.02615      +0.5107
%  3             11            +0.3921       +0.1188       +0.6102
%  4             5             +0.2608       -0.02793      +0.5094
%  4             6             -0.4394       -0.6449       -0.1748
%  4             7             +0.5084       +0.2596       +0.6940
%  4             8             +0.2221       -0.06896      +0.4783
%  4             9             +0.08585      -0.2059       +0.3636
%  4             10            -0.5032       -0.6903       -0.2531
%  4             11            -0.1707       -0.4360       +0.1220
%  5             6             -0.5809       -0.7437       -0.3530
%  5             7             +0.7922       +0.6540       +0.8792
%  5             8             -0.01063      -0.2964       +0.2769
%  5             9             +0.2117       -0.07984      +0.4698
%  5             10            +0.06522      -0.2257       +0.3454
%  5             11            -0.3708       -0.5943       -0.09414
%  6             7             -0.6723       -0.8040       -0.4777
%  6             8             -0.07008      -0.3497       +0.2210
%  6             9             -0.09571      -0.3722       +0.1963
%  6             10            +0.1809       -0.1115       +0.4445
%  6             11            +0.4087       +0.1382       +0.6224
%  7             8             -0.09925      -0.3752       +0.1929
%  7             9             +0.2504       -0.03904      +0.5011
%  7             10            -0.1350       -0.4060       +0.1577
%  7             11            -0.5009       -0.6887       -0.2501
%  8             9             -0.2928       -0.5346       -0.006709
%  8             10            -0.1557       -0.4235       +0.1371
%  8             11            +0.1178       -0.1748       +0.3913
%  9             10            +0.1391       -0.1537       +0.4094
%  9             11            -0.3784       -0.6000       -0.1029
%  10            11            +0.1581       -0.1347       +0.4255
%
%  95% credible intervals and Bayes factors for regression coefficients.
%  Global ridge prior contribution to posterior precision: 40.79 %
%  Stability selection (SS): >97.5% for the (-) or (+) sign of the coefficient.
%  Deff-adjusted SS probabilities are reported in S.stability
%
%  Outcome 1:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +44.43        +43.14        +45.71        +NaN          U (-Inf, Inf)
%  -0.4823       -2.727        +1.762        -0.630        t (0, 2.31, 48.5)
%  -0.2391       -2.506        +2.028        -0.693        t (0, 2.31, 48.5)
%  +1.628        -1.065        +4.321        +0.199        t (0, 2.31, 48.5)
%  -0.2017       -3.660        +3.257        -0.286        t (0, 2.31, 48.5)
%  +0.6240       -3.176        +4.424        -0.143        t (0, 2.31, 48.5)
%
%  Outcome 2:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  -12.10        -13.13        -11.07        +NaN          U (-Inf, Inf)
%  -1.211        -3.009        +0.5881       +0.191        t (0, 1.85, 48.5)
%  -1.289        -3.106        +0.5272       +0.302        t (0, 1.85, 48.5)
%  +0.2630       -1.895        +2.421        -0.513        t (0, 1.85, 48.5)
%  -0.4386       -3.210        +2.333        -0.241        t (0, 1.85, 48.5)
%  +0.07347      -2.972        +3.119        -0.198        t (0, 1.85, 48.5)
%
%  Outcome 3:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +81.29        +79.36        +83.22        +NaN          U (-Inf, Inf)
%  -0.2289       -3.608        +3.150        -0.716        t (0, 3.47, 48.5)
%  -2.326        -5.739        +1.086        +0.225        t (0, 3.47, 48.5)
%  +1.311        -2.743        +5.366        -0.328        t (0, 3.47, 48.5)
%  +0.01266      -5.194        +5.219        -0.293        t (0, 3.47, 48.5)
%  +0.04533      -5.676        +5.767        -0.199        t (0, 3.47, 48.5)
%
%  Outcome 4:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  -36.86        -38.29        -35.44        +NaN          U (-Inf, Inf)
%  -0.2534       -2.747        +2.241        -0.704        t (0, 2.56, 48.5)
%  +2.087        -0.4316       +4.606        +0.661        t (0, 2.56, 48.5)
%  +0.3168       -2.675        +3.309        -0.520        t (0, 2.56, 48.5)
%  -0.2144       -4.057        +3.629        -0.287        t (0, 2.56, 48.5)
%  +0.5786       -3.644        +4.801        -0.160        t (0, 2.56, 48.5)
%
%  Outcome 5:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +1.741        +1.697        +1.786        +NaN          U (-Inf, Inf)
%  -0.01781      -0.09551      +0.05990      -0.617        t (0, 0.0798, 48.5)
%  -0.09050      -0.1690       -0.01203      +1.89     (-) t (0, 0.0798, 48.5)
%  -0.02607      -0.1193       +0.06716      -0.382        t (0, 0.0798, 48.5)
%  -0.002752     -0.1225       +0.1170       -0.292        t (0, 0.0798, 48.5)
%  +0.01400      -0.1176       +0.1456       -0.175        t (0, 0.0798, 48.5)
%
%  Outcome 6:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +4.115        +3.810        +4.421        +NaN          U (-Inf, Inf)
%  -0.06685      -0.6010       +0.4673       -0.693        t (0, 0.549, 48.5)
%  +0.1404       -0.3991       +0.6799       -0.576        t (0, 0.549, 48.5)
%  +0.1406       -0.5003       +0.7815       -0.444        t (0, 0.549, 48.5)
%  -0.2098       -1.033        +0.6134       -0.159        t (0, 0.549, 48.5)
%  -0.2721       -1.177        +0.6324       -0.0129       t (0, 0.549, 48.5)
%
%  Outcome 7:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  -0.9672       -0.9984       -0.9359       +NaN          U (-Inf, Inf)
%  -0.01039      -0.06505      +0.04427      -0.651        t (0, 0.0562, 48.5)
%  -0.02671      -0.08191      +0.02848      -0.237        t (0, 0.0562, 48.5)
%  -0.005443     -0.07102      +0.06013      -0.529        t (0, 0.0562, 48.5)
%  -0.03220      -0.1164       +0.05202      +0.00666      t (0, 0.0562, 48.5)
%  -0.03196      -0.1245       +0.06058      +0.0460       t (0, 0.0562, 48.5)
%
%  Outcome 8:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +75.54        +68.15        +82.92        +NaN          U (-Inf, Inf)
%  -3.542        -16.46        +9.372        -0.571        t (0, 13.3, 48.5)
%  -10.87        -23.91        +2.177        +0.676        t (0, 13.3, 48.5)
%  +4.154        -11.34        +19.65        -0.395        t (0, 13.3, 48.5)
%  +18.55        -1.346        +38.45        +1.44     (+) t (0, 13.3, 48.5)
%  +10.31        -11.55        +32.18        +0.256        t (0, 13.3, 48.5)
%
%  Outcome 9:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +164.8        +154.3        +175.4        +NaN          U (-Inf, Inf)
%  +12.44        -5.953        +30.84        +0.200        t (0, 18.9, 48.5)
%  -4.746        -23.33        +13.83        -0.581        t (0, 18.9, 48.5)
%  -2.340        -24.41        +19.73        -0.520        t (0, 18.9, 48.5)
%  -7.435        -35.78        +20.91        -0.152        t (0, 18.9, 48.5)
%  +3.445        -27.70        +34.59        -0.174        t (0, 18.9, 48.5)
%
%  Outcome 10:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +19.63        +18.72        +20.55        +NaN          U (-Inf, Inf)
%  -0.07937      -1.675        +1.517        -0.720        t (0, 1.64, 48.5)
%  -3.910        -5.522        -2.298        +9.16     (-) t (0, 1.64, 48.5)
%  -0.9227       -2.838        +0.9922       -0.0690       t (0, 1.64, 48.5)
%  +1.150        -1.310        +3.609        +0.154        t (0, 1.64, 48.5)
%  -0.3752       -3.077        +2.327        -0.159        t (0, 1.64, 48.5)
%
%  Outcome 11:
%  coefficient   CI_lower      CI_upper      lnBF10    SS  prior
%  +10.98        +10.14        +11.82        +NaN          U (-Inf, Inf)
%  -0.3438       -1.818        +1.130        -0.613        t (0, 1.51, 48.5)
%  +1.790        +0.3008       +3.279        +2.10     (+) t (0, 1.51, 48.5)
%  +0.5753       -1.194        +2.344        -0.326        t (0, 1.51, 48.5)
%  +1.647        -0.6250       +3.918        +0.767    (+) t (0, 1.51, 48.5)
%  +0.1500       -2.346        +2.646        -0.191        t (0, 1.51, 48.5)
%
% Elapsed time is 228.362 seconds.

% %%
% Stability selection probabilities of the regression coefficients
disp(ridge_coeff.stability*100)
% Out:
%  Columns 1 through 6:
%
%           NaN          NaN          NaN          NaN          NaN          NaN
%        69.026       95.273       55.504       60.099       71.424       60.609
%        58.661       93.405       91.513       95.661       99.122       72.956
%        96.907       62.867       85.293       62.653        79.59       72.639
%        57.101       67.097       48.976        55.42        51.15       77.533
%        76.873       53.701       50.439       69.998       69.379       87.684
%
%  Columns 7 through 11:
%
%           NaN          NaN          NaN          NaN          NaN
%        65.188       76.498        95.35       56.008       70.576
%          86.8       97.363        70.71       99.819       99.602
%        57.227       73.911       60.524       90.226       78.007
%        86.636       99.819       77.249       91.892        98.73
%        90.893       96.732       65.318       67.272       57.649

% %% [markdown]
% ## Interpreting the coefficients from sign-flipped helmert contrasts
% 1. is the intercept so represents the grand mean
% 2. is the difference between the two genotypes (G2 - G1) averaged over the conditions
% 3. is the difference between conditions (C2C3 - C1) averaged over the genotypes
% 4. is the difference between conditions (C3 - C2) averaged over the genotypes
% 5. is the difference between the two genotypes (G2 - G1) different in C2C3 compared to C1?
% 6. is the difference between the two genotypes (G2 - G1) different in C3 compared to C2?
%
% The outcome numbers correspond to.
% 1. peak
% 2. afterhyp
% 3. amp
% 4. thresh
% 5. half
% 6. rise
% 7. fall
% 8. IR
% 9. Rh
% 10. sag
% 11. maxApnum
%
% Things I have noticed - there is strong evidence  (lnBF10 = +9.28, BF10 = 10721, SS = 99.8%) for a 3.90 mV decrease in Ih sag, strong evidence for a 0.09 ms narrowing of the action potential (full-width half-maximum) (lnBF10 = +1.92, BF10 = 6.82, SS = 99.2%), and strong evidence for a 1.78 Hz increase in maximum AP firing frequency (lnBF10 = +2.13, BF10 = 8.41), with ketamine/memantine irrespective of genotype. For AP firing frequency, there is some (anecdotal) evidence to indicate that that the genotype effect dependence on drug is a strong predictor of maximum firing rate (lnBF10 = +0.78, BF10 = 2.18, SS = 98.8%). There is good evidence for G2 having an 18.4 Mohm difference between the genotypes depending on the drug condition C1 vs C2C3 (lnBF10 = +1.45, BF10 = 4.26, SS = 99.8%), specifically it is lower for G2 compared to G1 in the control condition, but it is also equally low for both genotypes in C2 and C3 conditions. There is also some anecdotal evidence for a 2.08 mV increase in AP firing threshold in C2C3 compared to C1 irrespective of genotype (lnBF10 = +2.68, BF10 = 14.6, SS = 95.8%).

% %%
# Lets fit using ridge regression and use the hypothesis matrix to return the group estimated marginal means.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_H.X, "*", 1999, .05, MAT_H.L, Deff);
toc
ridge_emm = ans;

# Note that we expect NaN for Bayes factors (BF10) and U (-Inf, Inf) for the prior on all the linear estimates
# of the marginal means since they all involve the intercept.
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 11
%
%  Design effect (Deff): 1.43
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 10.4536
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 5.6066
%
%  Effective residual degrees of freedom (df_lambda): 71.0
%
%  Residual variances (range, Deff-inflated):  [0.0178, 2.01e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 48.3
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     correlation   CI_lower      CI_upper
%  1             2             +0.2686       -0.02007      +0.5159
%  1             3             +0.6748       +0.4809       +0.8058
%  1             4             -0.01441      -0.3002       +0.2738
%  1             5             -0.3349       -0.5674       -0.05291
%  1             6             +0.6278       +0.4157       +0.7752
%  1             7             -0.4401       -0.6456       -0.1752
%  1             8             +0.3176       +0.03361      +0.5542
%  1             9             -0.1844       -0.4478       +0.1084
%  1             10            -0.1640       -0.4308       +0.1292
%  1             11            +0.4007       +0.1284       +0.6168
%  2             3             +0.7342       +0.5665       +0.8435
%  2             4             -0.7531       -0.8553       -0.5945
%  2             5             -0.04710      -0.3297       +0.2433
%  2             6             +0.2846       -0.002691     +0.5285
%  2             7             -0.3404       -0.5716       -0.05913
%  2             8             -0.04617      -0.3289       +0.2441
%  2             9             -0.09577      -0.3726       +0.1967
%  2             10            +0.2923       +0.005657     +0.5345
%  2             11            +0.1688       -0.1243       +0.4348
%  3             4             -0.7476       -0.8519       -0.5864
%  3             5             -0.4150       -0.6273       -0.1452
%  3             6             +0.7413       +0.5770       +0.8479
%  3             7             -0.6676       -0.8011       -0.4708
%  3             8             +0.04702      -0.2433       +0.3296
%  3             9             -0.1859       -0.4490       +0.1069
%  3             10            +0.2625       -0.02660      +0.5111
%  3             11            +0.3921       +0.1184       +0.6105
%  4             5             +0.2609       -0.02835      +0.5098
%  4             6             -0.4394       -0.6451       -0.1743
%  4             7             +0.5085       +0.2592       +0.6942
%  4             8             +0.2221       -0.06937      +0.4787
%  4             9             +0.08586      -0.2063       +0.3640
%  4             10            -0.5032       -0.6905       -0.2526
%  4             11            -0.1707       -0.4364       +0.1224
%  5             6             -0.5809       -0.7439       -0.3526
%  5             7             +0.7922       +0.6538       +0.8793
%  5             8             -0.01065      -0.2968       +0.2773
%  5             9             +0.2117       -0.08029      +0.4702
%  5             10            +0.06516      -0.2261       +0.3458
%  5             11            -0.3708       -0.5946       -0.09369
%  6             7             -0.6724       -0.8042       -0.4774
%  6             8             -0.07003      -0.3501       +0.2215
%  6             9             -0.09571      -0.3725       +0.1968
%  6             10            +0.1809       -0.1119       +0.4449
%  6             11            +0.4087       +0.1378       +0.6227
%  7             8             -0.09920      -0.3756       +0.1934
%  7             9             +0.2504       -0.03949      +0.5015
%  7             10            -0.1351       -0.4064       +0.1581
%  7             11            -0.5009       -0.6889       -0.2497
%  8             9             -0.2928       -0.5349       -0.006271
%  8             10            -0.1558       -0.4239       +0.1374
%  8             11            +0.1178       -0.1752       +0.3916
%  9             10            +0.1391       -0.1541       +0.4098
%  9             11            -0.3784       -0.6003       -0.1024
%  10            11            +0.1582       -0.1350       +0.4259
%
%  95% credible intervals and Bayes factors for linear estimates.
%  Global ridge prior contribution to posterior precision: 40.74 %
%
%  Outcome 1:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +44.76        +42.40        +47.12        +NaN          U (-Inf, Inf)
%  +44.41        +41.94        +46.89        +NaN          U (-Inf, Inf)
%  +43.96        +41.27        +46.65        +NaN          U (-Inf, Inf)
%  +43.10        +40.66        +45.54        +NaN          U (-Inf, Inf)
%  +45.28        +42.71        +47.85        +NaN          U (-Inf, Inf)
%  +45.04        +42.26        +47.82        +NaN          U (-Inf, Inf)
%
%  Outcome 2:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -10.78        -12.68        -8.889        +NaN          U (-Inf, Inf)
%  -11.70        -13.68        -9.718        +NaN          U (-Inf, Inf)
%  -11.97        -14.12        -9.808        +NaN          U (-Inf, Inf)
%  -13.36        -15.32        -11.40        +NaN          U (-Inf, Inf)
%  -11.74        -13.80        -9.680        +NaN          U (-Inf, Inf)
%  -13.06        -15.29        -10.83        +NaN          U (-Inf, Inf)
%
%  Outcome 3:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +82.96        +79.40        +86.52        +NaN          U (-Inf, Inf)
%  +82.72        +79.00        +86.45        +NaN          U (-Inf, Inf)
%  +79.98        +75.93        +84.04        +NaN          U (-Inf, Inf)
%  +79.73        +76.06        +83.41        +NaN          U (-Inf, Inf)
%  +81.27        +77.40        +85.14        +NaN          U (-Inf, Inf)
%  +81.07        +76.88        +85.26        +NaN          U (-Inf, Inf)
%
%  Outcome 4:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -38.20        -40.83        -35.58        +NaN          U (-Inf, Inf)
%  -38.31        -41.06        -35.56        +NaN          U (-Inf, Inf)
%  -36.02        -39.01        -33.03        +NaN          U (-Inf, Inf)
%  -36.63        -39.35        -33.92        +NaN          U (-Inf, Inf)
%  -35.99        -38.85        -33.14        +NaN          U (-Inf, Inf)
%  -36.03        -39.12        -32.94        +NaN          U (-Inf, Inf)
%
%  Outcome 5:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +1.810        +1.728        +1.892        +NaN          U (-Inf, Inf)
%  +1.794        +1.708        +1.879        +NaN          U (-Inf, Inf)
%  +1.737        +1.644        +1.830        +NaN          U (-Inf, Inf)
%  +1.711        +1.627        +1.796        +NaN          U (-Inf, Inf)
%  +1.704        +1.615        +1.793        +NaN          U (-Inf, Inf)
%  +1.692        +1.596        +1.789        +NaN          U (-Inf, Inf)
%
%  Outcome 6:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +3.985        +3.423        +4.547        +NaN          U (-Inf, Inf)
%  +4.058        +3.469        +4.647        +NaN          U (-Inf, Inf)
%  +4.092        +3.451        +4.733        +NaN          U (-Inf, Inf)
%  +4.091        +3.510        +4.673        +NaN          U (-Inf, Inf)
%  +4.369        +3.757        +4.981        +NaN          U (-Inf, Inf)
%  +4.096        +3.434        +4.758        +NaN          U (-Inf, Inf)
%
%  Outcome 7:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.9549       -1.012        -0.8974       +NaN          U (-Inf, Inf)
%  -0.9438       -1.004        -0.8836       +NaN          U (-Inf, Inf)
%  -0.9708       -1.036        -0.9052       +NaN          U (-Inf, Inf)
%  -0.9760       -1.035        -0.9165       +NaN          U (-Inf, Inf)
%  -0.9603       -1.023        -0.8977       +NaN          U (-Inf, Inf)
%  -0.9974       -1.065        -0.9297       +NaN          U (-Inf, Inf)
%
%  Outcome 8:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +90.75        +77.15        +104.3        +NaN          U (-Inf, Inf)
%  +74.82        +60.58        +89.06        +NaN          U (-Inf, Inf)
%  +71.09        +55.60        +86.58        +NaN          U (-Inf, Inf)
%  +68.58        +54.53        +82.63        +NaN          U (-Inf, Inf)
%  +70.08        +55.29        +84.87        +NaN          U (-Inf, Inf)
%  +77.90        +61.89        +93.91        +NaN          U (-Inf, Inf)
%
%  Outcome 9:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +159.3        +139.9        +178.7        +NaN          U (-Inf, Inf)
%  +176.7        +156.4        +197.0        +NaN          U (-Inf, Inf)
%  +160.3        +138.2        +182.4        +NaN          U (-Inf, Inf)
%  +168.6        +148.5        +188.6        +NaN          U (-Inf, Inf)
%  +156.2        +135.2        +177.3        +NaN          U (-Inf, Inf)
%  +167.9        +145.1        +190.7        +NaN          U (-Inf, Inf)
%
%  Outcome 10:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +22.66        +20.98        +24.34        +NaN          U (-Inf, Inf)
%  +21.82        +20.06        +23.58        +NaN          U (-Inf, Inf)
%  +18.54        +16.63        +20.46        +NaN          U (-Inf, Inf)
%  +19.04        +17.30        +20.77        +NaN          U (-Inf, Inf)
%  +17.81        +15.98        +19.64        +NaN          U (-Inf, Inf)
%  +17.93        +15.95        +19.90        +NaN          U (-Inf, Inf)
%
%  Outcome 11:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +10.51        +8.956        +12.06        +NaN          U (-Inf, Inf)
%  +9.065        +7.440        +10.69        +NaN          U (-Inf, Inf)
%  +11.22        +9.456        +12.99        +NaN          U (-Inf, Inf)
%  +11.35        +9.751        +12.96        +NaN          U (-Inf, Inf)
%  +11.72        +10.04        +13.41        +NaN          U (-Inf, Inf)
%  +12.01        +10.18        +13.83        +NaN          U (-Inf, Inf)
%
% Elapsed time is 137.15 seconds.

% %%
# Get the correlations for any pairs of outcomes involving column 11 of outcomes (Apnum)
RTAB = ridge_emm.RTAB;
disp(min(RTAB(:,3)));
disp(max(RTAB(:,3)));
contains_Apnum = any (RTAB(:,1:2) == 11, 2);
RTAB(contains_Apnum,:)
# Columns 1 and 2 are the column numbers of the matrix of outcomes for each pair
# Column 3 is the correlation coefficient between the pair of outcomes.
# Columns 4 and 5 are the lower and upper 95% credible intervals (flat prior)
% Out:
% -0.75307
% 0.79219
% ans =
%
%             1           11      0.40071      0.12841      0.61683
%             2           11      0.16884     -0.12426      0.43485
%             3           11      0.39213      0.11837      0.61048
%             4           11     -0.17069     -0.43638      0.12239
%             5           11     -0.37079     -0.59458    -0.093686
%             6           11      0.40874      0.13783      0.62274
%             7           11     -0.50085     -0.68888     -0.24968
%             8           11      0.11776     -0.17525       0.3916
%             9           11     -0.37837     -0.60025     -0.10242
%            10           11      0.15817     -0.13504      0.42591

% %% [markdown]
% ## Notes
%
% The outcome numbers correspond to.
% 1. peak
% 2. afterhyp
% 3. amp
% 4. thresh
% 5. half
% 6. rise
% 7. fall
% 8. IR
% 9. Rh
% 10. sag
% 11. maxApnum
%
% maxApnum is negatively correlated with rheobase (9, -.38), fall ( 7, -.50), and half (5, -.37). Therefore, lower rheobase, faster AP repolarization and shorter AP full-width half-maximum are associated with higher AP frequency at the highest current injection.
%
% Apnum is positively correlated with AP amplitude (1, +.40), peak (3, +.39) and rise (6, +.41). Therefore, larger amplitude, peak and faster rise of APs are associated with higher AP frequency at the highest current injection.

% %%
# Now lets fit the data again to get the hypothesis matrix for specific group comparisons we are interested in.
comparisons = [2 1; 4 3; 6 5; 3 1; 5 1; 5 3; 4 2; 6 2; 6 4]

# Get design matrix hypothesis matrix for estimated marginal means. We could use any outcome but we'll pick 11.
# This time we set display off. 
MAT_H_PAIRS = bootlm (outcomes(:,11), {genotype, condition}, 'model', 'full', 'nboot', 0, 'display', 'off', ...
                      'contrasts', 'helmert', 'dim', [1, 2], 'posthoc', comparisons);
% Out:
% comparisons =
%
%             2            1
%             4            3
%             6            5
%             3            1
%             5            1
%             5            3
%             4            2
%             6            2
%             6            4

% %%
# Lets fit using ridge regression and use the hypothesis matrix to return the comparisons of interest.
# -- Function File: bootridge (Y, X, CATEGOR, NBOOT, ALPHA, L, DEFF, SEED, TOL)
# Note that we specify CATEGOR input argument as vector 2:6 so that columns 2:6 are treated as categorical
# and we supply our calculated estimate of the design effect.
tic
bootridge(outcomes, MAT_H_PAIRS.X, [2:6], 1999, .05, MAT_H_PAIRS.L, Deff);
toc
ridge_pairs = ans;
# Note that outcome 8 is input resistance
% Out:
%  Empirical Bayes Ridge Regression (.632 Bootstrap Tuning) - Summary
%  *******************************************************************************
%
%  Number of outcomes (q): 11
%
%  Design effect (Deff): 1.43
%
%  Bootstrap resamples (nboot): 1999
%
%  Minimized .632 bootstrap prediction error: 10.4536
%
%  Bootstrap optimized ridge tuning constant (lambda, Deff-adjusted): 5.6066
%
%  Effective residual degrees of freedom (df_lambda): 71.0
%
%  Residual variances (range, Deff-inflated):  [0.0178, 2.01e+03]
%
%  Inferential degrees of freedom (df_t, Deff-adjusted): 48.3
%  Used for credible intervals and Bayes factors below.
%
%  95% credible intervals for correlations between outcomes:
%  (Prior on Fisher's z is flat/improper)
%
%  Outcome J     Outcome I     correlation   CI_lower      CI_upper
%  1             2             +0.2686       -0.02007      +0.5159
%  1             3             +0.6748       +0.4809       +0.8058
%  1             4             -0.01441      -0.3002       +0.2738
%  1             5             -0.3349       -0.5674       -0.05291
%  1             6             +0.6278       +0.4157       +0.7752
%  1             7             -0.4401       -0.6456       -0.1752
%  1             8             +0.3176       +0.03361      +0.5542
%  1             9             -0.1844       -0.4478       +0.1084
%  1             10            -0.1640       -0.4308       +0.1292
%  1             11            +0.4007       +0.1284       +0.6168
%  2             3             +0.7342       +0.5665       +0.8435
%  2             4             -0.7531       -0.8553       -0.5945
%  2             5             -0.04710      -0.3297       +0.2433
%  2             6             +0.2846       -0.002691     +0.5285
%  2             7             -0.3404       -0.5716       -0.05913
%  2             8             -0.04617      -0.3289       +0.2441
%  2             9             -0.09577      -0.3726       +0.1967
%  2             10            +0.2923       +0.005657     +0.5345
%  2             11            +0.1688       -0.1243       +0.4348
%  3             4             -0.7476       -0.8519       -0.5864
%  3             5             -0.4150       -0.6273       -0.1452
%  3             6             +0.7413       +0.5770       +0.8479
%  3             7             -0.6676       -0.8011       -0.4708
%  3             8             +0.04702      -0.2433       +0.3296
%  3             9             -0.1859       -0.4490       +0.1069
%  3             10            +0.2625       -0.02660      +0.5111
%  3             11            +0.3921       +0.1184       +0.6105
%  4             5             +0.2609       -0.02835      +0.5098
%  4             6             -0.4394       -0.6451       -0.1743
%  4             7             +0.5085       +0.2592       +0.6942
%  4             8             +0.2221       -0.06937      +0.4787
%  4             9             +0.08586      -0.2063       +0.3640
%  4             10            -0.5032       -0.6905       -0.2526
%  4             11            -0.1707       -0.4364       +0.1224
%  5             6             -0.5809       -0.7439       -0.3526
%  5             7             +0.7922       +0.6538       +0.8793
%  5             8             -0.01065      -0.2968       +0.2773
%  5             9             +0.2117       -0.08029      +0.4702
%  5             10            +0.06516      -0.2261       +0.3458
%  5             11            -0.3708       -0.5946       -0.09369
%  6             7             -0.6724       -0.8042       -0.4774
%  6             8             -0.07003      -0.3501       +0.2215
%  6             9             -0.09571      -0.3725       +0.1968
%  6             10            +0.1809       -0.1119       +0.4449
%  6             11            +0.4087       +0.1378       +0.6227
%  7             8             -0.09920      -0.3756       +0.1934
%  7             9             +0.2504       -0.03949      +0.5015
%  7             10            -0.1351       -0.4064       +0.1581
%  7             11            -0.5009       -0.6889       -0.2497
%  8             9             -0.2928       -0.5349       -0.006271
%  8             10            -0.1558       -0.4239       +0.1374
%  8             11            +0.1178       -0.1752       +0.3916
%  9             10            +0.1391       -0.1541       +0.4098
%  9             11            -0.3784       -0.6003       -0.1024
%  10            11            +0.1582       -0.1350       +0.4259
%
%  95% credible intervals and Bayes factors for linear estimates.
%  Global ridge prior contribution to posterior precision: 40.74 %
%
%  Outcome 1:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.3479       -3.435        +2.739        -0.567        t (0, 2.78, 48.3)
%  -0.8623       -4.049        +2.325        -0.381        t (0, 2.70, 48.3)
%  -0.2373       -3.513        +3.039        -0.493        t (0, 2.70, 48.3)
%  -0.7967       -4.107        +2.513        -0.443        t (0, 2.89, 48.3)
%  +0.5203       -2.719        +3.760        -0.531        t (0, 2.89, 48.3)
%  +1.317        -1.990        +4.624        -0.127        t (0, 2.58, 48.3)
%  -1.311        -4.531        +1.909        -0.251        t (0, 2.89, 48.3)
%  +0.6309       -2.791        +4.053        -0.459        t (0, 2.89, 48.3)
%  +1.942        -1.355        +5.239        +0.250        t (0, 2.58, 48.3)
%
%  Outcome 2:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.9183       -3.392        +1.556        -0.310        t (0, 2.23, 48.3)
%  -1.394        -3.948        +1.160        +0.0758       t (0, 2.16, 48.3)
%  -1.321        -3.946        +1.304        +0.0127       t (0, 2.16, 48.3)
%  -1.183        -3.836        +1.469        -0.155        t (0, 2.32, 48.3)
%  -0.9572       -3.553        +1.639        -0.305        t (0, 2.32, 48.3)
%  +0.2263       -2.424        +2.876        -0.437        t (0, 2.07, 48.3)
%  -1.660        -4.240        +0.9210       +0.248        t (0, 2.32, 48.3)
%  -1.360        -4.102        +1.383        -0.0274       t (0, 2.32, 48.3)
%  +0.2998       -2.342        +2.942        -0.428        t (0, 2.07, 48.3)
%
%  Outcome 3:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.2374       -4.885        +4.410        -0.588        t (0, 4.18, 48.3)
%  -0.2473       -5.046        +4.551        -0.526        t (0, 4.06, 48.3)
%  -0.2020       -5.134        +4.730        -0.500        t (0, 4.06, 48.3)
%  -2.979        -7.962        +2.005        +0.163        t (0, 4.35, 48.3)
%  -1.689        -6.566        +3.188        -0.338        t (0, 4.35, 48.3)
%  +1.290        -3.689        +6.269        -0.314        t (0, 3.89, 48.3)
%  -2.989        -7.837        +1.860        +0.181        t (0, 4.35, 48.3)
%  -1.654        -6.806        +3.498        -0.318        t (0, 4.35, 48.3)
%  +1.335        -3.629        +6.299        -0.306        t (0, 3.89, 48.3)
%
%  Outcome 4:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.1105       -3.541        +3.320        -0.591        t (0, 3.09, 48.3)
%  -0.6150       -4.156        +2.927        -0.469        t (0, 3.00, 48.3)
%  -0.03527      -3.675        +3.605        -0.504        t (0, 3.00, 48.3)
%  +2.182        -1.496        +5.860        +0.153        t (0, 3.21, 48.3)
%  +2.209        -1.390        +5.809        +0.181        t (0, 3.21, 48.3)
%  +0.02725      -3.647        +3.702        -0.452        t (0, 2.87, 48.3)
%  +1.678        -1.901        +5.256        -0.141        t (0, 3.21, 48.3)
%  +2.285        -1.518        +6.087        +0.204        t (0, 3.21, 48.3)
%  +0.6070       -3.057        +4.271        -0.398        t (0, 2.87, 48.3)
%
%  Outcome 5:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.01598      -0.1229       +0.09090      -0.547        t (0, 0.0962, 48.3)
%  -0.02575      -0.1361       +0.08460      -0.419        t (0, 0.0934, 48.3)
%  -0.01173      -0.1251       +0.1017       -0.482        t (0, 0.0934, 48.3)
%  -0.07263      -0.1872       +0.04198      +0.252        t (0, 0.100, 48.3)
%  -0.1057       -0.2179       +0.006428     +1.18         t (0, 0.100, 48.3)
%  -0.03311      -0.1476       +0.08139      -0.280        t (0, 0.0895, 48.3)
%  -0.08239      -0.1939       +0.02910      +0.511        t (0, 0.100, 48.3)
%  -0.1015       -0.2200       +0.01700      +0.939        t (0, 0.100, 48.3)
%  -0.01909      -0.1332       +0.09506      -0.397        t (0, 0.0895, 48.3)
%
%  Outcome 6:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +0.07313      -0.6616       +0.8079       -0.573        t (0, 0.661, 48.3)
%  -0.0006525    -0.7592       +0.7579       -0.531        t (0, 0.642, 48.3)
%  -0.2732       -1.053        +0.5065       -0.252        t (0, 0.642, 48.3)
%  +0.1070       -0.6808       +0.8949       -0.525        t (0, 0.688, 48.3)
%  +0.3840       -0.3871       +1.155        -0.0778       t (0, 0.688, 48.3)
%  +0.2770       -0.5101       +1.064        -0.198        t (0, 0.615, 48.3)
%  +0.03324      -0.7332       +0.7997       -0.586        t (0, 0.688, 48.3)
%  +0.03767      -0.7768       +0.8522       -0.525        t (0, 0.688, 48.3)
%  +0.004426     -0.7803       +0.7892       -0.455        t (0, 0.615, 48.3)
%
%  Outcome 7:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +0.01110      -0.06408      +0.08628      -0.548        t (0, 0.0677, 48.3)
%  -0.005141     -0.08275      +0.07247      -0.522        t (0, 0.0657, 48.3)
%  -0.03716      -0.1169       +0.04262      -0.0605       t (0, 0.0657, 48.3)
%  -0.01589      -0.09649      +0.06472      -0.483        t (0, 0.0704, 48.3)
%  -0.005328     -0.08422      +0.07356      -0.575        t (0, 0.0704, 48.3)
%  +0.01056      -0.06997      +0.09109      -0.417        t (0, 0.0629, 48.3)
%  -0.03213      -0.1105       +0.04629      -0.246        t (0, 0.0704, 48.3)
%  -0.05359      -0.1369       +0.02975      +0.309        t (0, 0.0704, 48.3)
%  -0.02146      -0.1017       +0.05883      -0.308        t (0, 0.0629, 48.3)
%
%  Outcome 8:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -15.93        -33.69        +1.834        +1.01         t (0, 16.0, 48.3)
%  -2.513        -20.85        +15.82        -0.493        t (0, 15.5, 48.3)
%  +7.815        -11.03        +26.66        -0.152        t (0, 15.5, 48.3)
%  -19.66        -38.70        -0.6130       +1.54         t (0, 16.6, 48.3)
%  -20.66        -39.30        -2.024        +1.83         t (0, 16.6, 48.3)
%  -1.006        -20.03        +18.02        -0.446        t (0, 14.9, 48.3)
%  -6.243        -24.77        +12.28        -0.357        t (0, 16.6, 48.3)
%  +3.080        -16.61        +22.77        -0.479        t (0, 16.6, 48.3)
%  +9.323        -9.647        +28.29        +0.0382       t (0, 14.9, 48.3)
%
%  Outcome 9:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  +17.41        -7.891        +42.72        +0.365        t (0, 22.8, 48.3)
%  +8.243        -17.88        +34.37        -0.327        t (0, 22.1, 48.3)
%  +11.69        -15.16        +38.55        -0.116        t (0, 22.1, 48.3)
%  +1.006        -26.12        +28.14        -0.560        t (0, 23.7, 48.3)
%  -3.061        -29.61        +23.49        -0.557        t (0, 23.7, 48.3)
%  -4.067        -31.17        +23.04        -0.406        t (0, 21.2, 48.3)
%  -8.164        -34.56        +18.23        -0.394        t (0, 23.7, 48.3)
%  -8.780        -36.83        +19.27        -0.328        t (0, 23.7, 48.3)
%  -0.6159       -27.64        +26.41        -0.454        t (0, 21.2, 48.3)
%
%  Outcome 10:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -0.8468       -3.042        +1.348        -0.288        t (0, 1.98, 48.3)
%  +0.4924       -1.774        +2.759        -0.434        t (0, 1.92, 48.3)
%  +0.1164       -2.213        +2.446        -0.499        t (0, 1.92, 48.3)
%  -4.120        -6.474        -1.767        +5.06         t (0, 2.05, 48.3)
%  -4.856        -7.159        -2.552        +7.21         t (0, 2.05, 48.3)
%  -0.7356       -3.087        +1.616        -0.251        t (0, 1.84, 48.3)
%  -2.781        -5.071        -0.4915       +2.28         t (0, 2.05, 48.3)
%  -3.893        -6.326        -1.459        +4.25         t (0, 2.05, 48.3)
%  -1.112        -3.456        +1.233        +0.00438      t (0, 1.84, 48.3)
%
%  Outcome 11:
%  estimate      CI_lower      CI_upper      lnBF10        prior
%  -1.443        -3.471        +0.5844       +0.430        t (0, 1.83, 48.3)
%  +0.1306       -1.963        +2.224        -0.523        t (0, 1.77, 48.3)
%  +0.2810       -1.871        +2.433        -0.469        t (0, 1.77, 48.3)
%  +0.7159       -1.458        +2.890        -0.340        t (0, 1.90, 48.3)
%  +1.217        -0.9112       +3.344        +0.0811       t (0, 1.90, 48.3)
%  +0.5007       -1.671        +2.673        -0.343        t (0, 1.70, 48.3)
%  +2.290        +0.1747       +4.405        +1.72         t (0, 1.90, 48.3)
%  +2.941        +0.6932       +5.189        +2.77         t (0, 1.90, 48.3)
%  +0.6510       -1.515        +2.817        -0.269        t (0, 1.70, 48.3)
%
% Elapsed time is 139.101 seconds.
